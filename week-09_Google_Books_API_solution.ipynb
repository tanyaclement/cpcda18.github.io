# %% [markdown]
# ## Using the Google Books REST API
#
# #### API documentation:
#
# https://developers.google.com/books/docs/v1/getting_started#REST
#
# https://developers.google.com/books/docs/v1/using#query-params

# %%
## Querying the Google Books API with an ISBN and loading the response

from urllib.request import urlopen
import json

url = 'https://www.googleapis.com/books/v1/volumes?q=isbn:162779073X'

json_text = urlopen(url).read().decode('utf8')

print(json_text)
# Out:
# {
#  "kind": "books#volumes",
#  "totalItems": 1,
#  "items": [
#   {
#    "kind": "books#volume",
#    "id": "Q-sxBQAAQBAJ",
#    "etag": "P+Cery74t7w",
#    "selfLink": "https://www.googleapis.com/books/v1/volumes/Q-sxBQAAQBAJ",
#    "volumeInfo": {
#     "title": "No Place to Hide",
#     "subtitle": "Edward Snowden, the NSA, and the U.S. Surveillance State",
#     "authors": [
#      "Glenn Greenwald"
#     ],
#     "publisher": "Macmillan",
#     "publishedDate": "2014-05-13",
#     "description": "An investigative reporter for The Guardian and best-selling author of With Liberty and Justice for Some presents an assessment of the NSA surveillance scandal that has triggered debates over national security and information privacy to explore its alliances and consequences. 150,000 first printing.",
#     "industryIdentifiers": [
#      {
#       "type": "ISBN_13",
#       "identifier": "9781627790734"
#      },
#      {
#       "type": "ISBN_10",
#       "identifier": "162779073X"
#      }
#     ],
#     "readingModes": {
#      "text": false,
#      "image": false
#     },
#     "pageCount": 259,
#     "printType": "BOOK",
#     "categories": [
#      "Computers"
#     ],
#     "averageRating": 4.5,
#     "ratingsCount": 8,
#     "maturityRating": "NOT_MATURE",
#     "allowAnonLogging": false,
#     "contentVersion": "0.1.0.0.preview.0",
#     "imageLinks": {
#      "smallThumbnail": "http://books.google.com/books/content?id=Q-sxBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api",
#      "thumbnail": "http://books.google.com/books/content?id=Q-sxBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api"
#     },
#     "language": "en",
#     "previewLink": "http://books.google.com/books?id=Q-sxBQAAQBAJ&printsec=frontcover&dq=isbn:162779073X&hl=&cd=1&source=gbs_api",
#     "infoLink": "http://books.google.com/books?id=Q-sxBQAAQBAJ&dq=isbn:162779073X&hl=&source=gbs_api",
#     "canonicalVolumeLink": "https://books.google.com/books/about/No_Place_to_Hide.html?hl=&id=Q-sxBQAAQBAJ"
#    },
#    "saleInfo": {
#     "country": "US",
#     "saleability": "NOT_FOR_SALE",
#     "isEbook": false
#    },
#    "accessInfo": {
#     "country": "US",
#     "viewability": "PARTIAL",
#     "embeddable": true,
#     "publicDomain": false,
#     "textToSpeechPermission": "ALLOWED",
#     "epub": {
#      "isAvailable": false
#     },
#     "pdf": {
#      "isAvailable": false
#     },
#     "webReaderLink": "http://play.google.com/books/reader?id=Q-sxBQAAQBAJ&hl=&printsec=frontcover&source=gbs_api",
#     "accessViewStatus": "SAMPLE",
#     "quoteSharingAllowed": false
#    },
#    "searchInfo": {
#     "textSnippet": "An investigative reporter for The Guardian and best-selling author of With Liberty and Justice for Some presents an assessment of the NSA surveillance scandal that has triggered debates over national security and information privacy to ..."
#    }
#   }
#  ]
# }

# %%
## Parsing the JSON text data to create a JSON object

json_object = json.loads(json_text)

json_object
# Out:
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=j_JEDAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'NNgnA27Io84',
#    'id': 'j_JEDAAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': '&quot;A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney&quot;--'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/j_JEDAAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Stephen King'],
#     'averageRating': 4.0,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/End_of_Watch.html?hl=&id=j_JEDAAAQBAJ',
#     'categories': ['Fiction'],
#     'contentVersion': '0.4.0.0.preview.0',
#     'description': '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781501129742', 'type': 'ISBN_13'},
#      {'identifier': '1501129740', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&dq=isbn:9781501129742&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 448,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&pg=PP1&dq=isbn:9781501129742&hl=&cd=1&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016-06-07',
#     'publisher': 'Simon and Schuster',
#     'ratingsCount': 2485,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'A Novel',
#     'title': 'End of Watch'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1}

# %%
## Viewing the top-level keys in the JSON object

for key in json_object:
    print(key)
# Out:
# totalItems
# kind
# items

# %%
## Viewing the list of 'items', which contains metadata for a single book 

json_object['items']
# Out:
# [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#    'country': 'US',
#    'embeddable': True,
#    'epub': {'isAvailable': False},
#    'pdf': {'isAvailable': False},
#    'publicDomain': False,
#    'quoteSharingAllowed': False,
#    'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#    'viewability': 'PARTIAL',
#    'webReaderLink': 'http://play.google.com/books/reader?id=j_JEDAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#   'etag': 'NNgnA27Io84',
#   'id': 'j_JEDAAAQBAJ',
#   'kind': 'books#volume',
#   'saleInfo': {'country': 'US',
#    'isEbook': False,
#    'saleability': 'NOT_FOR_SALE'},
#   'searchInfo': {'textSnippet': '&quot;A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney&quot;--'},
#   'selfLink': 'https://www.googleapis.com/books/v1/volumes/j_JEDAAAQBAJ',
#   'volumeInfo': {'allowAnonLogging': False,
#    'authors': ['Stephen King'],
#    'averageRating': 4.0,
#    'canonicalVolumeLink': 'https://books.google.com/books/about/End_of_Watch.html?hl=&id=j_JEDAAAQBAJ',
#    'categories': ['Fiction'],
#    'contentVersion': '0.4.0.0.preview.0',
#    'description': '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--',
#    'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#     'thumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#    'industryIdentifiers': [{'identifier': '9781501129742', 'type': 'ISBN_13'},
#     {'identifier': '1501129740', 'type': 'ISBN_10'}],
#    'infoLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&dq=isbn:9781501129742&hl=&source=gbs_api',
#    'language': 'en',
#    'maturityRating': 'NOT_MATURE',
#    'pageCount': 448,
#    'panelizationSummary': {'containsEpubBubbles': False,
#     'containsImageBubbles': False},
#    'previewLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&pg=PP1&dq=isbn:9781501129742&hl=&cd=1&source=gbs_api',
#    'printType': 'BOOK',
#    'publishedDate': '2016-06-07',
#    'publisher': 'Simon and Schuster',
#    'ratingsCount': 2485,
#    'readingModes': {'image': False, 'text': False},
#    'subtitle': 'A Novel',
#    'title': 'End of Watch'}}]

# %%
## Viewing keys included in the metadata entry for a single book

for key in json_object['items'][0]:
    print(key)
# Out:
# id
# volumeInfo
# etag
# searchInfo
# selfLink
# kind
# saleInfo
# accessInfo

# %%
## Viewing keys included in a single book's 'volumeInfo'

for key in json_object['items'][0]['volumeInfo']:
    print(key)
# Out:
# title
# infoLink
# publishedDate
# ratingsCount
# imageLinks
# authors
# subtitle
# pageCount
# description
# readingModes
# publisher
# language
# categories
# maturityRating
# allowAnonLogging
# previewLink
# industryIdentifiers
# canonicalVolumeLink
# contentVersion
# averageRating
# printType

# %%
## Viewing the contents of 'volumeInfo' for a single book

json_object['items'][0]['volumeInfo']
# Out:
# {'allowAnonLogging': False,
#  'authors': ['Stephen King'],
#  'averageRating': 4.0,
#  'canonicalVolumeLink': 'https://books.google.com/books/about/End_of_Watch.html?hl=&id=j_JEDAAAQBAJ',
#  'categories': ['Fiction'],
#  'contentVersion': '0.4.0.0.preview.0',
#  'description': '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--',
#  'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#   'thumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#  'industryIdentifiers': [{'identifier': '9781501129742', 'type': 'ISBN_13'},
#   {'identifier': '1501129740', 'type': 'ISBN_10'}],
#  'infoLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&dq=isbn:9781501129742&hl=&source=gbs_api',
#  'language': 'en',
#  'maturityRating': 'NOT_MATURE',
#  'pageCount': 448,
#  'panelizationSummary': {'containsEpubBubbles': False,
#   'containsImageBubbles': False},
#  'previewLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&pg=PP1&dq=isbn:9781501129742&hl=&cd=1&source=gbs_api',
#  'printType': 'BOOK',
#  'publishedDate': '2016-06-07',
#  'publisher': 'Simon and Schuster',
#  'ratingsCount': 2485,
#  'readingModes': {'image': False, 'text': False},
#  'subtitle': 'A Novel',
#  'title': 'End of Watch'}

# %%
## Assigning the contents of 'volumeInfo' to the variable 'volume_info'

item = json_object['items'][0]

volume_info = item['volumeInfo']
item
# Out:
# {'accessInfo': {'accessViewStatus': 'SAMPLE',
#   'country': 'US',
#   'embeddable': True,
#   'epub': {'isAvailable': False},
#   'pdf': {'isAvailable': False},
#   'publicDomain': False,
#   'quoteSharingAllowed': False,
#   'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#   'viewability': 'PARTIAL',
#   'webReaderLink': 'http://play.google.com/books/reader?id=j_JEDAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#  'etag': 'NNgnA27Io84',
#  'id': 'j_JEDAAAQBAJ',
#  'kind': 'books#volume',
#  'saleInfo': {'country': 'US',
#   'isEbook': False,
#   'saleability': 'NOT_FOR_SALE'},
#  'searchInfo': {'textSnippet': '&quot;A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney&quot;--'},
#  'selfLink': 'https://www.googleapis.com/books/v1/volumes/j_JEDAAAQBAJ',
#  'volumeInfo': {'allowAnonLogging': False,
#   'authors': ['Stephen King'],
#   'averageRating': 4.0,
#   'canonicalVolumeLink': 'https://books.google.com/books/about/End_of_Watch.html?hl=&id=j_JEDAAAQBAJ',
#   'categories': ['Fiction'],
#   'contentVersion': '0.4.0.0.preview.0',
#   'description': '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--',
#   'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#    'thumbnail': 'http://books.google.com/books/content?id=j_JEDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#   'industryIdentifiers': [{'identifier': '9781501129742', 'type': 'ISBN_13'},
#    {'identifier': '1501129740', 'type': 'ISBN_10'}],
#   'infoLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&dq=isbn:9781501129742&hl=&source=gbs_api',
#   'language': 'en',
#   'maturityRating': 'NOT_MATURE',
#   'pageCount': 448,
#   'panelizationSummary': {'containsEpubBubbles': False,
#    'containsImageBubbles': False},
#   'previewLink': 'http://books.google.com/books?id=j_JEDAAAQBAJ&pg=PP1&dq=isbn:9781501129742&hl=&cd=1&source=gbs_api',
#   'printType': 'BOOK',
#   'publishedDate': '2016-06-07',
#   'publisher': 'Simon and Schuster',
#   'ratingsCount': 2485,
#   'readingModes': {'image': False, 'text': False},
#   'subtitle': 'A Novel',
#   'title': 'End of Watch'}}

# %%
## Accessing the contents of several metadata fields

volume_info['title']
# Out:
# 'End of Watch'

# %%
volume_info['publisher']
# Out:
# 'Simon and Schuster'

# %%
volume_info['publishedDate']
# Out:
# '2016-06-07'

# %%
volume_info['description']
# Out:
# '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--'

# %%
## Note that the 'authors' field is formatted as a list

volume_info['authors']
# Out:
# ['Stephen King']

# %%
## Reformatting the 'authors' list as a pipe-separated string

'|'.join(volume_info['authors'])
# Out:
# 'Stephen King'

# %%
## Combining several fields to create an example 'row'

title = volume_info['title']
authors = '|'.join(volume_info['authors'])
published_date = volume_info['publishedDate']
publisher = volume_info['publisher']
description = volume_info['description']

row = [title, authors, published_date, publisher, description]

row
# Out:
# ['End of Watch',
#  'Stephen King',
#  '2016-06-07',
#  'Simon and Schuster',
#  '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--']

# %% [markdown]
# ## Using str.format() to construct API query URLs

# %%
"This is a very {} sentence.".format('informative')
# Out:
# 'This is a very informative sentence.'

# %%
adjectives = ['informative', 'short', 'true', 'beautiful', 'misleading']

for adjective in adjectives:
    sentence = "This is a very {} sentence.".format(adjective)
    print(sentence)
# Out:
# This is a very informative sentence.
# This is a very short sentence.
# This is a very true sentence.
# This is a very beautiful sentence.
# This is a very misleading sentence.

# %%
adverbs = ['very', 'fairly', 'definitively', 'kinda']

adjectives = ['informative', 'short', 'true', 'beautiful', 'misleading']

for adverb in adverbs:
    for adjective in adjectives:
        sentence = "This is a {} {} sentence.".format(adverb, adjective)
        print(sentence)
# Out:
# This is a very informative sentence.
# This is a very short sentence.
# This is a very true sentence.
# This is a very beautiful sentence.
# This is a very misleading sentence.
# This is a fairly informative sentence.
# This is a fairly short sentence.
# This is a fairly true sentence.
# This is a fairly beautiful sentence.
# This is a fairly misleading sentence.
# This is a definitively informative sentence.
# This is a definitively short sentence.
# This is a definitively true sentence.
# This is a definitively beautiful sentence.
# This is a definitively misleading sentence.
# This is a kinda informative sentence.
# This is a kinda short sentence.
# This is a kinda true sentence.
# This is a kinda beautiful sentence.
# This is a kinda misleading sentence.

# %%
## Generating a list of API query URLs

isbns = ['1-6277-9073-X', '0-8050-9205-6', '0-307-40802-7', '0-307-35419-9', '0-307-35428-8', '0-9779440-0-X']

for isbn in isbns:
    sanitized_isbn = isbn.replace('-', '')  # removing hyphens from each ISBN
    url = 'https://www.googleapis.com/books/v1/volumes?q=isbn:{}'.format(sanitized_isbn)
    print(url)
# Out:
# https://www.googleapis.com/books/v1/volumes?q=isbn:162779073X
# https://www.googleapis.com/books/v1/volumes?q=isbn:0805092056
# https://www.googleapis.com/books/v1/volumes?q=isbn:0307408027
# https://www.googleapis.com/books/v1/volumes?q=isbn:0307354199
# https://www.googleapis.com/books/v1/volumes?q=isbn:0307354288
# https://www.googleapis.com/books/v1/volumes?q=isbn:097794400X

# %% [markdown]
# ## *Assignment:*
#
# 1. Choose an author and create a list of their books' ISBNs. (Hint: Use Wikipedia.)
#
# 2. Query the Google Books API for each ISBN in the list.
#
# 3. Extract several metadata fields and add them to a list of lists.
#
# 4. Write the list of lists to a CSV file.
#
# Note: SK bibliography: https://en.wikipedia.org/wiki/Stephen_King_bibliography and Stephen King regex: 978.([^\s]+)

# %%
isbn_list = open('sk_bib.txt').read()
isbn_list = isbn_list.split('\n')
isbn_list
# Out:
# ['978-1982102319',
#  '978-1-880418-38-3',
#  '978-1-880-41862-8',
#  '978-1-880-41859-8',
#  '978-1-880-41856-7',
#  '978-1-781-16264-4',
#  '978-1-58767-610-9',
#  '978-1-50118-098-9',
#  '978-1-50116-340-1',
#  '978-1-501-12974-2',
#  '978-1-501-10007-9',
#  '978-1-476-77038-3',
#  '978-1-476-75445-1',
#  '978-1-476-72765-3',
#  '978-1-451-62728-2',
#  '978-1-439-14850-1',
#  '978-1-416-55484-4',
#  '978-1-416-55251-2',
#  '978-0-960-38282-8',
#  '978-0-937986-90-5',
#  '978-0-937986-50-9',
#  '978-0-937986-17-2',
#  '978-0-843-95584-2',
#  '978-0-743-29233-7',
#  '978-0-743-28941-2',
#  '978-0-743-21138-3',
#  '978-0-743-21137-6',
#  '978-0-684-86762-5',
#  '978-0-684-85350-5',
#  '978-0-670-86836-0',
#  '978-0-670-85869-9',
#  '978-0-670-85503-2',
#  '978-0-670-84650-4',
#  '978-0-670-84452-4',
#  '978-0-670-83953-7',
#  '978-0-670-82982-8',
#  '978-0-670-81458-9',
#  '978-0-670-81364-3',
#  '978-0-670-69199-9',
#  '978-0-670-45193-7',
#  '978-0-670-31541-3',
#  '978-0-670-26077-5',
#  '978-0-670-22026-7',
#  '978-0-525-94190-3',
#  '978-0-453-00468-8',
#  '978-0-451-11508-9',
#  '978-0-451-09668-5',
#  '978-0-451-08754-6',
#  '978-0-451-07645-8',
#  '978-0-399-13314-5',
#  '978-0-385-18244-7',
#  '978-0-385-12168-2',
#  '978-0-385-12167-5',
#  '978-0-385-00751-1',
#  '978-0-375-50439-6',
#  '']

# %%
isbn_list = isbn_list[:55]
len(isbn_list)
isbn_list
# Out:
# ['978-1982102319',
#  '978-1-880418-38-3',
#  '978-1-880-41862-8',
#  '978-1-880-41859-8',
#  '978-1-880-41856-7',
#  '978-1-781-16264-4',
#  '978-1-58767-610-9',
#  '978-1-50118-098-9',
#  '978-1-50116-340-1',
#  '978-1-501-12974-2',
#  '978-1-501-10007-9',
#  '978-1-476-77038-3',
#  '978-1-476-75445-1',
#  '978-1-476-72765-3',
#  '978-1-451-62728-2',
#  '978-1-439-14850-1',
#  '978-1-416-55484-4',
#  '978-1-416-55251-2',
#  '978-0-960-38282-8',
#  '978-0-937986-90-5',
#  '978-0-937986-50-9',
#  '978-0-937986-17-2',
#  '978-0-843-95584-2',
#  '978-0-743-29233-7',
#  '978-0-743-28941-2',
#  '978-0-743-21138-3',
#  '978-0-743-21137-6',
#  '978-0-684-86762-5',
#  '978-0-684-85350-5',
#  '978-0-670-86836-0',
#  '978-0-670-85869-9',
#  '978-0-670-85503-2',
#  '978-0-670-84650-4',
#  '978-0-670-84452-4',
#  '978-0-670-83953-7',
#  '978-0-670-82982-8',
#  '978-0-670-81458-9',
#  '978-0-670-81364-3',
#  '978-0-670-69199-9',
#  '978-0-670-45193-7',
#  '978-0-670-31541-3',
#  '978-0-670-26077-5',
#  '978-0-670-22026-7',
#  '978-0-525-94190-3',
#  '978-0-453-00468-8',
#  '978-0-451-11508-9',
#  '978-0-451-09668-5',
#  '978-0-451-08754-6',
#  '978-0-451-07645-8',
#  '978-0-399-13314-5',
#  '978-0-385-18244-7',
#  '978-0-385-12168-2',
#  '978-0-385-12167-5',
#  '978-0-385-00751-1',
#  '978-0-375-50439-6']

# %%
urls = []
for isbn in isbn_list:
    sanitized_isbn = isbn.replace('-', '')  # removing hyphens from each ISBN
    url = 'https://www.googleapis.com/books/v1/volumes?q=isbn:{}'.format(sanitized_isbn)
    urls.append(url)
urls
# Out:
# ['https://www.googleapis.com/books/v1/volumes?q=isbn:9781982102319',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781880418383',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781880418628',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781880418598',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781880418567',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781781162644',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781587676109',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781501180989',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781501163401',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781501129742',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781501100079',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781476770383',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781476754451',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781476727653',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781451627282',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781439148501',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781416554844',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9781416552512',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780960382828',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780937986905',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780937986509',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780937986172',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780843955842',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780743292337',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780743289412',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780743211383',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780743211376',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780684867625',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780684853505',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670868360',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670858699',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670855032',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670846504',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670844524',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670839537',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670829828',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670814589',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670813643',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670691999',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670451937',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670315413',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670260775',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780670220267',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780525941903',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780453004688',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780451115089',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780451096685',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780451087546',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780451076458',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780399133145',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780385182447',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780385121682',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780385121675',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780385007511',
#  'https://www.googleapis.com/books/v1/volumes?q=isbn:9780375504396']

# %%
from urllib.request import urlopen
import json
json_objects = []
for url in urls[:10]:
    json_text = urlopen(url).read().decode('utf8')
    json_object = json.loads(json_text)
    json_objects.append(json_object)

# %%
len(json_objects)
# Out:
# 10

# %%
jo_lists = []
for i in json_objects:
    try: 
        title = i['items'][0]['volumeInfo']['title'] 
        desc_info = i['items'][0]['volumeInfo']['description'] 
        author_info = '|'.join(i['items'][0]['volumeInfo']['authors'])
        pub_date = i['items'][0]['volumeInfo']['publishedDate']
        row = [title, desc_info, author_info, pub_date]
        jo_lists.append(row)
    except: 
        print('no hay:', i)
jo_lists
# Out:
# no hay: {'totalItems': 0, 'kind': 'books#volumes'}
# no hay: {'totalItems': 0, 'kind': 'books#volumes'}
# [['Wizard and glass',
#   'While Roland the Gunslinger and his companions leap between worlds, he relates his experiences with the elusive, powerful emotion of love in a journey into his own past',
#   'Stephen King|Dave McKean',
#   '1997-08'],
#  ['The Dark Tower VII',
#   'The final installment in the epic series completes the quest of Roland Deschain, who works to outmaneuver the increasingly desperate acts of his adversaries and confronts losses within his circle of companions.',
#   'Stephen King|Michael Whelan',
#   '2004-09-21'],
#  ['The Dark Tower VI',
#   "While Jake, Father Callahan, and Oy struggle to free Susannah Dean, whose body is possessed by a demon-mother named Mia, Roland and Eddie find themselves swept by magic to East Stoneham, Maine, in the summer of 1977, where they encounter a terrifying and dangerous worold, one inhabited by the author of a novel called 'Salem's Lot. 700,000 first printing.",
#   'Stephen King',
#   '2004-06-08'],
#  ['Wolves of the Calla',
#   "Along with his companions, gunslinger Roland endeavors to reach and save the Dark Tower, a quest that is challenged by the evil wolves of Thunderclap, who are abducting the children of the residents of a town in the tower's shadow.",
#   'Stephen King',
#   '2003'],
#  ['Joyland',
#   'In a small-town North Carolina amusement park in 1973, college student Devin Jones comes to work as a carny and confronts the legacy of a vicious murder, the fate of a dying child and the ways both will change his life forever. Original.',
#   'Stephen King',
#   '2013-06-01'],
#  ["Gwendy's Button Box",
#   'Journey back to Castle Rock again in this chilling new novella by Stephen King, bestselling author of The Bazaar of Bad Dreams, and Richard Chizmar, award-winning author of A Long December. This book will be a Cemetery Dance Publications exclusive with no other editions currently planned anywhere in the world!',
#   'Stephen King|Richard Chizmar',
#   '2017-05-30'],
#  ['Sleeping Beauties',
#   'The authors tell the highest of high-stakes stories: what might happen if women disappeared from the world of men?',
#   'Stephen King|Owen King',
#   '2017-09-26'],
#  ['End of Watch',
#   '"A ... suspenseful closing volume--Brady Hartsfield, the Mercedes killer, ... returns to diabolically drive his victims to suicide in this last, ... installment starring the ever more winning Bill Hodges and Holly Gibney"--',
#   'Stephen King',
#   '2016-06-07']]

# %%
import csv

out_path = "SK_table.csv"

header = ['title', 'desc_info', 'author_info', 'pub_date']

with open(out_path, 'w') as fo:
    csv_writer = csv.writer(fo)
    csv_writer.writerow(header)
    csv_writer.writerows(jo_lists)

# %% [markdown]
# ## Google Books Free Text Query

# %%
from urllib.request import urlopen
import json

url = 'https://www.googleapis.com/books/v1/volumes?q=Glenn+Greenwald&maxResults=40'

json_text = urlopen(url).read().decode('utf8')

json_object = json.loads(json_text)

json_object
# Out:
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/No_Place_to_Hide-sample-epub.acsm?id=AvFzAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=AvFzAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'ePO+wwMcwRU',
#    'id': 'AvFzAgAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=AvFzAgAAQBAJ&rdid=book-AvFzAgAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Coming at a landmark moment in American history, No Place to Hide is a fearless, incisive, and essential contribution to our understanding of the U.S. surveillance state.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/AvFzAgAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 4.5,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-AvFzAgAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '2.9.9.0.preview.2',
#     'description': "In May 2013, Glenn Greenwald set out for Hong Kong to meet an anonymous source who claimed to have astonishing evidence of pervasive government spying and insisted on communicating only through heavily encrypted channels. That source turned out to be the 29-year-old NSA contractor and whistleblower Edward Snowden, and his revelations about the agency's widespread, systemic overreach proved to be some of the most explosive and consequential news in recent history, triggering a fierce debate over national security and information privacy. As the arguments rage on and the government considers various proposals for reform, it is clear that we have yet to see the full impact of Snowden's disclosures. Now for the first time, Greenwald fits all the pieces together, recounting his high-intensity ten-day trip to Hong Kong, examining the broader implications of the surveillance detailed in his reporting for The Guardian, and revealing fresh information on the NSA's unprecedented abuse of power with never-before-seen documents entrusted to him by Snowden himself. Going beyond NSA specifics, Greenwald also takes on the establishment media, excoriating their habitual avoidance of adversarial reporting on the government and their failure to serve the interests of the people. Finally, he asks what it means both for individuals and for a nation's political health when a government pries so invasively into the private lives of its citizens—and considers what safeguards and forms of oversight are necessary to protect democracy in the digital age. Coming at a landmark moment in American history, No Place to Hide is a fearless, incisive, and essential contribution to our understanding of the U.S. surveillance state.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=AvFzAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=AvFzAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781627790741', 'type': 'ISBN_13'},
#      {'identifier': '1627790748', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=AvFzAgAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 272,
#     'previewLink': 'http://books.google.com/books?id=AvFzAgAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=1&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-13',
#     'publisher': 'Metropolitan Books',
#     'ratingsCount': 9,
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': 'Edward Snowden, the NSA, and the U.S. Surveillance State',
#     'title': 'No Place to Hide'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/With_Liberty_and_Justice_for_Some-sample-epub.acsm?id=Je_fc_WjF9oC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=Je_fc_WjF9oC&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'kvsGb6iD48s',
#    'id': 'Je_fc_WjF9oC',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=Je_fc_WjF9oC&rdid=book-Je_fc_WjF9oC&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Cogent, sharp, and urgent, this is a no-holds-barred indictment of a profoundly un-American system that sanctions immunity at the top and mercilessness for everyone else.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/Je_fc_WjF9oC',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 4.5,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-Je_fc_WjF9oC',
#     'categories': ['Law'],
#     'contentVersion': '1.3.0.0.preview.2',
#     'description': 'From "the most important voice to have entered the political discourse in years" (Bill Moyers), a scathing critique of the two-tiered system of justice that has emerged in America From the nation\'s beginnings, the law was to be the great equalizer in American life, the guarantor of a common set of rules for all. But over the past four decades, the principle of equality before the law has been effectively abolished. Instead, a two-tiered system of justice ensures that the country\'s political and financial class is virtually immune from prosecution, licensed to act without restraint, while the politically powerless are imprisoned with greater ease and in greater numbers than in any other country in the world. Starting with Watergate, continuing on through the Iran-Contra scandal, and culminating with Obama\'s shielding of Bush-era officials from prosecution, Glenn Greenwald lays bare the mechanisms that have come to shield the elite from accountability. He shows how the media, both political parties, and the courts have abetted a process that has produced torture, war crimes, domestic spying, and financial fraud. Cogent, sharp, and urgent, this is a no-holds-barred indictment of a profoundly un-American system that sanctions immunity at the top and mercilessness for everyone else.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Je_fc_WjF9oC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=Je_fc_WjF9oC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781466805767', 'type': 'ISBN_13'},
#      {'identifier': '1466805765', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=Je_fc_WjF9oC&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 304,
#     'previewLink': 'http://books.google.com/books?id=Je_fc_WjF9oC&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=2&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2011-11-11',
#     'publisher': 'Metropolitan Books',
#     'ratingsCount': 13,
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': 'How the Law Is Used to Destroy Equality and Protect the Powerful',
#     'title': 'With Liberty and Justice for Some'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=1XgaAQAAIAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'ZVGIcgn4jdQ',
#    'id': '1XgaAQAAIAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Proposes that a creeping extremism has taken hold of the federal government and, to remain true to America&#39;s founding principles, argues that society must fight against the president&#39;s unlimited and unchecked powers.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/1XgaAQAAIAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 4.0,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/How_Would_a_Patriot_Act.html?hl=&id=1XgaAQAAIAAJ',
#     'categories': ['Political Science'],
#     'contentVersion': 'preview-1.0.0',
#     'description': "Proposes that a creeping extremism has taken hold of the federal government and, to remain true to America's founding principles, argues that society must fight against the president's unlimited and unchecked powers.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=1XgaAQAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=1XgaAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '097794400X', 'type': 'ISBN_10'},
#      {'identifier': '9780977944002', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=1XgaAQAAIAAJ&dq=Glenn+Greenwald&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 128,
#     'previewLink': 'http://books.google.com/books?id=1XgaAQAAIAAJ&q=Glenn+Greenwald&dq=Glenn+Greenwald&hl=&cd=3&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2006',
#     'publisher': 'Working Assets Pub',
#     'ratingsCount': 3,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Defending American Values from a President Run Amok',
#     'title': 'How Would a Patriot Act?'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/A_Tragic_Legacy-sample-epub.acsm?id=NEmZvR6OiU0C&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/A_Tragic_Legacy-sample-pdf.acsm?id=NEmZvR6OiU0C&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=NEmZvR6OiU0C&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': '5+opOhnrYVw',
#    'id': 'NEmZvR6OiU0C',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=NEmZvR6OiU0C&rdid=book-NEmZvR6OiU0C&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 4.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 4990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 4990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 4.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Enlightening, powerful, and eye-opening, this is an in-depth look at the man whose incapability and cowboy logic have left America at risk. From the Hardcover edition.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/NEmZvR6OiU0C',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 5.0,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-NEmZvR6OiU0C',
#     'categories': ['Political Science'],
#     'contentVersion': '0.2.1.0.preview.3',
#     'description': 'What will be the legacy of President George Walker Bush? In this fascinating, timely book, Glenn Greenwald examines the Bush presidency and its long-term effect on the nation. What began on shaky, uncertain ground and was bolstered and propelled by tragedy, has ultimately faltered and failed on the back of the dichotomous worldview—good versus evil—that once served it so well. In A Tragic Legacy, Greenwald charts the rise and steep fall of the current administration, dissecting the rhetoric and revealing the faulty ideals upon which George W. Bush built his policies. On September 12, 2001, President Bush addressed the nation and presented a very clear view of what was to come—a view that can be said to define his entire presidency: “This will be a monumental struggle of good versus evil.” Based on his own Christian faith and backed by biblical allusions, Bush’s worldview was basic and binary—and everyone was forced to choose a side. Riding high on public support, Bush sailed through the early “War on Terror,” easily defining our enemies and clearly setting an agenda for defeating them. But once the war became murkier—its target unclear, its combatants no longer seen in black-and-white—support for Bush and his policies dropped precipitously. Glenn Greenwald brilliantly reveals the reasons behind the collapse of Bush’s power and approval, and argues that his greatest weakness is the same rhetoric that once propelled him so far forward. Facing issues that could not be turned into simple good versus evil choices—the disaster of Hurricane Katrina, his plans for Social Security “reform,” and, most ironic, the failed Dubai ports deal—Bush faltered and fell. Now, Greenwald argues, Bush is trapped by his own choices, unable to break out of the mold that once served him so well, and indifferent to the consequences. A Tragic Legacy is the first true character study of one of the most controversial men ever to hold the office of president. Enlightening, powerful, and eye-opening, this is an in-depth look at the man whose incapability and cowboy logic have left America at risk. From the Hardcover edition.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=NEmZvR6OiU0C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=NEmZvR6OiU0C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780307395214', 'type': 'ISBN_13'},
#      {'identifier': '0307395219', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=NEmZvR6OiU0C&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 320,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=NEmZvR6OiU0C&pg=PP1&dq=Glenn+Greenwald&hl=&cd=4&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2007-06-26',
#     'publisher': 'Crown',
#     'ratingsCount': 2,
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'How a Good vs. Evil Mentality Destroyed the Bush Presidency',
#     'title': 'A Tragic Legacy'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=1gUODAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'UjFzPBLgKYo',
#    'id': '1gUODAAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'The &quot;author and his colleagues at the investigative website, The Intercept, expose stunning new details about America&#39;s secret assassination policy.&quot;--NoveList.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/1gUODAAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Jeremy Scahill', 'The Staff of the Intercept'],
#     'averageRating': 3.5,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/The_Assassination_Complex.html?hl=&id=1gUODAAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '0.1.0.0.preview.0',
#     'description': 'Major revelations about the US government’s drone program—bestselling author Jeremy Scahill and his colleagues at the investigative website The Intercept expose stunning new details about America’s secret assassination policy. When the US government discusses drone strikes publicly, it offers assurances that such operations are a more precise alternative to troops on the ground and are authorized only when an “imminent” threat is present and there is “near certainty” that the intended target will be killed. The implicit message on drone strikes from the Obama administration has been trust, but don’t verify. The online magazine The Intercept exploded this secrecy when it obtained a cache of secret slides that provide a window into the inner workings of the US military’s kill/capture operations in Afghanistan, Yemen, and Somalia. Whether through the use of drones, night raids, or new platforms yet to be employed, these documents show assassination to be central to US counterterrorism policy. The classified documents reveal that Washington’s fourteen-year targeted killing campaign suffers from an overreliance on flawed signals intelligence, an apparently incalculable civilian toll, and an inability to extract potentially valuable intelligence from terror suspects. This campaign, carried out by two presidents through four presidential terms, has been deliberately obscured from the public and insulated from democratic debate. The Assassination Complex allows us to understand at last the circumstances under which the US government grants itself the right to sentence individuals to death without the established checks and balances of arrest, trial, and appeal. The book will include original contributions from Glenn Greenwald and Edward Snowden.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=1gUODAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=1gUODAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781501144134', 'type': 'ISBN_13'},
#      {'identifier': '1501144138', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=1gUODAAAQBAJ&dq=Glenn+Greenwald&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 256,
#     'previewLink': 'http://books.google.com/books?id=1gUODAAAQBAJ&pg=PR1&dq=Glenn+Greenwald&hl=&cd=5&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016-05-01',
#     'publisher': 'Simon and Schuster',
#     'ratingsCount': 17,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Inside the Governments Secret Drone Warfare Program',
#     'title': 'The Assassination Complex'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=x6vE_fJ4f-IC&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'tkMMZDru7aw',
#    'id': 'x6vE_fJ4f-IC',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'A former constitutional law attorney and best-selling author of A Tragic Legacy goes behind the scenes of the right-wing&#39;s pre-election propaganda to expose the fraud behind the image created by the Republican Party for their presidential ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/x6vE_fJ4f-IC',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 5.0,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Great_American_Hypocrites.html?hl=&id=x6vE_fJ4f-IC',
#     'categories': ['Political Science'],
#     'contentVersion': '0.2.1.0.preview.0',
#     'description': "A former constitutional law attorney and best-selling author of A Tragic Legacy goes behind the scenes of the right-wing's pre-election propaganda to expose the fraud behind the image created by the Republican Party for their presidential candidates and to reveal the truth behind the myths and hoaxes they perpetrate. 75,000 first printing.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=x6vE_fJ4f-IC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=x6vE_fJ4f-IC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780307408662', 'type': 'ISBN_13'},
#      {'identifier': '0307408663', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=x6vE_fJ4f-IC&dq=Glenn+Greenwald&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 290,
#     'previewLink': 'http://books.google.com/books?id=x6vE_fJ4f-IC&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=6&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2008',
#     'publisher': 'Broadway Books',
#     'ratingsCount': 1,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Toppling the Big Myths of Republican Politics',
#     'title': 'Great American Hypocrites'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=06zLjwEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'FV/rJIIR3dY',
#    'id': '06zLjwEACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/06zLjwEACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Instaread Summaries'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Summary_of_No_Place_to_Hide.html?hl=&id=06zLjwEACAAJ',
#     'categories': ['Law'],
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=06zLjwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=06zLjwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '1945251581', 'type': 'ISBN_10'},
#      {'identifier': '9781945251580', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=06zLjwEACAAJ&dq=Glenn+Greenwald&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 42,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=06zLjwEACAAJ&dq=Glenn+Greenwald&hl=&cd=7&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016-04-04',
#     'publisher': 'Idreambooks',
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'By Glenn Greenwald | Includes Analysis',
#     'title': 'Summary of No Place to Hide'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/The_Snowden_Files-sample-epub.acsm?id=Ri6uAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=Ri6uAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': '9RG5aLOlzgw',
#    'id': 'Ri6uAgAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=Ri6uAgAAQBAJ&rdid=book-Ri6uAgAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 11.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 11990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 11990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 11.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'The result is a gripping insider narrative—and a necessary and timely account of what is at stake for all of us in the new digital age. From the Trade Paperback edition.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/Ri6uAgAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Luke Harding'],
#     'averageRating': 4.0,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-Ri6uAgAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.6.6.0.preview.2',
#     'description': 'Now a major motion picture, directed by Oliver Stone and starring Joseph Gordon-Levitt. Edward Snowden was a 29-year-old computer genius working for the National Security Agency when he shocked the world by exposing the near-universal mass surveillance programs of the United States government. His whistleblowing has shaken the leaders of nations worldwide, and generated a passionate public debate on the dangers of global monitoring and the threat to individual privacy. In a tour de force of investigative journalism that reads like a spy novel, award-winning Guardian reporter Luke Harding tells Snowden’s astonishing story—from the day he left his glamorous girlfriend in Honolulu carrying a hard drive full of secrets, to the weeks of his secret-spilling in Hong Kong, to his battle for asylum and his exile in Moscow. For the first time, Harding brings together the many sources and strands of the story—touching on everything from concerns about domestic spying to the complicity of the tech sector—while also placing us in the room with Edward Snowden himself. The result is a gripping insider narrative—and a necessary and timely account of what is at stake for all of us in the new digital age. From the Trade Paperback edition.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Ri6uAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=Ri6uAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780804173537', 'type': 'ISBN_13'},
#      {'identifier': '0804173532', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=Ri6uAgAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 320,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=Ri6uAgAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=8&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-02-07',
#     'publisher': 'Vintage',
#     'ratingsCount': 9,
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': "The Inside Story of the World's Most Wanted Man",
#     'title': 'The Snowden Files'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Does_State_Spying_Make_Us_Safer-sample-epub.acsm?id=BhOMBQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Does_State_Spying_Make_Us_Safer-sample-pdf.acsm?id=BhOMBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=BhOMBQAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'Q63Riw9Mxio',
#    'id': 'BhOMBQAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=BhOMBQAAQBAJ&rdid=book-BhOMBQAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 12.95, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 12950000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'In this edition of the Munk Debates, former head of the CIA and NSA Michael Hayden and civil liberties lawyer Alan Dershowitz square off against journalist Glenn Greenwald and reddit co-founder Alexis Ohanian to debate the legitimacy of ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/BhOMBQAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Michael Hayden',
#      'Alan Dershowitz',
#      'Glenn Greenwald',
#      'Alexis Ohanian'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-BhOMBQAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.1.1.0.preview.3',
#     'description': 'Does government surveillance make us safer? The thirteenth Munk Debate, held in Toronto on Friday, May 2, 2014, pitted Michael Hayden and Alan Dershowitz against Glenn Greenwald and Alexis Ohanian to debate whether state surveillance is a legitimate defence of our freedom — the democratic issue of the moment. In a risk-filled world, democracies are increasingly turning to large-scale state surveillance, at home and abroad, to fight complex and unconventional threats — but is it justified? For some, the threats more than justify the current surveillance system, and the laws and institutions of democracies are more than capable of balancing the needs of individual privacy with collective security. But for others, we are in peril of sacrificing to a vast and unaccountable state surveillance apparatus the civil liberties that guarantee citizens’ basic freedoms and our democratic way of life. In this edition of the Munk Debates, former head of the CIA and NSA Michael Hayden and civil liberties lawyer Alan Dershowitz square off against journalist Glenn Greenwald and reddit co-founder Alexis Ohanian to debate the legitimacy of state surveillance. With issues of Internet privacy increasingly gaining prominence, the Munk Debate on the Surveillance State asks: Should government be able to monitor our activities in order to keep us safe?',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=BhOMBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=BhOMBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781770898424', 'type': 'ISBN_13'},
#      {'identifier': '1770898425', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=BhOMBQAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 128,
#     'previewLink': 'http://books.google.com/books?id=BhOMBQAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=9&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-11-21',
#     'publisher': 'House of Anansi',
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'The Munk Debate on Mass Surveillance',
#     'title': 'Does State Spying Make Us Safer?'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Pay_Any_Price-sample-epub.acsm?id=P7zaAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Pay_Any_Price-sample-pdf.acsm?id=P7zaAgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=P7zaAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'bvV9wdUu0Gw',
#    'id': 'P7zaAgAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=P7zaAgAAQBAJ&rdid=book-P7zaAgAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'In Pay Any Price, Pulitzer Prize winner James Risen reveals an extraordinary litany of the hidden costs of that war: billions of dollars that went missing from Iraq only to turn up in a bunker in Lebanon; whistleblowers abused, including a ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/P7zaAgAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['James Risen'],
#     'averageRating': 4.5,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-P7zaAgAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.6.6.0.preview.3',
#     'description': '"James Risen has established himself as the finest national security reporter of this generation, a field crowded with first rank talent." —Newsweek “An important and powerful book that should be read by anyone who believes it is time to take stock after thirteen years and re-evaluate the nature of the threat the country faces and its response to the atrocity of 9/11.” —New York Times Book Review Ever since 9/11 America has fought an endless war on terror, seeking enemies everywhere and never promising peace. In Pay Any Price, Pulitzer Prize winner James Risen reveals an extraordinary litany of the hidden costs of that war: billions of dollars that went missing from Iraq only to turn up in a bunker in Lebanon; whistleblowers abused, including a staffer on the House Intelligence Committee persecuted by the F.B.I. for expressing her concerns about the NSA spying on U.S. citizens; and an entire professional organization, the American Psychological Association, forced to investigate its own involvement with the government’s use of torture. In the name of fighting terrorism, our government has perpetrated acts that rival the shameful historic wartime abuses of generations past, and it has worked very hard to cover them up. James Risen brings them into the light. “[Pay Any Price is] a wide-ranging look at consequences of the so-called war on terror and includes stories of shocking thievery during the U.S. occupation of Iraq.” —U.S. News & World Report “A no-holds-barred tarring and feathering of the past thirteen years of the U.S. national security system. At times frightening, Risen’s book is a strong reminder of the importance of a free press keeping a powerful government in check.” —Daily Beast',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=P7zaAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=P7zaAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780544341425', 'type': 'ISBN_13'},
#      {'identifier': '0544341422', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=P7zaAgAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 304,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=P7zaAgAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=10&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-10-14',
#     'publisher': 'Houghton Mifflin Harcourt',
#     'ratingsCount': 6,
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'Greed, Power, and Endless War',
#     'title': 'Pay Any Price'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/The_Battle_for_Justice_in_Palestine-sample-epub.acsm?id=r70cAwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/The_Battle_for_Justice_in_Palestine-sample-pdf.acsm?id=r70cAwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=r70cAwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'rTiG2ULpuxI',
#    'id': 'r70cAwAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=r70cAwAAQBAJ&rdid=book-r70cAwAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 16.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 16990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'As Israeli society lurches toward greater extremism, many ask where the struggle is headed. This book offers a clear analysis of this crossroads moment and looks forward with urgency down the path to a more hopeful future.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/r70cAwAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Ali Abunimah'],
#     'averageRating': 5.0,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-r70cAwAAQBAJ',
#     'categories': ['History'],
#     'contentVersion': '2.4.3.0.preview.3',
#     'description': 'Efforts to achieve a "two-state solution" have finally collapsed, and the struggle for justice in Palestine is at a crossroads. As Israeli society lurches toward greater extremism, many ask where the struggle is headed. This book offers a clear analysis of this crossroads moment and looks forward with urgency down the path to a more hopeful future.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=r70cAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=r70cAwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781608463473', 'type': 'ISBN_13'},
#      {'identifier': '1608463478', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=r70cAwAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 224,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=r70cAwAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=11&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-03-03',
#     'publisher': 'Haymarket Books',
#     'ratingsCount': 2,
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'The Case for a Single Democratic State in Palestine',
#     'title': 'The Battle for Justice in Palestine'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/No_Place_to_Hide-sample-epub.acsm?id=uXsnDQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/No_Place_to_Hide-sample-pdf.acsm?id=uXsnDQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=uXsnDQAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'lmFr1Qq51Yk',
#    'id': 'uXsnDQAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=uXsnDQAAQBAJ&rdid=book-uXsnDQAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 3.63, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 3630000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 2760000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 2.76, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Bersama Glenn Greenwald, kolumnis The Guardian, mereka membongkar sistem pengintaian masif rahasia ciptaan Amerika Serikat dan sekutunya ke ranah publik. [Mizan, Bentang Pustaka, Politik, Terjemahan, Wikileaks, Indonesia]'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/uXsnDQAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-uXsnDQAAQBAJ',
#     'categories': ['Computers'],
#     'contentVersion': '1.1.1.0.preview.3',
#     'description': 'Dalam beberapa dasawarsa terakhir, pemerintah Amerika Serikat telah mengeksploitasi rasa takut akan terorisme untuk menjustifikasi aneka kebijakan ekstrem. Dengan dalih ini, National Security Agency (NSA) bekerja sama secara rahasia dengan Microsoft, Yahoo!, Google, Facebook, PalTalk, AOL, Skype, YouTube, dan Apple. NSA diberi wewenang penuh untuk mengumpulkan data langsung dari server sembilan perusahaan komputer berskala internasional tersebut. Edward Snowden, pakar keamanan komputer NSA, tidak bisa menerima tindakan pemerintah AS tersebut. Bagi Snowden, internet adalah ruang yang menjanjikan kebebasan dan peluang untuk eksplorasi. Pemerintah bisa dengan semena-mena memanfaatkan informasi pribadi pesaingnya demi kepentingan politik yang kotor. Menggadaikan kebebasannya sendiri, Edward Snowden hengkang dari NSA dan merencanakan serangkaian strategi. Bersama Glenn Greenwald, kolumnis The Guardian, mereka membongkar sistem pengintaian masif rahasia ciptaan Amerika Serikat dan sekutunya ke ranah publik. [Mizan, Bentang Pustaka, Politik, Terjemahan, Wikileaks, Indonesia]',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=uXsnDQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=uXsnDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9786022910695', 'type': 'ISBN_13'},
#      {'identifier': '6022910692', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=uXsnDQAAQBAJ&source=gbs_api',
#     'language': 'id',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 384,
#     'previewLink': 'http://books.google.com/books?id=uXsnDQAAQBAJ&pg=PP1&dq=Glenn+Greenwald&hl=&cd=12&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016-10-06',
#     'publisher': 'Bentang Pustaka',
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': '',
#     'title': 'No Place to Hide'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Shadow_Government-sample-epub.acsm?id=_QHnBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Shadow_Government-sample-pdf.acsm?id=_QHnBAAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=_QHnBAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'aC2yNpYo4fA',
#    'id': '_QHnBAAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=_QHnBAAAQBAJ&rdid=book-_QHnBAAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 15.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 15990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Shadow Government offers a powerful survey of a democracy of the wealthy that your grandparents wouldn&#39;t have recognized. Tom Engelhardt created and runs the TomDispatch.com website, a project of the Nation Institute, where he is a fellow.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/_QHnBAAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Tom Engelhardt'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-_QHnBAAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '2.9.10.0.preview.3',
# ...
#       'retailPrice': {'amountInMicros': 15390000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 15.39, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'The Drone Memos collects for the first time the legal and policy documents underlying the U.S. government’s deeply controversial practice of “targeted killing”—the extrajudicial killing of suspected terrorists and militants, ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/-0tmDQAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Jameel Jaffer'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book--0tmDQAAQBAJ',
#     'categories': ['Law'],
#     'contentVersion': '1.3.3.0.preview.3',
#     'description': 'The Drone Memos collects for the first time the legal and policy documents underlying the U.S. government’s deeply controversial practice of “targeted killing”—the extrajudicial killing of suspected terrorists and militants, typically using remotely piloted aircraft or “drones.” The documents—including the Presidential Policy Guidance that provides the framework for drone strikes today, Justice Department white papers addressing the assassination of an American citizen, and a highly classified legal memo that was published only after a landmark legal battle involving the ACLU, the New York Times, and the CIA—together constitute a remarkable effort to legitimize a practice that most human rights experts consider to be unlawful and that the United States has historically condemned. In a lucid and provocative introduction, Jameel Jaffer, who led the ACLU legal team that secured the release of many of the documents, evaluates the “drone memos” in light of domestic and international law. He connects the documents’ legal abstractions to the real-world violence they allow, and makes the case that we are trading core principles of democracy and human rights for the illusion of security.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=-0tmDQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=-0tmDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781620972601', 'type': 'ISBN_13'},
#      {'identifier': '1620972603', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=-0tmDQAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 224,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=-0tmDQAAQBAJ&pg=PP1&dq=Glenn+Greenwald&hl=&cd=37&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016-11-15',
#     'publisher': 'New Press, The',
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'Targeted Killing, Secrecy, and the Law',
#     'title': 'The Drone Memos'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Afacerea_Edward_Snowden-sample-epub.acsm?id=na5TCgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Afacerea_Edward_Snowden-sample-pdf.acsm?id=na5TCgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=na5TCgAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'MXsBPBSkEtw',
#    'id': 'na5TCgAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=na5TCgAAQBAJ&rdid=book-na5TCgAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 8.32, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 8320000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 6990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 6.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Internetul democratizează discursul politic şi echilibrează balanţa între cei puternici şi cei slabi, iar libertatea lui – posibilitatea de a folosi reţeaua fără constrângeri instituţionale și sociale sau fără controlul ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/na5TCgAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-na5TCgAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.4.6.0.preview.3',
#     'description': 'Internetul democratizează discursul politic şi echilibrează balanţa între cei puternici şi cei slabi, iar libertatea lui – posibilitatea de a folosi reţeaua fără constrângeri instituţionale și sociale sau fără controlul statului şi fără o teamă permanentă – este esențială. Convertirea internetului într-un sistem de supraveghere îl privează astfel de potenţialul său, îl transformă într-un instrument de represiune, ameninţând să producă arma cea mai opresivă şi extremă a intruziunii statului din istorie. De aceea uluitoarele dezvăluiri ale lui Snowden sunt atât de importante. Ele au concentrat atenţia lumii asupra pericolelor supravegherii omniprezente din partea statului, au generat prima dezbatere globală despre valoarea vieţii private în epoca digitală şi au determinat contestarea controlului hegemonic al Americii asupra internetului. Au schimbat modul în care oamenii au văzut autenticitatea oricărei declaraţii făcute de oficialii SUA şi au transformat relaţiile între ţări. Au modificat radical viziunile despre rolul adecvat al jurnalismului în relaţia cu puterea guvernamentală. Îndrăznind să expună surprinzătoarele capacităţi de supraveghere ale NSA, Snowden a clarificat că ne aflăm la o răscruce de drumuri. Va fi era digitală un precursor al libertăţii individuale şi al libertăţilor politice pe care internetul este singurul capabil să le elibereze? Sau va aduce un sistem de monitorizare şi control omniprezent, dincolo de visurile celor mai mari tirani din trecut? Acţiunile noastre vor stabili încotro ne vom îndrepta.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=na5TCgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=na5TCgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9786067419436', 'type': 'ISBN_13'},
#      {'identifier': '6067419432', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=na5TCgAAQBAJ&source=gbs_api',
#     'language': 'ro',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 242,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=na5TCgAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=38&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2015-08-03',
#     'publisher': 'Litera via PublishDrive',
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'Cele mai șocante dezvăluiri despre spionajul global american',
#     'title': 'Afacerea Edward Snowden'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=f95HDwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'JssmDNBrFVg',
#    'id': 'f95HDwAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'The book comes at a vital time, and is indispensable for current debates about NSA surveillance and related counterterrorism activities.&quot;--Eric A. Posner, coauthor of The Executive Unbound &quot;A truly excellent and provocative book.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/f95HDwAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Rahul Sagar'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Who_Guards_the_Guardians_Secrecy_in_Gove.html?hl=&id=f95HDwAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': 'preview-1.0.0',
#     'description': '"In this provocative and original book, Rahul Sagar resolves a core dilemma of executive power in a democracy. He shows how the justification for secrecy and accountability for its misuse both hover outside the normal legal order. Elegant in its symmetry and uncanny in its timing."--Jeffrey K. Tulis, University of Texas at Austin "Rahul Sagar investigates the mirror problems of government secrecy and the leaking of government secrets. There are no easy solutions to these problems, and Sagar doesn\'t pretend there are. Instead, he provides a rigorous, judicious, and clear-eyed analysis of the tradeoffs that policymakers must make, and the uneasy compromises that must be reached. The book comes at a vital time, and is indispensable for current debates about NSA surveillance and related counterterrorism activities."--Eric A. Posner, coauthor of The Executive Unbound "A truly excellent and provocative book. Secrets and Leaks makes an outstanding contribution to an issue of contemporary concern that will not go away--and will probably become far more serious--in the future."--Sanford Levinson, author of Our Undemocratic Constitution "Sagar examines the very hot topic of the role of leaks and whistleblowing in democracy. He argues that they are fundamental to democratic politics generally and American democracy specifically, but he is subtle and informed enough to recognize the dangers of whistleblowing, particularly on matters of national security. Sagar could well launch a new literature on the subject."--Corey Brettschneider, author of When the State Speaks, What Should It Say?',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=f95HDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=f95HDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780691149875', 'type': 'ISBN_13'},
#      {'identifier': '0691149879', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=f95HDwAAQBAJ&dq=Glenn+Greenwald&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 281,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=f95HDwAAQBAJ&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=39&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2013-10-13',
#     'publisher': 'Princeton University Press',
#     'readingModes': {'image': True, 'text': False},
#     'title': 'Who Guards the Guardians - Secrecy in Government'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Going_to_Tehran-sample-epub.acsm?id=86R_pCqS4o0C&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=86R_pCqS4o0C&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'VanD/XIvo4U',
#    'id': '86R_pCqS4o0C',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=86R_pCqS4o0C&rdid=book-86R_pCqS4o0C&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'A bold call for new thinking, the Leveretts&#39; indispensable work makes it clear that America must &quot;go to Tehran&quot; if it is to avert strategic catastrophe.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/86R_pCqS4o0C',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Flynt Leverett', 'Hillary Mann Leverett'],
#     'averageRating': 3.5,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-86R_pCqS4o0C',
#     'categories': ['Political Science'],
#     'contentVersion': '4.5.5.0.preview.2',
#     'description': 'An eye-opening argument for a new approach to Iran, from two of America\'s most informed and influential Middle East experts Less than a decade after Washington endorsed a fraudulent case for invading Iraq, similarly misinformed and politically motivated claims are pushing America toward war with Iran. Today the stakes are even higher: such a war could break the back of America\'s strained superpower status. Challenging the daily clamor of U.S. saber rattling, Flynt and Hillary Mann Leverett argue that America should renounce thirty years of failed strategy and engage with Iran—just as Nixon revolutionized U.S. foreign policy by going to Beijing and realigning relations with China. Former analysts in both the Bush and Clinton administrations, the Leveretts offer a uniquely informed account of Iran as it actually is today, not as many have caricatured it or wished it to be. They show that Iran\'s political order is not on the verge of collapse, that most Iranians still support the Islamic Republic, and that Iran\'s regional influence makes it critical to progress in the Middle East. Drawing on years of research and access to high-level officials, Going to Tehran explains how Iran sees the world and why its approach to foreign policy is hardly the irrational behavior of a rogue nation. A bold call for new thinking, the Leveretts\' indispensable work makes it clear that America must "go to Tehran" if it is to avert strategic catastrophe.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=86R_pCqS4o0C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=86R_pCqS4o0C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781429973342', 'type': 'ISBN_13'},
#      {'identifier': '142997334X', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=86R_pCqS4o0C&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 496,
#     'previewLink': 'http://books.google.com/books?id=86R_pCqS4o0C&printsec=frontcover&dq=Glenn+Greenwald&hl=&cd=40&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2013-01-08',
#     'publisher': 'Metropolitan Books',
#     'ratingsCount': 3,
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': 'Why the United States Must Come to Terms with the Islamic Republic of Iran',
#     'title': 'Going to Tehran'}}],
#  'kind': 'books#volumes',
#  'totalItems': 1757}

# %%
len(json_object['items'])
# Out:
# 40

# %%
for item in json_object['items']:
    print(item['volumeInfo']['title'])
# Out:
# No Place to Hide
# With Liberty and Justice for Some
# How Would a Patriot Act?
# A Tragic Legacy
# The Assassination Complex
# Great American Hypocrites
# Summary of No Place to Hide
# The Snowden Files
# Does State Spying Make Us Safer?
# Pay Any Price
# The Battle for Justice in Palestine
# No Place to Hide
# Shadow Government
# No Place to Hide: A 30-minute Summary of Glenn Greenwald's book
# Overvåget
# The Myth of America's Decline: Politics, Economics, and a Half Century of False Prophecies
# Drug Decriminalization in Portugal
# Traitor
# Quicklet on Glenn Greenwald's With Liberty and Justice for Some (CliffNotes-like Summary)
# Chasing the Scream
# Brazillionaires
# This Muslim American Life
# Twilight of the Elites
# How America Lost Its Secrets
# Summary and Analysis of No Place to Hide: Edward Snowden, the NSA, and the U.S. Surveillance State
# The Israel Lobby and U.S. Foreign Policy
# Nulle part où se cacher
# Power Wars
# Snowden. Sin un lugar donde esconderse
# Mafia State
# The Rhetorical Invention of America's National Security State
# What Kind of Creatures Are We?
# Die globale Überwachung
# Waking Up
# The NSA Report
# The New Nobility
# The Drone Memos
# Afacerea Edward Snowden
# Who Guards the Guardians - Secrecy in Government
# Going to Tehran

# %%
for item in json_object['items']:
    volume_info = item['volumeInfo']
    print('|'.join(volume_info['authors']))
# Out:
# Glenn Greenwald
# Glenn Greenwald
# Glenn Greenwald
# Glenn Greenwald
# Jeremy Scahill|The Staff of the Intercept
# Glenn Greenwald
# Instaread Summaries
# Luke Harding
# Michael Hayden|Alan Dershowitz|Glenn Greenwald|Alexis Ohanian
# James Risen
# Ali Abunimah
# Glenn Greenwald
# Tom Engelhardt
# Instaread Summaries
# Glenn Greenwald
# Josef Joffe
# Glenn Greenwald
# A. Radack Jesselyn
# Danny Fenster
# Johann Hari
# Alex Cuadros
# Moustafa Bayoumi
# Chris Hayes
# Edward Jay Epstein
# Worth Books
# John J. Mearsheimer|Stephen M. Walt
# Glenn Greenwald
# Charlie Savage
# Glenn Greenwald
# Luke Harding
# Marouf Hasian Jr.|Sean Lawson|Megan D. McFarlane
# Noam Chomsky
# Glenn Greenwald
# Sam Harris
# The President's Review Group on Intelligence and Communications Technologies|Richard A. Clarke|Michael J. Morell|Geoffrey R. Stone|Cass R. Sunstein|Peter Swire
# Andrei Soldatov|Irina Borogan
# Jameel Jaffer
# Glenn Greenwald
# Rahul Sagar
# Flynt Leverett|Hillary Mann Leverett

# %%
for item in json_object['items']:
    volume_info = item['volumeInfo']
    try:
        print('|'.join(volume_info['authors']))  
    except:
        print('** No Author **')
# Out:
# Glenn Greenwald
# Glenn Greenwald
# Glenn Greenwald
# Glenn Greenwald
# Jeremy Scahill|The Staff of the Intercept
# Glenn Greenwald
# Instaread Summaries
# Luke Harding
# Michael Hayden|Alan Dershowitz|Glenn Greenwald|Alexis Ohanian
# James Risen
# Ali Abunimah
# Glenn Greenwald
# Tom Engelhardt
# Instaread Summaries
# Glenn Greenwald
# Josef Joffe
# Glenn Greenwald
# A. Radack Jesselyn
# Danny Fenster
# Johann Hari
# Alex Cuadros
# Moustafa Bayoumi
# Chris Hayes
# Edward Jay Epstein
# Worth Books
# John J. Mearsheimer|Stephen M. Walt
# Glenn Greenwald
# Charlie Savage
# Glenn Greenwald
# Luke Harding
# Marouf Hasian Jr.|Sean Lawson|Megan D. McFarlane
# Noam Chomsky
# Glenn Greenwald
# Sam Harris
# The President's Review Group on Intelligence and Communications Technologies|Richard A. Clarke|Michael J. Morell|Geoffrey R. Stone|Cass R. Sunstein|Peter Swire
# Andrei Soldatov|Irina Borogan
# Jameel Jaffer
# Glenn Greenwald
# Rahul Sagar
# Flynt Leverett|Hillary Mann Leverett

# %% [markdown]
# ## Google Books Author Query

# %%
from urllib.request import urlopen
import json

url = 'https://www.googleapis.com/books/v1/volumes?q=inauthor:"Glenn+Greenwald"&maxResults=40'

json_text = urlopen(url).read().decode('utf8')

json_object = json.loads(json_text)

json_object
# Out:
# {'items': [{'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/No_Place_to_Hide-sample-epub.acsm?id=AvFzAgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=AvFzAgAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'jLnCWTVtIVA',
#    'id': 'AvFzAgAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=AvFzAgAAQBAJ&rdid=book-AvFzAgAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Coming at a landmark moment in American history, No Place to Hide is a fearless, incisive, and essential contribution to our understanding of the U.S. surveillance state.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/AvFzAgAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 4.5,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-AvFzAgAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '2.9.9.0.preview.2',
#     'description': "In May 2013, Glenn Greenwald set out for Hong Kong to meet an anonymous source who claimed to have astonishing evidence of pervasive government spying and insisted on communicating only through heavily encrypted channels. That source turned out to be the 29-year-old NSA contractor and whistleblower Edward Snowden, and his revelations about the agency's widespread, systemic overreach proved to be some of the most explosive and consequential news in recent history, triggering a fierce debate over national security and information privacy. As the arguments rage on and the government considers various proposals for reform, it is clear that we have yet to see the full impact of Snowden's disclosures. Now for the first time, Greenwald fits all the pieces together, recounting his high-intensity ten-day trip to Hong Kong, examining the broader implications of the surveillance detailed in his reporting for The Guardian, and revealing fresh information on the NSA's unprecedented abuse of power with never-before-seen documents entrusted to him by Snowden himself. Going beyond NSA specifics, Greenwald also takes on the establishment media, excoriating their habitual avoidance of adversarial reporting on the government and their failure to serve the interests of the people. Finally, he asks what it means both for individuals and for a nation's political health when a government pries so invasively into the private lives of its citizens—and considers what safeguards and forms of oversight are necessary to protect democracy in the digital age. Coming at a landmark moment in American history, No Place to Hide is a fearless, incisive, and essential contribution to our understanding of the U.S. surveillance state.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=AvFzAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=AvFzAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781627790741', 'type': 'ISBN_13'},
#      {'identifier': '1627790748', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=AvFzAgAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 272,
#     'previewLink': 'http://books.google.com/books?id=AvFzAgAAQBAJ&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=1&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-13',
#     'publisher': 'Metropolitan Books',
#     'ratingsCount': 9,
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': 'Edward Snowden, the NSA, and the U.S. Surveillance State',
#     'title': 'No Place to Hide'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=x6vE_fJ4f-IC&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'IFKRD6IQNaQ',
#    'id': 'x6vE_fJ4f-IC',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'A former constitutional law attorney and best-selling author of A Tragic Legacy goes behind the scenes of the right-wing&#39;s pre-election propaganda to expose the fraud behind the image created by the Republican Party for their presidential ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/x6vE_fJ4f-IC',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 5.0,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Great_American_Hypocrites.html?hl=&id=x6vE_fJ4f-IC',
#     'categories': ['Political Science'],
#     'contentVersion': '0.2.1.0.preview.0',
#     'description': "A former constitutional law attorney and best-selling author of A Tragic Legacy goes behind the scenes of the right-wing's pre-election propaganda to expose the fraud behind the image created by the Republican Party for their presidential candidates and to reveal the truth behind the myths and hoaxes they perpetrate. 75,000 first printing.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=x6vE_fJ4f-IC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=x6vE_fJ4f-IC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780307408662', 'type': 'ISBN_13'},
#      {'identifier': '0307408663', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=x6vE_fJ4f-IC&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 290,
#     'previewLink': 'http://books.google.com/books?id=x6vE_fJ4f-IC&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=2&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2008',
#     'publisher': 'Broadway Books',
#     'ratingsCount': 1,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Toppling the Big Myths of Republican Politics',
#     'title': 'Great American Hypocrites'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=7moNPwAACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'GONBYbnOLrc',
#    'id': '7moNPwAACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/7moNPwAACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Drug_Decriminalization_in_Portugal.html?hl=&id=7moNPwAACAAJ',
#     'categories': ['Drug control'],
#     'contentVersion': 'preview-1.0.0',
#     'industryIdentifiers': [{'identifier': 'OCLC:319633482', 'type': 'OTHER'}],
#     'infoLink': 'http://books.google.com/books?id=7moNPwAACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 30,
#     'previewLink': 'http://books.google.com/books?id=7moNPwAACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=3&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2009',
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Lessons for Creating Fair and Successful Drug Policies',
#     'title': 'Drug Decriminalization in Portugal'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=cY0KY9f2-_oC&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'LxsAAgqz6js',
#    'id': 'cY0KY9f2-_oC',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'A critical look at George W. Bush, his administration, and its legacy argues that Bush&#39;s ignorant, black-and-white view of the world, as well as the complex domestic issues of the time, the incompetence of his cronies during hurricane ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/cY0KY9f2-_oC',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 5.0,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/A_Tragic_Legacy.html?hl=&id=cY0KY9f2-_oC',
#     'categories': ['History'],
#     'contentVersion': '0.1.1.0.preview.0',
#     'description': "A critical look at George W. Bush, his administration, and its legacy argues that Bush's ignorant, black-and-white view of the world, as well as the complex domestic issues of the time, the incompetence of his cronies during hurricane Katrina, and the increasing lack of Middle East stability, will have profound implications for the United States and its future. Reprint. 25,000 first printing.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=cY0KY9f2-_oC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=cY0KY9f2-_oC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9780307354280', 'type': 'ISBN_13'},
#      {'identifier': '0307354288', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=cY0KY9f2-_oC&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 321,
#     'previewLink': 'http://books.google.com/books?id=cY0KY9f2-_oC&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=4&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2007',
#     'publisher': 'Broadway Books',
#     'ratingsCount': 2,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'How a Good Vs. Evil Mentality Destroyed the Bush Presidency',
#     'title': 'A Tragic Legacy'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/With_Liberty_and_Justice_for_Some-sample-epub.acsm?id=Je_fc_WjF9oC&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=Je_fc_WjF9oC&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'KSZOfUR0UA0',
#    'id': 'Je_fc_WjF9oC',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=Je_fc_WjF9oC&rdid=book-Je_fc_WjF9oC&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Cogent, sharp, and urgent, this is a no-holds-barred indictment of a profoundly un-American system that sanctions immunity at the top and mercilessness for everyone else.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/Je_fc_WjF9oC',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 4.5,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-Je_fc_WjF9oC',
#     'categories': ['Law'],
#     'contentVersion': '1.3.0.0.preview.2',
#     'description': 'From "the most important voice to have entered the political discourse in years" (Bill Moyers), a scathing critique of the two-tiered system of justice that has emerged in America From the nation\'s beginnings, the law was to be the great equalizer in American life, the guarantor of a common set of rules for all. But over the past four decades, the principle of equality before the law has been effectively abolished. Instead, a two-tiered system of justice ensures that the country\'s political and financial class is virtually immune from prosecution, licensed to act without restraint, while the politically powerless are imprisoned with greater ease and in greater numbers than in any other country in the world. Starting with Watergate, continuing on through the Iran-Contra scandal, and culminating with Obama\'s shielding of Bush-era officials from prosecution, Glenn Greenwald lays bare the mechanisms that have come to shield the elite from accountability. He shows how the media, both political parties, and the courts have abetted a process that has produced torture, war crimes, domestic spying, and financial fraud. Cogent, sharp, and urgent, this is a no-holds-barred indictment of a profoundly un-American system that sanctions immunity at the top and mercilessness for everyone else.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Je_fc_WjF9oC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=Je_fc_WjF9oC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781466805767', 'type': 'ISBN_13'},
#      {'identifier': '1466805765', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=Je_fc_WjF9oC&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 304,
#     'previewLink': 'http://books.google.com/books?id=Je_fc_WjF9oC&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=5&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2011-11-11',
#     'publisher': 'Metropolitan Books',
#     'ratingsCount': 13,
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': 'How the Law Is Used to Destroy Equality and Protect the Powerful',
#     'title': 'With Liberty and Justice for Some'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=1XgaAQAAIAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': '0T+vjGHlWWk',
#    'id': '1XgaAQAAIAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Proposes that a creeping extremism has taken hold of the federal government and, to remain true to America&#39;s founding principles, argues that society must fight against the president&#39;s unlimited and unchecked powers.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/1XgaAQAAIAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 4.0,
#     'canonicalVolumeLink': 'https://books.google.com/books/about/How_Would_a_Patriot_Act.html?hl=&id=1XgaAQAAIAAJ',
#     'categories': ['Political Science'],
#     'contentVersion': 'preview-1.0.0',
#     'description': "Proposes that a creeping extremism has taken hold of the federal government and, to remain true to America's founding principles, argues that society must fight against the president's unlimited and unchecked powers.",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=1XgaAQAAIAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=1XgaAQAAIAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '097794400X', 'type': 'ISBN_10'},
#      {'identifier': '9780977944002', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=1XgaAQAAIAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 128,
#     'previewLink': 'http://books.google.com/books?id=1XgaAQAAIAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=6&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2006',
#     'publisher': 'Working Assets Pub',
#     'ratingsCount': 3,
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Defending American Values from a President Run Amok',
#     'title': 'How Would a Patriot Act?'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Does_State_Spying_Make_Us_Safer-sample-epub.acsm?id=BhOMBQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Does_State_Spying_Make_Us_Safer-sample-pdf.acsm?id=BhOMBQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=BhOMBQAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'NnKzP4NgEFE',
#    'id': 'BhOMBQAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=BhOMBQAAQBAJ&rdid=book-BhOMBQAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 12.95, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 12950000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 9990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 9.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'In this edition of the Munk Debates, former head of the CIA and NSA Michael Hayden and civil liberties lawyer Alan Dershowitz square off against journalist Glenn Greenwald and reddit co-founder Alexis Ohanian to debate the legitimacy of ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/BhOMBQAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Michael Hayden',
#      'Alan Dershowitz',
#      'Glenn Greenwald',
#      'Alexis Ohanian'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-BhOMBQAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.1.1.0.preview.3',
#     'description': 'Does government surveillance make us safer? The thirteenth Munk Debate, held in Toronto on Friday, May 2, 2014, pitted Michael Hayden and Alan Dershowitz against Glenn Greenwald and Alexis Ohanian to debate whether state surveillance is a legitimate defence of our freedom — the democratic issue of the moment. In a risk-filled world, democracies are increasingly turning to large-scale state surveillance, at home and abroad, to fight complex and unconventional threats — but is it justified? For some, the threats more than justify the current surveillance system, and the laws and institutions of democracies are more than capable of balancing the needs of individual privacy with collective security. But for others, we are in peril of sacrificing to a vast and unaccountable state surveillance apparatus the civil liberties that guarantee citizens’ basic freedoms and our democratic way of life. In this edition of the Munk Debates, former head of the CIA and NSA Michael Hayden and civil liberties lawyer Alan Dershowitz square off against journalist Glenn Greenwald and reddit co-founder Alexis Ohanian to debate the legitimacy of state surveillance. With issues of Internet privacy increasingly gaining prominence, the Munk Debate on the Surveillance State asks: Should government be able to monitor our activities in order to keep us safe?',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=BhOMBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=BhOMBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9781770898424', 'type': 'ISBN_13'},
#      {'identifier': '1770898425', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=BhOMBQAAQBAJ&source=gbs_api',
#     'language': 'en',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 128,
#     'previewLink': 'http://books.google.com/books?id=BhOMBQAAQBAJ&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=7&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-11-21',
#     'publisher': 'House of Anansi',
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'The Munk Debate on Mass Surveillance',
#     'title': 'Does State Spying Make Us Safer?'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Overv%C3%A5get-sample-epub.acsm?id=RnRGDQAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Overv%C3%A5get-sample-pdf.acsm?id=RnRGDQAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=RnRGDQAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': '3CBMB/BRkhU',
#    'id': 'RnRGDQAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=RnRGDQAAQBAJ&rdid=book-RnRGDQAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 31.0, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 31000000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 16740000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 16.74, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'I Overvåget fortæller Glenn Greenwald for første gang hele historien om NSA-skandalen og om mødet med Edward Snowden – fra Snowden første gang kontaktede Greenwald og indtrængende opfordrede ham til at installere krypteringssoftware ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/RnRGDQAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-RnRGDQAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.1.1.0.preview.3',
#     'description': 'OVERVÅGET er Glenn Greenwalds længe ventede insiderberetning om hele forløbet omkring Edward Snowdens læk af tophemmelige NSA-dokumenter, der indeholder både nye og uddybende oplysninger om sagen og den amerikanske overvågningsskandale. I Overvåget fortæller Glenn Greenwald for første gang hele historien om NSA-skandalen og om mødet med Edward Snowden – fra Snowden første gang kontaktede Greenwald og indtrængende opfordrede ham til at installere krypteringssoftware, så de kunne kommunikere frit, til de endelig mødes i Hongkong, hvor Greenwald modtager Snowdens arkiv, der afslører omfanget og rækkevidden af USA’s overvågning i detaljer. Greenwald fortæller time for time om de ti nervepirrende dage sammen med whistlebloweren i Hongkong og de intense journalistiske, juridiske og politiske overvejelser han gør sig, og de valg han træffer. Ud over at give et unikt indblik i NSA’s efterretningspraksis og dets politiske og juridiske konsekvenser, udstiller Glenn Greenwald den brede amerikanske medieoffentligheds ukritiske og følgagtige forhold til den amerikanske statsmagt og de radikale konsekvenser for den journalistiske og politiske frihed, som den tætte relation mellem medierne og magten har.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=RnRGDQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=RnRGDQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9788775148875', 'type': 'ISBN_13'},
#      {'identifier': '8775148870', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=RnRGDQAAQBAJ&source=gbs_api',
#     'language': 'da',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 298,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=RnRGDQAAQBAJ&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=8&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-10-27',
#     'publisher': 'Informations Forlag',
#     'readingModes': {'image': True, 'text': True},
#     'title': 'Overvåget'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Nulle_part_o%C3%B9_se_cacher-sample-epub.acsm?id=3hKiBAAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=3hKiBAAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'NzVHE8cKxtg',
#    'id': '3hKiBAAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=3hKiBAAAQBAJ&rdid=book-3hKiBAAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 17.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 17990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 17990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 17.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Glenn Greenwald est le seul, avec Edward Snowden, à disposer de la totalité des documents de l’affaire dont une faible partie a déjà été publiée.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/3hKiBAAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-3hKiBAAAQBAJ',
#     'categories': ['Social Science'],
#     'contentVersion': 'preview-1.0.0',
#     'description': "Sortie mondiale simultanée dans 20 pays La plus grosse fuite de l'histoire de l'espionnage Des nouvelles révélations sur les techniques de la N.S.A pour surveiller les sphères publiques et privées du monde entier et de la France en particulier. Glenn Greenwald est le seul, avec Edward Snowden, à disposer de la totalité des documents de l’affaire dont une faible partie a déjà été publiée. L’histoire au jour le jour de ce que l’on appelle dorénavant « l’affaire Snowden ». Traduit de l'anglais par Johan-Frederik Hel Guedj",
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=3hKiBAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=3hKiBAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9782709646413', 'type': 'ISBN_13'},
#      {'identifier': '2709646412', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=3hKiBAAAQBAJ&source=gbs_api',
#     'language': 'fr',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 280,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=3hKiBAAAQBAJ&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=9&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-14',
#     'publisher': 'JC Lattès',
#     'readingModes': {'image': False, 'text': True},
#     'title': 'Nulle part où se cacher'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=PQTxoAEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'ZjrFecomAUM',
#    'id': 'PQTxoAEACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'The book is the winner of the 2014 Pulitzer Prize for Public Service. In Traditional Chinese. Annotation copyright Tsai Fong Books, Inc. Distributed by Tsai Fong Books, Inc.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/PQTxoAEACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/%E6%94%BF%E5%BA%9C%E6%AD%A3%E5%9C%A8%E7%9B%A3%E6%8E%A7%E4%BD%A0.html?hl=&id=PQTxoAEACAAJ',
#     'categories': ['Political Science'],
#     'contentVersion': 'preview-1.0.0',
#     'description': 'A simultaneous Traditional Chinese translation of the much talked about book No Place to Hide: Edward Snowden, the NSA, and the U.S. Surveillance State by Glenn Greenwald. The book is the winner of the 2014 Pulitzer Prize for Public Service. In Traditional Chinese. Annotation copyright Tsai Fong Books, Inc. Distributed by Tsai Fong Books, Inc.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=PQTxoAEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=PQTxoAEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9571359653', 'type': 'ISBN_10'},
#      {'identifier': '9789571359656', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=PQTxoAEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'zh-TW',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 320,
#     'previewLink': 'http://books.google.com/books?id=PQTxoAEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=10&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-13',
#     'publisher': 'Shi Bao Chu Ban/Tsai Fong Books',
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': '史諾登揭密',
#     'title': '政府正在監控你'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Snowden_Sin_un_lugar_donde_esconderse-sample-epub.acsm?id=XUOlAwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Snowden_Sin_un_lugar_donde_esconderse-sample-pdf.acsm?id=XUOlAwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED_FOR_ACCESSIBILITY',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=XUOlAwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'uff+mlHbkjM',
#    'id': 'XUOlAwAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=XUOlAwAAQBAJ&rdid=book-XUOlAwAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 6.99, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 6990000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 6990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 6.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Edward Snowden, la NSA y el estado de vigilancia de EE.UU. En mayo de 2013, Glenn Greenwald partió rumbo a Hong Kong para reunirse con una fuente anónima que afirmaba tener pruebas pasmosas de espionaje gubernamental generalizado e ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/XUOlAwAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-XUOlAwAAQBAJ',
#     'categories': ['Biography & Autobiography'],
#     'contentVersion': '1.6.7.0.preview.3',
#     'description': 'Edward Snowden, la NSA y el estado de vigilancia de EE.UU. En mayo de 2013, Glenn Greenwald partió rumbo a Hong Kong para reunirse con una fuente anónima que afirmaba tener pruebas pasmosas de espionaje gubernamental generalizado e insistía en comunicarse sólo mediante canales muy encriptados. La fuente resultó ser Edward Snowden, contratista de la NSA de veintinueve años, cuyas revelaciones sobre las extendidas y sistémicas actuaciones de la agencia demostraron ser una de las noticias más explosivas y trascendentales de la historia reciente, lo que desencadenó un encarnizado debate sobre la seguridad nacional y la privacidad en la información. Mientras las discusiones suben de tono y el gobierno estadounidense contempla diversas propuestas de reforma, está claro que aún no sabemos cuál será el verdadero impacto de las revelaciones de Snowden. Ahora, Greenwald encaja por primera vez todas las piezas: relata su intensísimo viaje de once días a Hong Kong, analiza las numerosas implicaciones de la vigilancia detalladas en sus reportajes en The Guardian, y saca a la luz nueva información sobre el abuso de poder sin precedentes de la NSA con documentos inéditos que le confiara el propio Snowden. Más allá de los pormenores de la NSA, Greenwald también se enfrenta en este libro al estamento mediático, criticando duramente que evite como norma las coberturas informativas que puedan generar algún tipo de confrontación con el gobierno y no se ponga al servicio del interés público. También se pregunta qué significa, tanto para los individuos como para la salud política de un país, el que un gobierno se inmiscuya de forma tan invasiva en la vida privada de sus ciudadanos, y se plantea qué salvaguardas y formas de supervisión hacen falta para proteger la democracia en la era digital. En un momento clave de la historia norteamericana, Snowden. Sin un lugar donde esconderse es una aportación audaz, incisiva, esencial, a nuestro conocimiento del estado de vigilancia de EE UU. Reseña: «Quizá el más influyente escritor sobre las libertades civiles en la Red.» American Prospect',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=XUOlAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=XUOlAwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9788490197592', 'type': 'ISBN_13'},
#      {'identifier': '8490197598', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=XUOlAwAAQBAJ&source=gbs_api',
#     'language': 'es',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 320,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=XUOlAwAAQBAJ&pg=PP1&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=11&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-21',
#     'publisher': 'B DE BOOKS',
#     'readingModes': {'image': True, 'text': True},
#     'title': 'Snowden. Sin un lugar donde esconderse'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/De_afluisterstaat-sample-epub.acsm?id=ygsPAwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/De_afluisterstaat-sample-pdf.acsm?id=ygsPAwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=ygsPAwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'FymZgzXLlFA',
#    'id': 'ygsPAwAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'De afluisterstaat verschijnt op een keerpunt in de wereldgeschiedenis. Het is een onbevreesde, scherpzinnige en essentiele bijdrage aan ons begrip van de Amerikaanse toezichtsstaat. Glenn Greenwald is journalist en schrijver.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/ygsPAwAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/De_afluisterstaat.html?hl=&id=ygsPAwAAQBAJ',
#     'categories': ['Biography & Autobiography'],
#     'contentVersion': '0.6.7.0.preview.3',
#     'description': 'In mei 2013 vertrok Glenn Greenwald naar Hong Kong om een anonieme bron te ontmoeten die claimde in het bezit te zijn van overweldigend bewijs voor vergaande overheidsspionage. Die bron bleek de 29-jarige nsa-systeembeheerder Edward Snowden. Zijn onthullingen over het wijdverbreide en systematische misbruik van gegevens behoren tot het meest explosieve en omvangrijke nieuws in de recente geschiedenis en leidden wereldwijd tot een hevig debat over nationale veiligheid en privacy van burgers. In dit boek verbindt Greenwald voor het eerst alle stukjes van de puzzel. Hij vertelt over zijn zeer intensieve trip naar Hong Kong, onderzoekt de bredere implicaties van de surveillance waarover hij rapporteerde in The Guardian en brengt nieuwe informatie over het ongekende machtsmisbruik van de nsa naar voren, met niet eerder verschenen documenten, aan hem toevertrouwd door Snowden zelf. Naast de nsa pakt Greenwald ook de gevestigde media aan. Hij keert zich fel tegen hun gewoonte overheidskritische reportages niet te publiceren en hun onvermogen de belangen van de gewone mens te dienen. Tot slot vraagt hij zich af wat het voor de individuele en nationale politieke gezondheid betekent wanneer een overheid zo intensief de privélevens van burgers monitort, en laat zien welke maatregelen getroffen moeten worden om democratie in het digitale tijdperk te waarborgen. De afluisterstaat verschijnt op een keerpunt in de wereldgeschiedenis. Het is een onbevreesde, scherpzinnige en essentiele bijdrage aan ons begrip van de Amerikaanse toezichtsstaat. Glenn Greenwald is journalist en schrijver. Hij was tot oktober 2013 columnist van The Guardian, de krant die in 2014 een Pulitzerprijs won dankzij Greenwalds reportages en artikelen over de afluisterpraktijken van de nsa. Greenwalds stukken verschenen in vele kranten en politieke tijdschriften, waaronder The New York Times, The Los Angeles Times en de American Conservative. In februari 2014 startte hij een nieuwe mediagroep, First Look Media.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=ygsPAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=ygsPAwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9789048819416', 'type': 'ISBN_13'},
#      {'identifier': '9048819415', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=ygsPAwAAQBAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'nl',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 219,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=ygsPAwAAQBAJ&printsec=frontcover&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=12&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-03-15',
#     'publisher': 'Overamstel Uitgevers',
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'Edward Snowden, de NSA en de Amerikaanse spionage- en afluisterdiensten',
#     'title': 'De afluisterstaat'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=Tsr2oQEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'wJS5sUhLrnk',
#    'id': 'Tsr2oQEACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/Tsr2oQEACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Die_globale_%C3%9Cberwachung.html?hl=&id=Tsr2oQEACAAJ',
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=Tsr2oQEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=Tsr2oQEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '3426786915', 'type': 'ISBN_10'},
#      {'identifier': '9783426786918', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=Tsr2oQEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'de',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 384,
#     'previewLink': 'http://books.google.com/books?id=Tsr2oQEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=13&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2015-09-01',
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'Der Fall Snowden, die amerikanischen Geheimdienste und die Folgen',
#     'title': 'Die globale Überwachung'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Afacerea_Edward_Snowden-sample-epub.acsm?id=na5TCgAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Afacerea_Edward_Snowden-sample-pdf.acsm?id=na5TCgAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=na5TCgAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'QMQu/1MQsLo',
#    'id': 'na5TCgAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=na5TCgAAQBAJ&rdid=book-na5TCgAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 8.32, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 8320000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 6990000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 6.99, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Internetul democratizează discursul politic şi echilibrează balanţa între cei puternici şi cei slabi, iar libertatea lui – posibilitatea de a folosi reţeaua fără constrângeri instituţionale și sociale sau fără controlul ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/na5TCgAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-na5TCgAAQBAJ',
#     'categories': ['Political Science'],
#     'contentVersion': '1.4.6.0.preview.3',
#     'description': 'Internetul democratizează discursul politic şi echilibrează balanţa între cei puternici şi cei slabi, iar libertatea lui – posibilitatea de a folosi reţeaua fără constrângeri instituţionale și sociale sau fără controlul statului şi fără o teamă permanentă – este esențială. Convertirea internetului într-un sistem de supraveghere îl privează astfel de potenţialul său, îl transformă într-un instrument de represiune, ameninţând să producă arma cea mai opresivă şi extremă a intruziunii statului din istorie. De aceea uluitoarele dezvăluiri ale lui Snowden sunt atât de importante. Ele au concentrat atenţia lumii asupra pericolelor supravegherii omniprezente din partea statului, au generat prima dezbatere globală despre valoarea vieţii private în epoca digitală şi au determinat contestarea controlului hegemonic al Americii asupra internetului. Au schimbat modul în care oamenii au văzut autenticitatea oricărei declaraţii făcute de oficialii SUA şi au transformat relaţiile între ţări. Au modificat radical viziunile despre rolul adecvat al jurnalismului în relaţia cu puterea guvernamentală. Îndrăznind să expună surprinzătoarele capacităţi de supraveghere ale NSA, Snowden a clarificat că ne aflăm la o răscruce de drumuri. Va fi era digitală un precursor al libertăţii individuale şi al libertăţilor politice pe care internetul este singurul capabil să le elibereze? Sau va aduce un sistem de monitorizare şi control omniprezent, dincolo de visurile celor mai mari tirani din trecut? Acţiunile noastre vor stabili încotro ne vom îndrepta.',
# ...
#     'infoLink': 'http://books.google.com/books?id=jgW2jwEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'de',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 127,
#     'previewLink': 'http://books.google.com/books?id=jgW2jwEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=15&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014',
#     'readingModes': {'image': False, 'text': False},
#     'title': 'NSA: Die Schere im Kopf'}},
#   {'accessInfo': {'accessViewStatus': 'SAMPLE',
#     'country': 'US',
#     'embeddable': True,
#     'epub': {'acsTokenLink': 'http://books.google.com/books/download/Sem_lugar_para_se_esconder-sample-epub.acsm?id=WIFoAwAAQBAJ&format=epub&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'pdf': {'acsTokenLink': 'http://books.google.com/books/download/Sem_lugar_para_se_esconder-sample-pdf.acsm?id=WIFoAwAAQBAJ&format=pdf&output=acs4_fulfillment_token&dl_type=sample&source=gbs_api',
#      'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'PARTIAL',
#     'webReaderLink': 'http://play.google.com/books/reader?id=WIFoAwAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'dm7EmbSNX28',
#    'id': 'WIFoAwAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'buyLink': 'https://play.google.com/store/books/details?id=WIFoAwAAQBAJ&rdid=book-WIFoAwAAQBAJ&rdot=1&source=gbs_api',
#     'country': 'US',
#     'isEbook': True,
#     'listPrice': {'amount': 7.82, 'currencyCode': 'USD'},
#     'offers': [{'finskyOfferType': 1,
#       'giftable': True,
#       'listPrice': {'amountInMicros': 7820000.0, 'currencyCode': 'USD'},
#       'retailPrice': {'amountInMicros': 6020000.0, 'currencyCode': 'USD'}}],
#     'retailPrice': {'amount': 6.02, 'currencyCode': 'USD'},
#     'saleability': 'FOR_SALE'},
#    'searchInfo': {'textSnippet': 'As reportagens, assinadas pelo ex-advogado e jornalista Glenn Greenwald, revelaram ao mundo que a inteligência do país estava espionando em larga escala não só as comunicações domésticas, mas também as de outros países, inclusive ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/WIFoAwAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': True,
#     'authors': ['Glenn Greenwald'],
#     'averageRating': 5.0,
#     'canonicalVolumeLink': 'https://market.android.com/details?id=book-WIFoAwAAQBAJ',
#     'categories': ['True Crime'],
#     'contentVersion': '1.13.13.0.preview.3',
#     'description': 'Em meados de 2013, o jornal britânico The Guardian publicou uma série de matérias que desvendavam a vigilância ilimitada praticada pela NSA, a Agência de Segurança Nacional norte-americana. As reportagens, assinadas pelo ex-advogado e jornalista Glenn Greenwald, revelaram ao mundo que a inteligência do país estava espionando em larga escala não só as comunicações domésticas, mas também as de outros países, inclusive os aliados. As denúncias suscitaram um longo debate global, ainda em curso, sobre o direito à privacidade e o alcance da vigilância governamental. Neste livro, Greenwald conta, desde o início, como foi escolhido por Edward Snowden para ser o receptor dos dados confidenciais que formaram o escopo de seu trabalho jornalístico. Além de falar sobre o período que passou com Snowden, ex-prestador de serviços da NSA que se tornou um dos delatores mais célebres da história moderna, o autor reflete sobre o papel que a mídia desempenha no jornalismo atual, alinhando-se aos interesses dos governos em detrimento dos cidadãos. Trata também das consequências, para a democracia, de um programa de supervisão ininterrupta e irrestrita de pessoas, empresas e governos. Greenwald ainda revela novas informações sobre o abuso de poder da NSA e propõe medidas para conter o alcance aparentemente inflexível dos aparatos de vigilância norte-americanos.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=WIFoAwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=WIFoAwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9788543100968', 'type': 'ISBN_13'},
#      {'identifier': '8543100968', 'type': 'ISBN_10'}],
#     'infoLink': 'https://play.google.com/store/books/details?id=WIFoAwAAQBAJ&source=gbs_api',
#     'language': 'pt',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 288,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=WIFoAwAAQBAJ&pg=PP1&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=16&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-14',
#     'publisher': 'Sextante',
#     'ratingsCount': 1,
#     'readingModes': {'image': True, 'text': True},
#     'subtitle': 'Edward Snowden, a NSA e a espionagem do governo americano',
#     'title': 'Sem lugar para se esconder'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=LzycngEACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'n4ncJGEnadg',
#    'id': 'LzycngEACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'El periodista de investigación de The Guardian y autor superventas Glenn Greenwald, ofrece una mirada en profundidad sobre el escándalo de la NSA que ha provocado un gran debate sobre la seguridad nacional y la privacidad de la ...'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/LzycngEACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Sin_un_lugar_donde_esconderse_No_Place_t.html?hl=&id=LzycngEACAAJ',
#     'categories': ['Political Science'],
#     'contentVersion': 'preview-1.0.0',
#     'description': 'El periodista de investigación de The Guardian y autor superventas Glenn Greenwald, ofrece una mirada en profundidad sobre el escándalo de la NSA que ha provocado un gran debate sobre la seguridad nacional y la privacidad de la información. Con nuevas rev',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=LzycngEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=LzycngEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '8466654593', 'type': 'ISBN_10'},
#      {'identifier': '9788466654593', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=LzycngEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'es',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 313,
#     'previewLink': 'http://books.google.com/books?id=LzycngEACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=17&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2014-05-30',
#     'readingModes': {'image': False, 'text': False},
#     'title': 'Sin un lugar donde esconderse / No Place to Hide'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=jPEZMQAACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'MNB8/rNY6kg',
#    'id': 'jPEZMQAACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/jPEZMQAACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/No_place_to_hide_Edward_Snowden_e_la_sor.html?hl=&id=jPEZMQAACAAJ',
#     'categories': ['Political Science'],
#     'contentVersion': 'preview-1.0.0',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=jPEZMQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=jPEZMQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '8817091456', 'type': 'ISBN_10'},
#      {'identifier': '9788817091459', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=jPEZMQAACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'it',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 373,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=jPEZMQAACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=18&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016',
#     'readingModes': {'image': False, 'text': False},
#     'title': 'No place to hide. Edward Snowden e la sorveglianza di massa'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': True},
#     'pdf': {'isAvailable': True},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=O9eqDQAAQBAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': 'eR+H+jwS3XI',
#    'id': 'O9eqDQAAQBAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/O9eqDQAAQBAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['Glenn Greenwald'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/Sotto_controllo.html?hl=&id=O9eqDQAAQBAJ',
#     'categories': ['True Crime'],
#     'contentVersion': '1.1.1.0.preview.2',
#     'description': 'Il 1° dicembre 2012 Glenn Greenwald, giornalista americano in prima fila nella difesa delle libertà civili, riceve un’email da un certo “Cincinnatus” per un passaggio di informazioni riservate. Qualche mese più tardi quelle “informazioni” sconvolgeranno la politica mondiale, inonderanno telegiornali, quotidiani, siti internet, chiameranno in causa colossi come Google e Facebook, scuoteranno le relazioni tra gli Stati Uniti e i loro alleati: “Cincinnatus”, infatti, è Edward Snowden, il giovane informatico che ha lavorato per la CIA e la NSA, l’Agenzia per la Sicurezza Nazionale, e ha deciso di rischiare la vita per rivelare il più gigantesco programma di sorveglianza di massa mai realizzato. In questo libro Greenwald racconta come in un thriller i primi contatti e l’incontro con Snowden; la serie di scoop con cui il “Guardian” ha pubblicato le carte della NSA; la fuga di Snowden a Mosca; i metodi usati dalla NSA per accedere a cellulari e computer in tutto il mondo; le spaventose implicazioni di quel “sistema finalizzato alla totale eliminazione della riservatezza telematica in tutto il pianeta”. Il più grande caso di spionaggio mondiale degli ultimi anni, una storia sconvolgente che riguarda la sicurezza di tutti noi.',
#     'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=O9eqDQAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api',
#      'thumbnail': 'http://books.google.com/books/content?id=O9eqDQAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'},
#     'industryIdentifiers': [{'identifier': '9788858686782', 'type': 'ISBN_13'},
#      {'identifier': '8858686780', 'type': 'ISBN_10'}],
#     'infoLink': 'http://books.google.com/books?id=O9eqDQAAQBAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'it',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 384,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=O9eqDQAAQBAJ&pg=PP1&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=19&source=gbs_api',
#     'printType': 'BOOK',
#     'publishedDate': '2016-11-24T00:00:00+01:00',
#     'publisher': 'Bur',
#     'readingModes': {'image': False, 'text': True},
#     'subtitle': 'No place to Hide. Edward Snowden e la sorveglianza di massa',
#     'title': 'Sotto controllo'}},
#   {'accessInfo': {'accessViewStatus': 'NONE',
#     'country': 'US',
#     'embeddable': False,
#     'epub': {'isAvailable': False},
#     'pdf': {'isAvailable': False},
#     'publicDomain': False,
#     'quoteSharingAllowed': False,
#     'textToSpeechPermission': 'ALLOWED',
#     'viewability': 'NO_PAGES',
#     'webReaderLink': 'http://play.google.com/books/reader?id=0KYXvgAACAAJ&hl=&printsec=frontcover&source=gbs_api'},
#    'etag': '822X/gQtymw',
#    'id': '0KYXvgAACAAJ',
#    'kind': 'books#volume',
#    'saleInfo': {'country': 'US',
#     'isEbook': False,
#     'saleability': 'NOT_FOR_SALE'},
#    'searchInfo': {'textSnippet': 'Greenwald ainda revela novas informações sobre o abuso de poder da NSA e propõe medidas para conter o alcance aparentemente inflexível dos aparatos de vigilância norte-americanos.'},
#    'selfLink': 'https://www.googleapis.com/books/v1/volumes/0KYXvgAACAAJ',
#    'volumeInfo': {'allowAnonLogging': False,
#     'authors': ['GLENN GREENWALD', 'FERNANDA ABREU'],
#     'canonicalVolumeLink': 'https://books.google.com/books/about/SEM_LUGAR_PARA_SE_ESCONDER_EDWARD_SNOWDE.html?hl=&id=0KYXvgAACAAJ',
#     'contentVersion': 'preview-1.0.0',
#     'description': 'Em meados de 2013, o jornal britânico The Guardian publicou uma série de matérias que desvendavam a vigilância ilimitada praticada pela NSA, a Agência de Segurança Nacional norte-americana. As reportagens, assinadas pelo ex-advogado e jornalista Glenn Greenwald, revelaram ao mundo que a inteligência do país estava espionando em larga escala não só as comunicações domésticas, mas também as de outros países, inclusive os aliados. As denúncias suscitaram um longo debate global, ainda em curso, sobre o direito à privacidade e o alcance da vigilância governamental. Neste livro, Greenwald conta, desde o início, como foi escolhido por Edward Snowden para ser o receptor dos dados confidenciais que formaram o escopo de seu trabalho jornalístico. Além de falar sobre o período que passou com Snowden, ex-prestador de serviços da NSA que se tornou um dos delatores mais célebres da história moderna, o autor reflete sobre o papel que a mídia desempenha no jornalismo atual, alinhando-se aos interesses dos governos em detrimento dos cidadãos. Trata também das consequências, para a democracia, de um programa de supervisão ininterrupta e irrestrita de pessoas, empresas e governos. Greenwald ainda revela novas informações sobre o abuso de poder da NSA e propõe medidas para conter o alcance aparentemente inflexível dos aparatos de vigilância norte-americanos.',
#     'industryIdentifiers': [{'identifier': '854310095X', 'type': 'ISBN_10'},
#      {'identifier': '9788543100951', 'type': 'ISBN_13'}],
#     'infoLink': 'http://books.google.com/books?id=0KYXvgAACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&source=gbs_api',
#     'language': 'pt',
#     'maturityRating': 'NOT_MATURE',
#     'pageCount': 288,
#     'panelizationSummary': {'containsEpubBubbles': False,
#      'containsImageBubbles': False},
#     'previewLink': 'http://books.google.com/books?id=0KYXvgAACAAJ&dq=inauthor:%22Glenn+Greenwald%22&hl=&cd=20&source=gbs_api',
#     'printType': 'BOOK',
#     'readingModes': {'image': False, 'text': False},
#     'subtitle': 'E A ESPIONAGEM DO GOVERNO AMERICANO',
#     'title': 'SEM LUGAR PARA SE ESCONDER - EDWARD SNOWDEN, A NSA'}}],
#  'kind': 'books#volumes',
#  'totalItems': 20}

# %%
for item in json_object['items']:
    volume_info = item['volumeInfo']
    print(volume_info['title'])
    try:
        print('|'.join(volume_info['authors']))
    except:
        print('')
    print()
# Out:
# No Place to Hide
# Glenn Greenwald
#
# Great American Hypocrites
# Glenn Greenwald
#
# Drug Decriminalization in Portugal
# Glenn Greenwald
#
# A Tragic Legacy
# Glenn Greenwald
#
# With Liberty and Justice for Some
# Glenn Greenwald
#
# How Would a Patriot Act?
# Glenn Greenwald
#
# Does State Spying Make Us Safer?
# Michael Hayden|Alan Dershowitz|Glenn Greenwald|Alexis Ohanian
#
# Overvåget
# Glenn Greenwald
#
# Nulle part où se cacher
# Glenn Greenwald
#
# 政府正在監控你
# Glenn Greenwald
#
# Snowden. Sin un lugar donde esconderse
# Glenn Greenwald
#
# De afluisterstaat
# Glenn Greenwald
#
# Die globale Überwachung
# Glenn Greenwald
#
# Afacerea Edward Snowden
# Glenn Greenwald
#
# NSA: Die Schere im Kopf
#
#
# Sem lugar para se esconder
# Glenn Greenwald
#
# Sin un lugar donde esconderse / No Place to Hide
# Glenn Greenwald
#
# No place to hide. Edward Snowden e la sorveglianza di massa
# Glenn Greenwald
#
# Sotto controllo
# Glenn Greenwald
#
# SEM LUGAR PARA SE ESCONDER - EDWARD SNOWDEN, A NSA
# GLENN GREENWALD|FERNANDA ABREU

# %% [markdown]
# ## *Assignment:*
#
# 1. Create a list of authors.
#
# 2. Query the Google Books API for each author in the list.
#
# 3. Extract several metadata fields for each book and add them all to a single list of lists.
#
# 4. Write the list of lists to a CSV file.
