# %% [markdown]
# This code is an adapation for this class from the ["Applied Archival Downloading with Wget"](https://programminghistorian.org/lessons/applied-archival-downloading-with-wget) lesson in Programming Historian by Kellen Kurschinski.

# %% [markdown]
# This code will go in your .py file.

# %%
urls = '';
f=open('urls.txt','w')
for x in range(8029, 8110):
    urls = 'http://data2.collectionscanada.ca/e/e061/e00151%d.jpg\n' % (x)
    f.write(urls)
f.close

# %% [markdown]
# The above code is similar to the code you would put in your Jupyter Notebook to produce a list of URLs. It will produce the URLs, but you don't have it in a text file that you can pull into your code. So, for this assignment, it would be easier to make a separate .py file.

# %%
urls = '';
for x in range(8029, 8110):
    urls = 'http://data2.collectionscanada.ca/e/e061/e00151%d.jpg\n' % (x)
    print(urls)
# Out:
# http://data2.collectionscanada.ca/e/e061/e001518029.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518030.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518031.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518032.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518033.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518034.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518035.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518036.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518037.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518038.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518039.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518040.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518041.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518042.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518043.jpg
#
# http://data2.collectionscanada.ca/e/e061/e001518044.jpg
#
# ...

# %%
# !wget -N -i urls.txt -r --no-parent -nd -w 2 --limit-rate=100k
# Out:
# --2018-02-09 00:48:42--  http://data2.collectionscanada.ca/e/e061/e001518029.jpg
# Resolving data2.collectionscanada.ca (data2.collectionscanada.ca)... 142.78.200.71
# Connecting to data2.collectionscanada.ca (data2.collectionscanada.ca)|142.78.200.71|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 121153 (118K) [image/jpeg]
# Saving to: ‘e001518029.jpg’
#
# e001518029.jpg      100%[===================>] 118.31K  67.7KB/s    in 1.7s
#
# 2018-02-09 00:48:45 (67.7 KB/s) - ‘e001518029.jpg’ saved [121153/121153]
#
# --2018-02-09 00:48:47--  http://data2.collectionscanada.ca/e/e061/e001518030.jpg
# Reusing existing connection to data2.collectionscanada.ca:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 186782 (182K) [image/jpeg]
# Saving to: ‘e001518030.jpg’
#
# e001518030.jpg      100%[===================>] 182.40K   106KB/s    in 1.7s
#
# 2018-02-09 00:48:49 (106 KB/s) - ‘e001518030.jpg’ saved [186782/186782]
#
# ...
