# %% [markdown]
# Sample datasets from The Museum of Modern Art (MoMA) [via GitHub](https://github.com/MuseumofModernArt/collection).
#
# The files on MOMA are updated all the time and are now HUGE so I have provided more workable versions on Canvas for you to download in the artists_artworks.zip file:
# https://utexas.instructure.com/courses/1216881/files/folder/Week_8
#
# Unzip and download these files to your /sharedfolder/ on your desktop.
#
# If you want to revisit this assignment with the actual MOMA files, you can get them here:
# - [Artists.csv](https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artists.csv)
# - [Artworks.csv](https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.csv)

# %% [markdown]
# ###  Artists Data

# %%
import csv

artist_csv_path = "/sharedfolder/Artists.csv"
artist_table = []

with open(artist_csv_path) as fi:
    csv_input = csv.reader(fi)
    for row in csv_input:
        artist_table.append(row)

artist_header = artist_table[0]
artist_table.remove(artist_table[0])

artist_header
# Out:
# ['\ufeffConstituentID',
#  'DisplayName',
#  'ArtistBio',
#  'Nationality',
#  'Gender',
#  'BeginDate',
#  'EndDate',
#  'Wiki QID',
#  'ULAN']

# %% [markdown]
# Now, check the length of the table, then enter an index value in brackets to look at an entry.

# %%
print(len(artist_table))

artist_table[6310]
# Out:
# 15228
# ['7019',
#  'Rudolph Von Ripper',
#  'American, 1905–1960',
#  'American',
#  'Male',
#  '1905',
#  '1960',
#  '',
#  '']

# %% [markdown]
# We’ve just copied all the data from a CSV-formatted spreadsheet and turned it into a format Python can easily work with: a list of lists of strings. Let’s walk through the above a step at a time, this time loading MoMA’s artwork metadata.
#
# We began by importing the `csv` module, Python’s built-in CSV input/output tool. `import csv`

# %% [markdown]
# ### Artworks Data

# %% [markdown]
# Next we assign our pathname to the `artwork_path` variable and initialize an empty list called `artwork_table`.
#
# This will become our *list of lists*, Python’s version of a table.

# %%
artwork_csv_path = "/sharedfolder/Artworks.csv"
artwork_table = []

# %% [markdown]
# Then we create a file stream object `fi` that points to our spreadsheet, We pass our file object to `csv`’s constructor function and assign the new reader object to `csv_file`. Finally, using a for loop, we iterate through our csv object and add each row (represented by a list) to the master list `artwork_table`.

# %%
with open(artwork_csv_path) as fi:
    csv_file = csv.reader(fi)
    for row in csv_file:
        artwork_table.append(row)

# %% [markdown]
# Because this table uses column labels in the first row, we’ll save those labels to the variable `header` and remove it from the table.

# %%
artwork_header = artwork_table[0]
artwork_table.remove(artwork_table[0])

# %% [markdown]
# Finally, let’s look at our list of column titles …

# %%
artwork_header
# Out:
# ['\ufeffTitle',
#  'Artist',
#  'ConstituentID',
#  'ArtistBio',
#  'Nationality',
#  'BeginDate',
#  'EndDate',
#  'Gender',
#  'Date',
#  'Medium',
#  'Dimensions',
#  'CreditLine',
#  'AccessionNumber',
#  'Classification',
#  'Department',
#  'DateAcquired',
#  'Cataloged',
#  'ObjectID',
#  'URL',
#  'ThumbnailURL',
#  'Circumference (cm)',
#  'Depth (cm)',
#  'Diameter (cm)',
#  'Height (cm)',
#  'Length (cm)',
#  'Weight (kg)',
#  'Width (cm)',
#  'Seat Height (cm)',
#  'Duration (sec.)']

# %% [markdown]
# … as well as a row in our table.

# %%
artwork_table[60946]
# Out:
# ['Youth',
#  'Louise Bourgeois',
#  '710',
#  '(American, born France. 1911–2010)',
#  '(American)',
#  '(1911)',
#  '(2010)',
#  '(Female)',
#  '1941-1944',
#  'Etching, drypoint, and aquatint',
#  'plate: 5 1/16 x 7 9/16" (12.9 x 19.2 cm); sheet: 9 1/16 x 12 9/16" (23 x 31.9 cm)',
#  'Gift of the artist',
#  '237.1992.10',
#  'Print',
#  'Prints & Illustrated Books',
#  '1992-05-20',
#  'Y',
#  '64962',
#  'http://www.moma.org/collection/works/64962',
#  'http://www.moma.org/media/W1siZiIsIjE2NjUxNyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=8697b75874b02a22',
#  '',
#  '',
#  '',
#  '12.9',
#  '',
#  '',
#  '19.2',
#  '',
#  '']

# %% [markdown]
#  **Tip:** Python will ignore any text following the “#” character on a line, which we can use to add explanatory comments within our code. Here are a couple lines from the snippet above followed by example notes.

# %% [markdown]
# #### Quick Assignment 1
# Write a piece of code that prints each column label in `artist_header` and `artwork_header` next to its index in the list, beginning from zero as usual. You may want to keep this reference handy for the next few exercises.

# %%
print('Artists\n')

for i in range(len(artist_header)):
    print(str(i) + ' ' + artist_header[i])

print('\nArtworks\n')

for i in range(len(artwork_header)):
    print(str(i) + ' ' + artwork_header[i])
# Out:
# Artists
#
# 0 ﻿ConstituentID
# 1 DisplayName
# 2 ArtistBio
# 3 Nationality
# 4 Gender
# 5 BeginDate
# 6 EndDate
# 7 Wiki QID
# 8 ULAN
#
# Artworks
#
# 0 ﻿Title
# 1 Artist
# 2 ConstituentID
# 3 ArtistBio
# 4 Nationality
# 5 BeginDate
# 6 EndDate
# 7 Gender
# 8 Date
# 9 Medium
# 10 Dimensions
# 11 CreditLine
# 12 AccessionNumber
# 13 Classification
# 14 Department
# 15 DateAcquired
# 16 Cataloged
# 17 ObjectID
# 18 URL
# 19 ThumbnailURL
# 20 Circumference (cm)
# 21 Depth (cm)
# 22 Diameter (cm)
# 23 Height (cm)
# 24 Length (cm)
# 25 Weight (kg)
# 26 Width (cm)
# 27 Seat Height (cm)
# 28 Duration (sec.)

# %% [markdown]
# #### Quick Assignment 2
# Write a piece of code that creates a new table (i.e., list of lists) containing only artists born in the 1880s.

# %%
born_1880s = []

for row in artist_table:
    if 1880 <= int(row[5]) <= 1889:
        born_1880s.append(row)

# %% [markdown]
# #### Average Artist Age
# Now that we’ve defined a meaningful subset of our data, let’s see what we can do with it. For instance, what was the mean life span of artists born in the 1880s (who happen to be included in MoMA's collections)?

# %%
lifespans_1880s = []

for row in born_1880s:
    lifespans_1880s.append(int(row[6]) - int(row[5]))

lifespans_1880s
# Out:
# [80,
#  55,
#  90,
#  65,
#  82,
#  88,
#  76,
#  77,
#  78,
#  66,
#  80,
#  89,
#  86,
#  56,
#  71,
#  66,
#  78,
#  65,
#  72,
#  66,
#  66,
#  36,
#  77,
#  86,
#  43,
#  52,
#  86,
#  73,
#  89,
#  88,
#  76,
#  79,
#  78,
#  34,
#  50,
#  50,
#  87,
#  71,
#  67,
#  60,
#  52,
#  57,
#  81,
#  84,
#  85,
#  55,
#  75,
#  74,
#  83,
#  85,
#  68,
#  58,
#  70,
#  85,
#  58,
#  71,
#  98,
#  87,
#  62,
#  90,
#  84,
#  74,
#  45,
#  103,
#  84,
#  86,
#  78,
#  75,
#  84,
#  93,
#  64,
#  85,
#  85,
#  98,
#  65,
#  63,
#  63,
#  56,
#  94,
#  52,
#  74,
#  71,
#  55,
#  41,
#  75,
#  66,
#  81,
#  90,
#  62,
#  85,
#  80,
#  79,
#  67,
#  60,
#  83,
#  49,
#  81,
#  77,
#  73,
#  74,
#  77,
#  78,
#  83,
#  82,
#  71,
#  80,
#  84,
#  71,
#  51,
#  53,
#  62,
#  59,
#  -1881,
#  60,
#  58,
#  98,
#  74,
#  76,
#  72,
#  59,
#  81,
#  -1880,
#  87,
#  91,
#  57,
#  80,
#  93,
#  47,
#  40,
#  94,
#  86,
#  59,
#  70,
#  46,
#  77,
#  75,
#  74,
#  85,
#  64,
#  87,
#  70,
#  87,
#  78,
#  85,
#  89,
#  86,
#  85,
#  96,
#  79,
#  77,
#  76,
#  79,
#  56,
#  73,
#  73,
#  76,
#  83,
#  67,
#  71,
#  58,
#  66,
#  80,
#  95,
#  72,
#  89,
#  47,
#  58,
#  87,
#  66,
#  74,
#  94,
#  78,
#  76,
#  90,
#  83,
#  84,
#  94,
#  64,
#  40,
#  56,
#  53,
#  83,
#  73,
#  69,
#  78,
#  65,
#  80,
#  38,
#  81,
#  75,
#  -1882,
#  77,
#  80,
#  89,
#  89,
#  27,
#  72,
#  83,
#  -1880,
#  73,
#  36,
#  61,
#  57,
#  92,
#  58,
#  47,
#  74,
#  93,
#  83,
#  78,
#  67,
#  74,
#  74,
#  82,
#  79,
#  72,
#  73,
#  71,
#  90,
#  69,
#  36,
#  62,
#  83,
#  69,
#  86,
#  66,
#  68,
#  69,
#  76,
#  79,
#  64,
#  88,
#  57,
#  82,
#  75,
#  61,
#  54,
#  57,
#  88,
#  82,
#  72,
#  99,
#  -1880,
#  66,
#  -1886,
#  80,
#  74,
#  75,
#  91,
#  45,
#  66,
#  74,
#  50,
#  76,
#  47,
#  92,
#  58,
#  71,
#  35,
#  90,
#  69,
#  86,
#  70,
#  57,
#  82,
#  95,
#  81,
#  90,
#  88,
#  61,
#  77,
#  76,
#  71,
#  79,
#  87,
#  76,
#  70,
#  32,
#  67,
#  65,
#  68,
#  58,
#  72,
#  66,
#  68,
#  55,
#  92,
#  54,
#  80,
#  49,
#  61,
#  75,
#  87,
#  90,
#  84,
#  84,
#  83,
#  82,
#  77,
#  90,
#  76,
#  76,
#  66,
#  64,
#  86,
#  79,
#  80,
#  57,
#  70,
#  76,
#  67,
#  81,
#  71,
#  95,
#  63,
#  53,
#  63,
#  54,
#  68,
#  102,
#  77,
#  81,
#  65,
#  81,
#  95,
#  50,
#  54,
#  79,
#  72,
#  82,
#  97,
#  48,
#  88,
#  79,
#  -1887,
#  75,
#  76,
#  61,
#  82,
#  60,
#  81,
#  81,
#  72,
#  58,
#  89,
#  80,
#  95,
#  83,
#  94,
#  72,
#  58,
#  102,
#  79,
#  83,
#  76,
#  70,
#  75,
#  81,
#  77,
#  92,
#  75,
#  74,
#  59,
#  57,
#  70,
#  59,
#  54,
#  55,
#  83,
#  83,
#  76,
#  69,
#  -1884,
#  65,
#  61,
#  54,
#  62,
#  85,
#  66,
#  74,
#  81,
#  64,
#  82,
#  75,
#  94,
#  65,
#  -1881,
#  -1888,
#  -1889,
#  -1889,
#  -1887,
#  -1888,
#  -1880,
#  -1884,
#  -1884,
#  81,
#  84,
#  37,
#  82,
#  31,
#  58,
#  85,
#  74,
#  -1888,
#  38,
#  54,
#  72,
#  73,
#  67,
#  88,
#  86,
#  67,
#  61,
#  88,
#  79,
#  41,
#  91,
#  51,
#  52,
#  54,
#  63,
#  65,
#  67,
#  57,
#  77,
#  78,
#  44,
#  79,
#  86,
#  48,
#  89,
#  88,
#  86,
#  69,
#  75,
#  43,
#  72,
#  -1884,
#  -1886,
#  65,
#  -1882,
#  45,
#  97,
#  80,
#  74,
#  73,
#  84,
#  83,
#  59,
#  92,
#  92,
#  76,
#  95,
#  79,
#  60,
#  44,
#  79,
#  82,
#  87,
#  64,
#  72,
#  89,
#  93,
#  76,
#  75,
#  76,
#  -1881,
#  77,
#  82,
#  84,
#  50,
#  96,
#  93,
#  59,
#  63,
#  77,
#  73,
#  84,
#  91,
#  -1889,
#  83,
#  90,
#  84,
#  83,
#  94,
#  85,
#  67,
#  84,
#  85,
#  63,
#  97,
#  65,
#  92,
#  78,
#  90,
#  -1886,
#  71,
#  80,
#  54,
#  -1885,
#  56,
#  -1885,
#  86,
#  74,
#  57,
#  48,
#  46,
#  48,
#  66,
#  77,
#  74,
#  72,
#  53,
#  59,
#  85,
#  58,
#  93,
#  78,
#  102,
#  68,
#  62,
#  67,
#  87,
#  62,
#  64]

# %% [markdown]
# If you scroll through your list of lifespans, you’ll see occasional negative numbers (e.g., “-1887”). Since missing values are represented by “0,” if no death date is listed we’ll end up subtracting an artist’s birth year from zero. Let’s amend our code to leave out these rows.

# %%
lifespans_1880s = []

for row in born_1880s:
    age = int(row[6])-int(row[5])
    if age > 0:
        lifespans_1880s.append(age)

lifespans_1880s
# Out:
# [80,
#  55,
#  90,
#  65,
#  82,
#  88,
#  76,
#  77,
#  78,
#  66,
#  80,
#  89,
#  86,
#  56,
#  71,
#  66,
#  78,
#  65,
#  72,
#  66,
#  66,
#  36,
#  77,
#  86,
#  43,
#  52,
#  86,
#  73,
#  89,
#  88,
#  76,
#  79,
#  78,
#  34,
#  50,
#  50,
#  87,
#  71,
#  67,
#  60,
#  52,
#  57,
#  81,
#  84,
#  85,
#  55,
#  75,
#  74,
#  83,
#  85,
#  68,
#  58,
#  70,
#  85,
#  58,
#  71,
#  98,
#  87,
#  62,
#  90,
#  84,
#  74,
#  45,
#  103,
#  84,
#  86,
#  78,
#  75,
#  84,
#  93,
#  64,
#  85,
#  85,
#  98,
#  65,
#  63,
#  63,
#  56,
#  94,
#  52,
#  74,
#  71,
#  55,
#  41,
#  75,
#  66,
#  81,
#  90,
#  62,
#  85,
#  80,
#  79,
#  67,
#  60,
#  83,
#  49,
#  81,
#  77,
#  73,
#  74,
#  77,
#  78,
#  83,
#  82,
#  71,
#  80,
#  84,
#  71,
#  51,
#  53,
#  62,
#  59,
#  60,
#  58,
#  98,
#  74,
#  76,
#  72,
#  59,
#  81,
#  87,
#  91,
#  57,
#  80,
#  93,
#  47,
#  40,
#  94,
#  86,
#  59,
#  70,
#  46,
#  77,
#  75,
#  74,
#  85,
#  64,
#  87,
#  70,
#  87,
#  78,
#  85,
#  89,
#  86,
#  85,
#  96,
#  79,
#  77,
#  76,
#  79,
#  56,
#  73,
#  73,
#  76,
#  83,
#  67,
#  71,
#  58,
#  66,
#  80,
#  95,
#  72,
#  89,
#  47,
#  58,
#  87,
#  66,
#  74,
#  94,
#  78,
#  76,
#  90,
#  83,
#  84,
#  94,
#  64,
#  40,
#  56,
#  53,
#  83,
#  73,
#  69,
#  78,
#  65,
#  80,
#  38,
#  81,
#  75,
#  77,
#  80,
#  89,
#  89,
#  27,
#  72,
#  83,
#  73,
#  36,
#  61,
#  57,
#  92,
#  58,
#  47,
#  74,
#  93,
#  83,
#  78,
#  67,
#  74,
#  74,
#  82,
#  79,
#  72,
#  73,
#  71,
#  90,
#  69,
#  36,
#  62,
#  83,
#  69,
#  86,
#  66,
#  68,
#  69,
#  76,
#  79,
#  64,
#  88,
#  57,
#  82,
#  75,
#  61,
#  54,
#  57,
#  88,
#  82,
#  72,
#  99,
#  66,
#  80,
#  74,
#  75,
#  91,
#  45,
#  66,
#  74,
#  50,
#  76,
#  47,
#  92,
#  58,
#  71,
#  35,
#  90,
#  69,
#  86,
#  70,
#  57,
#  82,
#  95,
#  81,
#  90,
#  88,
#  61,
#  77,
#  76,
#  71,
#  79,
#  87,
#  76,
#  70,
#  32,
#  67,
#  65,
#  68,
#  58,
#  72,
#  66,
#  68,
#  55,
#  92,
#  54,
#  80,
#  49,
#  61,
#  75,
#  87,
#  90,
#  84,
#  84,
#  83,
#  82,
#  77,
#  90,
#  76,
#  76,
#  66,
#  64,
#  86,
#  79,
#  80,
#  57,
#  70,
#  76,
#  67,
#  81,
#  71,
#  95,
#  63,
#  53,
#  63,
#  54,
#  68,
#  102,
#  77,
#  81,
#  65,
#  81,
#  95,
#  50,
#  54,
#  79,
#  72,
#  82,
#  97,
#  48,
#  88,
#  79,
#  75,
#  76,
#  61,
#  82,
#  60,
#  81,
#  81,
#  72,
#  58,
#  89,
#  80,
#  95,
#  83,
#  94,
#  72,
#  58,
#  102,
#  79,
#  83,
#  76,
#  70,
#  75,
#  81,
#  77,
#  92,
#  75,
#  74,
#  59,
#  57,
#  70,
#  59,
#  54,
#  55,
#  83,
#  83,
#  76,
#  69,
#  65,
#  61,
#  54,
#  62,
#  85,
#  66,
#  74,
#  81,
#  64,
#  82,
#  75,
#  94,
#  65,
#  81,
#  84,
#  37,
#  82,
#  31,
#  58,
#  85,
#  74,
#  38,
#  54,
#  72,
#  73,
#  67,
#  88,
#  86,
#  67,
#  61,
#  88,
#  79,
#  41,
#  91,
#  51,
#  52,
#  54,
#  63,
#  65,
#  67,
#  57,
#  77,
#  78,
#  44,
#  79,
#  86,
#  48,
#  89,
#  88,
#  86,
#  69,
#  75,
#  43,
#  72,
#  65,
#  45,
#  97,
#  80,
#  74,
#  73,
#  84,
#  83,
#  59,
#  92,
#  92,
#  76,
#  95,
#  79,
#  60,
#  44,
#  79,
#  82,
#  87,
#  64,
#  72,
#  89,
#  93,
#  76,
#  75,
#  76,
#  77,
#  82,
#  84,
#  50,
#  96,
#  93,
#  59,
#  63,
#  77,
#  73,
#  84,
#  91,
#  83,
#  90,
#  84,
#  83,
#  94,
#  85,
#  67,
#  84,
#  85,
#  63,
#  97,
#  65,
#  92,
#  78,
#  90,
#  71,
#  80,
#  54,
#  56,
#  86,
#  74,
#  57,
#  48,
#  46,
#  48,
#  66,
#  77,
#  74,
#  72,
#  53,
#  59,
#  85,
#  58,
#  93,
#  78,
#  102,
#  68,
#  62,
#  67,
#  87,
#  62,
#  64]

# %% [markdown]
# Now that we have a list of valid integers, all we need to do is calculate the mean. Below we divide the sum of the list (which we cast as a float) by its length to get 72.65 years.

# %%
float(sum(lifespans_1880s)) / len(lifespans_1880s)
# Out:
# 72.8496993987976

# %% [markdown]
# That format is a bit verbose for a simple task like this, so to make life easier we’ll use the Python package `NumPy`.

# %%
import numpy
numpy.mean(lifespans_1880s)
# Out:
# 72.849699398797597

# %% [markdown]
# **Tip:** The code above imports the entire `numpy` package. Python also lets us import packages’ individual functions to the current environment, which can make code more compact.

# %%
from numpy import mean
mean(lifespans_1880s)
# Out:
# 72.849699398797597

# %% [markdown]
# A common convention is to rename `numpy` to `np` at the import step.

# %%
import numpy as np
np.mean(lifespans_1880s)
# Out:
# 72.849699398797597

# %% [markdown]
# This guide will use to `numpy.mean()` for the sake of clarity, but feel free to set up your environment however you like.

# %% [markdown]
# #### Quick Assignment 3
# Write a piece of code that creates a new table containing all artworks that include the term “Fluxus” in any metadata field.

# %%
fluxus_table = []

for row in artwork_table:
    for cell in row:
        if 'fluxus' in cell.lower():
            if row not in fluxus_table:
                fluxus_table.append(row)

# %% [markdown]
# #### Fluxus Metadata Continued
# Now let’s make a master list of entries under “medium” in our Fluxus metadata set.

# %%
medium_list = []

for row in fluxus_table:
    medium_list.append(row[9])

len(medium_list)
# Out:
# 4861

# %% [markdown]
# Let’s look at 10 random samples from the collection, first importing the `random` package.

# %%
import random

random.sample(medium_list, 10)
# Out:
# ['Offset postcard',
#  'Gelatin silver print',
#  '(CONFIRM)',
#  'Ink and color chart on paper',
#  'Typewriting and ink on paper',
#  'Typewriting on cardstock with stamps and postal cancellation',
#  'Ink on paper',
#  '16mm film (black and white, silent)',
#  'Super- 8 cartridge',
#  'File cabinet drawer, containing objects in various media']

# %% [markdown]
# Let’s see what terms appear most frequently in our list of media.

# %%
from collections import Counter

c = Counter(medium_list)
c.most_common(10)
# Out:
# [('', 1151),
#  ('Gelatin silver print', 477),
#  ('(CONFIRM)', 190),
#  ('Ink on paper', 134),
#  ('Offset', 120),
#  ('Offset lithograph', 114),
#  ('Offset card', 81),
#  ('Letterpress', 75),
#  ('Mixed media', 62),
#  ('Photocopy', 54)]

# %% [markdown]
# Note that 1151 artworks are missing an entry for “medium,” with the term “(CONFIRM)” appearing 190 times.

# %% [markdown]
# #### Quick Assignment 4
# Returning to our original MoMA metadata table, write a piece of code that extracts only works created in the 1960s (or another decade of your choosing). Since the date field in MoMA’s metadata doesn’t follow a strictly defined numerical format, you’ll have to think about how to interpret values like “1963,” “1963-5“, “c. 1963,” “c. 1960s,” etc.

# %%
art_1960s = []

for row in artwork_table:
    if '196' in row[8]:
        art_1960s.append(row)
        
art_1960s
# Out:
# [['Memorial to the Six Million Jewish Martyrs, project, New York City, New York, Perspective of central pier',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1968',
#   'Charcoal and graphite on tracing paper',
#   '44 1/2 x 66" (113 x 167.6 cm)',
#   'Purchase',
#   '3.1997',
#   'Architecture',
#   'Architecture & Design',
#   '1997-01-15',
#   'Y',
#   '32',
#   'http://www.moma.org/collection/works/32',
#   'http://www.moma.org/media/W1siZiIsIjE3MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=84cc6597561b2de4',
#   '',
#   '',
#   '',
#   '113.0',
#   '',
#   '',
#   '167.6',
#   '',
#   ''],
#  ['Yale University, Art and Architecture Building, New Haven, Connecticut, Elevation',
#   'Paul Rudolph',
#   '5076',
#   '(American, 1918–1997)',
#   '(American)',
#   '(1918)',
#   '(1997)',
#   '(Male)',
#   '1958–1964',
#   'Graphite and colored pencil on paper',
#   '27 1/4 x 34 1/4" (69.2 x 87 cm)',
#   'Gift of the architect',
#   '98.1989',
#   'Architecture',
#   'Architecture & Design',
#   '1989-05-16',
#   'Y',
#   '193',
#   'http://www.moma.org/collection/works/193',
#   'http://www.moma.org/media/W1siZiIsIjE4MDAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=0e54cf2f46103a1d',
#   '',
#   '',
#   '',
#   '69.2',
#   '',
#   '',
#   '87.0',
#   '',
#   ''],
#  ['City Hall, project, North Canton, Ohio, Perspective sketch',
#   'Venturi and Rauch, Robert Venturi, John Rauch',
#   '8213, 6132, 8214',
#   '(American, est. 1964–1979) (American, born 1925) (American, born 1930)',
#   '(American) (American) (American)',
#   '(1964) (1925) (1930)',
#   '(1979) (0) (0)',
#   '() (Male) (Male)',
#   '1965',
#   'Graphite on tracing paper',
#   '20 1/2 x 36" (52.1 x 91.4 cm)',
#   'Gift of Venturi, Rauch and Scott Brown, Inc.',
#   '120.1988',
#   'Architecture',
#   'Architecture & Design',
#   '1988-04-27',
#   'Y',
#   '210',
#   'http://www.moma.org/collection/works/210',
#   'http://www.moma.org/media/W1siZiIsIjIxMjgiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=62d5e18053f62b75',
#   '',
#   '',
#   '',
#   '52.1',
#   '',
#   '',
#   '91.4',
#   '',
#   ''],
#  ['Transplantation I, Perspective and plan',
#   'Raimund Abraham',
#   '47',
#   '(American, born Austria. 1933–2010)',
#   '(American)',
#   '(1933)',
#   '(2010)',
#   '(Male)',
#   '1964',
#   '.a: Pen and ink\n.b: Collage',
#   '.a:  5 5/8 x 7" (14.3 x 17.8 cm)\n.b: 4 1/2 x 7" (11.4 x 17.8 cm)',
#   'Philip Johnson Fund',
#   '281.1965.a-b',
#   'Architecture',
#   'Architecture & Design',
#   '1965-04-06',
#   'Y',
#   '307',
#   'http://www.moma.org/collection/works/307',
#   'http://www.moma.org/media/W1siZiIsIjQ1NDUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=6e7eb3b96f4318b5',
#   '',
#   '',
#   '',
#   '14.3',
#   '',
#   '',
#   '17.8',
#   '',
#   ''],
#  ['Linear City Project, Perspective',
#   'Raimund Abraham',
#   '47',
#   '(American, born Austria. 1933–2010)',
#   '(American)',
#   '(1933)',
#   '(2010)',
#   '(Male)',
#   '1964',
#   '.1: Ink and graphite on paper\n.2: Ink and graphite on paper',
#   '.1: 17 1/2 x 24 3/4" (44.5 x 62.9 cm) \n.2: 8 1/4 x 15 1/2" (21 x 39.4 cm)',
#   'Philip Johnson Fund',
#   '282.1965.1-2',
#   'Architecture',
#   'Architecture & Design',
#   '1965-04-06',
#   'Y',
#   '308',
#   'http://www.moma.org/collection/works/308',
#   'http://www.moma.org/media/W1siZiIsIjQ1NTYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=bc7ec51640991d57',
#   '',
#   '',
#   '',
#   '21.0',
#   '',
#   '',
#   '39.4',
#   '',
#   ''],
#  ['Market Street East Studies, project, Philadelphia, Pennsylvania, Perspective',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Ink and graphite on tracing paper',
#   '12 1/4 x 19 7/8" (31.1 x 50.5 cm)',
#   'Gift of the architect',
#   '362.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '394',
#   'http://www.moma.org/collection/works/394',
#   'http://www.moma.org/media/W1siZiIsIjU2NzciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=3a33881fd892244d',
#   '',
#   '',
#   '',
#   '31.1',
#   '',
#   '',
#   '50.5',
#   '',
#   ''],
#  ['Alfred Newton Richards Medical Research Building and Biology Building, University of Pennsylvania, Philadelphia, Pennsylvania, Exterior perspective, final version',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1960',
#   'Graphite on tracing paper',
#   '23 x 23 1/2" (58.4 x 59.7 cm)',
#   'Gift of the architect',
#   '369.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '411',
#   'http://www.moma.org/collection/works/411',
#   'http://www.moma.org/media/W1siZiIsIjU3NTkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=c2f1a6fb1969e190',
#   '',
#   '',
#   '',
#   '58.4',
#   '',
#   '',
#   '59.7',
#   '',
#   ''],
#  ['Project for a Painted Wall, New York City, New York (Perspective)',
#   'Jason Crum',
#   '1318',
#   '(American, 1935–2004)',
#   '(American)',
#   '(1935)',
#   '(2004)',
#   '(Male)',
#   '1969',
#   'Gouache on photograph',
#   '20 x 27 1/2" (50.8 x 69.9 cm)',
#   'Purchase',
#   '372.1969',
#   'Architecture',
#   'Architecture & Design',
#   '1969-04-24',
#   'Y',
#   '421',
#   'http://www.moma.org/collection/works/421',
#   'http://www.moma.org/media/W1siZiIsIjU4MTEiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=6b326dc3db2aa13e',
#   '',
#   '',
#   '',
#   '50.8',
#   '',
#   '',
#   '69.9',
#   '',
#   ''],
#  ['Project for a Painted Wall, New York City, New York (Perspective)',
#   'Jason Crum',
#   '1318',
#   '(American, 1935–2004)',
#   '(American)',
#   '(1935)',
#   '(2004)',
#   '(Male)',
#   '1969',
#   'Gouache on photograph',
#   '30 x 20" (76.2 x 50.8 cm)',
#   'Purchase',
#   '373.1969',
#   'Architecture',
#   'Architecture & Design',
#   '1969-04-24',
#   'Y',
#   '425',
#   'http://www.moma.org/collection/works/425',
#   'http://www.moma.org/media/W1siZiIsIjU4MjYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2ebbd4c7217a0239',
#   '',
#   '',
#   '',
#   '76.2',
#   '',
#   '',
#   '50.8',
#   '',
#   ''],
#  ['Project for a Painted Wall, Fox Department Store, Hartford, Connecticut (Perspective)',
#   'Jason Crum',
#   '1318',
#   '(American, 1935–2004)',
#   '(American)',
#   '(1935)',
#   '(2004)',
#   '(Male)',
#   '1969',
#   'Gouache on photograph',
#   '13 3/4 x 16 7/8" (34.9 x 42.9 cm)',
#   'Purchase',
#   '374.1969',
#   'Architecture',
#   'Architecture & Design',
#   '1969-04-24',
#   'Y',
#   '429',
#   'http://www.moma.org/collection/works/429',
#   'http://www.moma.org/media/W1siZiIsIjU4NDUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=7bb8d510169c37ed',
#   '',
#   '',
#   '',
#   '34.9',
#   '',
#   '',
#   '42.9',
#   '',
#   ''],
#  ['Airplane Hangar Project (Roof plan)',
#   'Konrad Wachsmann',
#   '6201',
#   '(American, born Germany. 1901–1980)',
#   '(American)',
#   '(1901)',
#   '(1980)',
#   '(Male)',
#   '1963',
#   'Lithograph',
#   '',
#   'Gift of Ivan Chermayeff',
#   '375.1969',
#   'Architecture',
#   'Architecture & Design',
#   '1969-04-24',
#   'Y',
#   '433',
#   'http://www.moma.org/collection/works/433',
#   'http://www.moma.org/media/W1siZiIsIjU4NjAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=fa93bf4fc7bc2284',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Building over Motorway Project, London, England, Perspectives',
#   'Leon Krier',
#   '3250',
#   '(Luxembourgish, born 1946)',
#   '(Luxembourgish)',
#   '(1946)',
#   '(0)',
#   '(Male)',
#   '1969',
#   'Ink on paper',
#   '19 x 15 5/8" (48.3 x 39.7 cm) (frame)',
#   'Gift of the architect in honor of Philip Johnson',
#   '378.1996',
#   'Architecture',
#   'Architecture & Design',
#   '1996-09-25',
#   'Y',
#   '445',
#   'http://www.moma.org/collection/works/445',
#   'http://www.moma.org/media/W1siZiIsIjU5MDYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=44561fc15452e846',
#   '',
#   '',
#   '',
#   '48.2601',
#   '',
#   '',
#   '39.6876',
#   '',
#   ''],
#  ['First Unitarian Church and School, Rochester, New York, Roof-structure and light-element sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1969',
#   'Graphite on tracing paper',
#   '12 x 25" (30.5 x 63.5 cm)',
#   'Gift of the architect',
#   '379.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '446',
#   'http://www.moma.org/collection/works/446',
#   'http://www.moma.org/media/W1siZiIsIjU5MTEiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=c75999e7ff99e4b0',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '63.5',
#   '',
#   ''],
#  ['First Unitarian Church and School, Rochester, New York, Roof-structure and light-element sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1960',
#   'Graphite on tracing paper',
#   '12 x 20 1/4" (30.5 x 51.4 cm)',
#   'Gift of the architect',
#   '380.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '450',
#   'http://www.moma.org/collection/works/450',
#   'http://www.moma.org/media/W1siZiIsIjU5MjUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=e6d27914a9630c78',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '51.4',
#   '',
#   ''],
#  ['Salk Institute for Biological Studies, La Jolla, California, Perspective of meeting house',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   ' 1961',
#   'Graphite and crayon on paper',
#   '23 7/8 x 31 1/2" (67 x 80 cm)',
#   'Gift of the architect',
#   '381.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '454',
#   'http://www.moma.org/collection/works/454',
#   'http://www.moma.org/media/W1siZiIsIjU5MzQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=0b4fd0a0a3b3e782',
#   '',
#   '',
#   '',
#   '67.0',
#   '',
#   '',
#   '80.0',
#   '',
#   ''],
#  ['Salk Institute for Biological Studies (laboratory, meeting house, and housing), La Jolla, California, Laboratory: elevation of studies',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Charcoal on tracing paper',
#   '15 x 21 1/2" (38.1 x 54.6 cm)',
#   'Gift of the architect',
#   '382.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '458',
#   'http://www.moma.org/collection/works/458',
#   'http://www.moma.org/media/W1siZiIsIjU5NDkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=e493ad81cc588ed3',
#   '',
#   '',
#   '',
#   '38.1',
#   '',
#   '',
#   '54.6',
#   '',
#   ''],
#  ['Salk Institute for Biological Studies (laboratory, meeting house, and housing), La Jolla, California, Laboratory: elevation of studies',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Charcoal on tracing paper',
#   '24 1/8 x 12" (61.3 x 30.5 cm)',
#   'Gift of the architect',
#   '383.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '462',
#   'http://www.moma.org/collection/works/462',
#   'http://www.moma.org/media/W1siZiIsIjEyMzkyNiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=f764c2f67aab067d',
#   '',
#   '',
#   '',
#   '61.3',
#   '',
#   '',
#   '30.5',
#   '',
#   ''],
#  ['Salk Institute for Biological Studies (Laboratory, Meeting House, and Housing), La Jolla, California, Laboratory: perspective',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Charcoal on tracing paper',
#   '19 1/2 x 38 3/4"  (49.5 x 98.4 cm)',
#   'Gift of the architect',
#   '384.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '466',
#   'http://www.moma.org/collection/works/466',
#   'http://www.moma.org/media/W1siZiIsIjU5ODIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=752f8e8255a6c418',
#   '',
#   '',
#   '',
#   '49.5',
#   '',
#   '',
#   '98.4',
#   '',
#   ''],
#  ['Eleanor Donnelley Erdman Hall, Bryn Mawr College, Bryn Mawr, Pennsylvania, Plan and elevation sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1960-61',
#   'Crayon on tracing paper',
#   '12 1/8 x 16" (30.8 x 40.6 cm)',
#   'Gift of the architect',
#   '385.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '470',
#   'http://www.moma.org/collection/works/470',
#   'http://www.moma.org/media/W1siZiIsIjU5OTYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=0d9c6c2654aa3437',
#   '',
#   '',
#   '',
#   '30.8',
#   '',
#   '',
#   '40.6',
#   '',
#   ''],
#  ['Eleanor Donnelley Erdman Hall, Bryn Mawr College, Bryn Mawr, Pennsylvania, Plan sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1960-61',
#   'Charcoal on tracing paper',
#   '12 1/8 x 14 3/4" (30.8 x 37.5 cm)',
#   'Gift of the architect',
#   '386.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '474',
#   'http://www.moma.org/collection/works/474',
#   'http://www.moma.org/media/W1siZiIsIjYwMTQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=8f275577f5e81aa1',
#   '',
#   '',
#   '',
#   '30.8',
#   '',
#   '',
#   '37.5',
#   '',
#   ''],
#  ['Eleanor Donnelley Erdman Hall, Bryn Mawr College, Bryn Mawr, Pennsylvania, Plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Charcoal on tracing paper',
#   '18 x 53 3/8" (45.7 x 135.6 cm)',
#   'Gift of the architect',
#   '387.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '478',
#   'http://www.moma.org/collection/works/478',
#   'http://www.moma.org/media/W1siZiIsIjYwMjkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=dc68c70bb793b733',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '135.6',
#   '',
#   ''],
#  ['Fine Arts Center, School, and Performing Arts Theater, Fort Wayne, Indiana, Site-plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '12 x 23 1/4" (30.5 x 59.1 cm)',
#   'Gift of the architect',
#   '388.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '485',
#   'http://www.moma.org/collection/works/485',
#   'http://www.moma.org/media/W1siZiIsIjYwNDIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=5300521394372d34',
#   '',
#   '',
#   '',
#   '30.4801',
#   '',
#   '',
#   '59.0551',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Plan sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '18 x 33 1/2" (45.7 x 85.1 cm)',
#   'Gift of the architect',
#   '389.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '489',
#   'http://www.moma.org/collection/works/489',
#   'http://www.moma.org/media/W1siZiIsIjYwNTMiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=a1bcc1733dcfa460',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '85.1',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh (Prayer Hall: plan and elevation sketches)',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1964',
#   'Charcoal and graphite on tracing paper',
#   '14 3/4 x 14 1/8" (37.5 x 35.9 cm)',
#   'Gift of the architect',
#   '390.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '492',
#   'http://www.moma.org/collection/works/492',
#   'http://www.moma.org/media/W1siZiIsIjYwNjIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=6de32e9f32d030ed',
#   '',
#   '',
#   '',
#   '37.4651',
#   '',
#   '',
#   '35.8776',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Perspective drawing',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Charcoal on tracing paper',
#   '23 7/8 x 36 5/8" (60.6 x 93 cm)',
#   'Gift of the architect',
#   '390.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '493',
#   'http://www.moma.org/collection/works/493',
#   'http://www.moma.org/media/W1siZiIsIjYwNjQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=e1cc26eef095e272',
#   '',
#   '',
#   '',
#   '60.6',
#   '',
#   '',
#   '93.0',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh (Site plan and elevation sketches)',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Graphite and crayon on tracing paper',
#   '10 3/8 x 18 3/4" (26.4 x 47.6 cm)',
#   'Gift of the architect',
#   '391.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '497',
#   'http://www.moma.org/collection/works/497',
#   'http://www.moma.org/media/W1siZiIsIjYwNzQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2d60bc22fa404194',
#   '',
#   '',
#   '',
#   '26.4',
#   '',
#   '',
#   '47.6',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Interior perspective sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '18 x 23" (45.7 x 58.4 cm)',
#   'Gift of the architect',
#   '391.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '498',
#   'http://www.moma.org/collection/works/498',
#   'http://www.moma.org/media/W1siZiIsIjYwNzUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=edc09147f804008a',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '58.4',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh (Site-plan and elevation sketches)',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on yellow tracing paper',
#   '17 3/4 x 24 1/2" (45.1 x 62.2 cm)',
#   'Gift of the architect',
#   '392.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '502',
#   'http://www.moma.org/collection/works/502',
#   'http://www.moma.org/media/W1siZiIsIjYwODYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=ac759de5559f5d64',
#   '',
#   '',
#   '',
#   '45.1',
#   '',
#   '',
#   '62.2',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Ceiling sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal and graphite on tracing paper',
#   '12 x 15 1/2" (30.5 x 39.4 cm)',
#   'Gift of the architect',
#   '392.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '503',
#   'http://www.moma.org/collection/works/503',
#   'http://www.moma.org/media/W1siZiIsIjYwODgiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=007fe2717bf38e89',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '39.4',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh (Plan sketch)',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '12 x 18" (30.5 x 45.7 cm)',
#   'Gift of the architect',
#   '393.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '507',
#   'http://www.moma.org/collection/works/507',
#   'http://www.moma.org/media/W1siZiIsIjYwOTkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2674f9126b40e434',
#   '',
#   '',
#   '',
#   '28.6',
#   '',
#   '',
#   '31.8',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Plan and perspective sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Graphite on tracing paper',
#   '18 1/8 x 30 1/2" (46 x 77.5 cm)',
#   'Gift of the architect',
#   '393.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '508',
#   'http://www.moma.org/collection/works/508',
#   'http://www.moma.org/media/W1siZiIsIjYxMDAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=43174c149d7b3f12',
#   '',
#   '',
#   '',
#   '46.0',
#   '',
#   '',
#   '77.5',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh (Plan sketch)',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '13 x 19 1/2" (33 x 49.5 cm)',
#   'Gift of the architect',
#   '394.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '512',
#   'http://www.moma.org/collection/works/512',
#   'http://www.moma.org/media/W1siZiIsIjYxMTAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2986389c14b9ac8e',
#   '',
#   '',
#   '',
#   '27.9',
#   '',
#   '',
#   '33.0',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Perspective sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Crayon on tracing paper',
#   '18 x 35 7/8" (45.7 x 91.1 cm)',
#   'Gift of the architect',
#   '394.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '513',
#   'http://www.moma.org/collection/works/513',
#   'http://www.moma.org/media/W1siZiIsIjYxMTIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=4a588825f78a7a5d',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '91.1',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '10 1/8 x 11 7/8" (25.7 x 30.2 cm)',
#   'Gift of the architect',
#   '395.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '518',
#   'http://www.moma.org/collection/works/518',
#   'http://www.moma.org/media/W1siZiIsIjYxMjUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=daadcd8ed37922b6',
#   '',
#   '',
#   '',
#   '25.7',
#   '',
#   '',
#   '30.2',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Preliminary sketches of the Citadel of the Assembly',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Crayon, charcoal, and graphite on tracing paper',
#   '24 x 38 1/2" (61 x 97.8 cm)',
#   'Gift of the architect',
#   '395.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '519',
#   'http://www.moma.org/collection/works/519',
#   'http://www.moma.org/media/W1siZiIsIjYxMjYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=834d647a60532229',
#   '',
#   '',
#   '',
#   '61.0',
#   '',
#   '',
#   '97.8',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: plan and sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Graphite on tracing paper',
#   '12 x 17" (30.5 x 43.2 cm)',
#   'Gift of the architect',
#   '396.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '524',
#   'http://www.moma.org/collection/works/524',
#   'http://www.moma.org/media/W1siZiIsIjYxMzkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=111fd1d9b6464bba',
#   '',
#   '',
#   '',
#   '30.4801',
#   '',
#   '',
#   '43.1801',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Site-plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1964',
#   'Charcoal and graphite on tracing paper',
#   '12 x 23 1/2" (30.5 x 59.7 cm)',
#   'Gift of the architect',
#   '396.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '525',
#   'http://www.moma.org/collection/works/525',
#   'http://www.moma.org/media/W1siZiIsIjYxNDAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=ff696ad6cae681c6',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '59.7',
#   '',
#   ''],
#  ['Fine Arts Center, School, and Performing Arts Theater, Fort Wayne, Indiana, Site-plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '12 x 23 3/8" (30.5 x 59.4 cm)',
#   'Gift of the architect',
#   '397.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '529',
#   'http://www.moma.org/collection/works/529',
#   'http://www.moma.org/media/W1siZiIsIjYxNTAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=232bef0355404fc4',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '54.6',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Site-plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1964',
#   'Charcoal, crayon, and graphite on tracing paper',
#   '18 x 33 1/2" (45.7 x 85.1 cm)',
#   'Gift of the architect',
#   '397.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '530',
#   'http://www.moma.org/collection/works/530',
#   'http://www.moma.org/media/W1siZiIsIjYxNTIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=a04a7ab6d87f8b02',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '85.1',
#   '',
#   ''],
#  ['Fine Arts Center, School, and Performing Arts Theater, Fort Wayne, Indiana, Site-plan and elevation sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal and crayon on tracing paper',
#   '12 x 22" (30.5 x 55.9 cm)',
#   'Gift of the architect',
#   '398.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '534',
#   'http://www.moma.org/collection/works/534',
#   'http://www.moma.org/media/W1siZiIsIjYxNjgiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=ee21b385552f6340',
#   '',
#   '',
#   '',
#   '22.8',
#   '',
#   '',
#   '50.8',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1964',
#   'Charcoal on tracing paper',
#   '18 x 24 1/2" (45.7 x 62.2 cm)',
#   'Gift of the architect',
#   '398.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '535',
#   'http://www.moma.org/collection/works/535',
#   'http://www.moma.org/media/W1siZiIsIjYxNzAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=c3fce22b2339765c',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '62.2',
#   '',
#   ''],
#  ['Fine Arts Center, School, and Performing Arts Theater, Fort Wayne, Indiana, Plan sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Graphite on paper',
#   '10 x 7 1/2" (25.4 x 19.1 cm)\n',
#   'Gift of the architect',
#   '399.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '538',
#   'http://www.moma.org/collection/works/538',
#   'http://www.moma.org/media/W1siZiIsIjYxODQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2bc2f8ae3e8b740d',
#   '',
#   '',
#   '',
#   '25.4001',
#   '',
#   '',
#   '19.05',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: plan and elevation sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '18 1/8 x 25 1/8" (46 x 63.8 cm)',
#   'Gift of the architect',
#   '399.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '539',
#   'http://www.moma.org/collection/works/539',
#   'http://www.moma.org/media/W1siZiIsIjYxODUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=43ace9ca9b06ed5a',
#   '',
#   '',
#   '',
#   '46.0',
#   '',
#   '',
#   '63.8',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Interior perspective',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper on board',
#   '23 1/8 x 21" (58.7 x 53.3 cm)',
#   'Gift of the architect',
#   '400.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '542',
#   'http://www.moma.org/collection/works/542',
#   'http://www.moma.org/media/W1siZiIsIjYyMDAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2dba1ce97dc02a1c',
#   '',
#   '',
#   '',
#   '53.3',
#   '',
#   '',
#   '50.2',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charocal on tracing paper',
#   '17 3/4 x 23" (45.1 x 58.4 cm)',
#   'Gift of the architect',
#   '400.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '543',
#   'http://www.moma.org/collection/works/543',
#   'http://www.moma.org/media/W1siZiIsIjIwODg3OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=92fc2005ab88b40d',
#   '',
#   '',
#   '',
#   '45.1',
#   '',
#   '',
#   '58.4',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Interior perspective',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '20 3/8 x 15 3/4" (51.8 x 40 cm)',
#   'Gift of the architect',
#   '401.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '546',
#   'http://www.moma.org/collection/works/546',
#   'http://www.moma.org/media/W1siZiIsIjYyMTYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=f461aa91f4c5f738',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '33.0',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: section sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Crayon on tracing paper',
#   '18 x 16 1/2" (45.7 x 41.9 cm)',
#   'Gift of the architect',
#   '401.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '547',
#   'http://www.moma.org/collection/works/547',
#   'http://www.moma.org/media/W1siZiIsIjYyMTciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=13c18555475d5bf2',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '41.9',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Perspective',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '14 1/2 x 22 1/8" (36.8 x 56.2 cm)',
#   'Gift of the architect',
#   '402.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '550',
#   'http://www.moma.org/collection/works/550',
#   'http://www.moma.org/media/W1siZiIsIjYyMzEiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=32bfe315a38cc65b',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '50.8',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: perspective sketch of light elements',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal on tracing paper',
#   '9 x 17 3/4" (22.9 x 45.1 cm)',
#   'Gift of the architect',
#   '402.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '551',
#   'http://www.moma.org/collection/works/551',
#   'http://www.moma.org/media/W1siZiIsIjYyMzMiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=6ffe84bb0aa960cb',
#   '',
#   '',
#   '',
#   '22.9',
#   '',
#   '',
#   '45.1',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Perspective of entrance',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1961',
#   'Charcoal on tracing paper',
#   '14 7/8 x 17" (37.8 x 43.2 cm)',
#   'Gift of the architect',
#   '403.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '553',
#   'http://www.moma.org/collection/works/553',
#   'http://www.moma.org/media/W1siZiIsIjYyNDUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=72a3a0a2e803e024',
#   '',
#   '',
#   '',
#   '37.8',
#   '',
#   '',
#   '43.2',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: elevation sketch of light elements',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1963',
#   'Charcoal and graphite on tracing paper',
#   '12 x 24" (30.5 x 61 cm)',
#   'Gift of the architect',
#   '403.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '554',
#   'http://www.moma.org/collection/works/554',
#   'http://www.moma.org/media/W1siZiIsIjYyNDYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=bd0abe18e0b77993',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '61.0',
#   '',
#   ''],
#  ['Mikveh Israel Synagogue, project, Philadelphia, Pennsylvania, Elevation with school building at left',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1962',
#   'Charcoal on tracing paper',
#   '23 3/4 x 113 1/2" (60.3 x 288.3 cm)',
#   'Gift of the architect',
#   '404.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '556',
#   'http://www.moma.org/collection/works/556',
#   'http://www.moma.org/media/W1siZiIsIjYyNjkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=753e938f1324aedb',
#   '',
#   '',
#   '',
#   '60.3',
#   '',
#   '',
#   '240.0',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: section sketch of roof structure and light elements',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Crayon and graphite on tracing paper',
#   '18 x 19" (45.7 x 48.2 cm)',
#   'Gift of the architect',
#   '404.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '557',
#   'http://www.moma.org/collection/works/557',
#   'http://www.moma.org/media/W1siZiIsIjYyNzAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=a61ec72238bceceb',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '48.2',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, National Assembly Building: elevation sketch of light element',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal and graphite on tracing paper',
#   '18 x 31 3/4" (45.7 x 80.6 cm)',
#   'Gift of the architect',
#   '405.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '560',
#   'http://www.moma.org/collection/works/560',
#   'http://www.moma.org/media/W1siZiIsIjYyODUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=23acefeff8dd2e01',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '80.6',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: preliminary version: elevation sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1964',
#   'Charcoal on tracing paper',
#   '18 x 15" (45.7 x 38.1 cm)',
#   'Gift of the architect',
#   '406.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '563',
#   'http://www.moma.org/collection/works/563',
#   'http://www.moma.org/media/W1siZiIsIjYyOTciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=e3b32b7f8024ef9e',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '38.1',
#   '',
#   ''],
#  ['Arthur W. Milam Residence, Ponte Vedra Beach, Florida, Exterior perspective from beach',
#   'Paul Rudolph',
#   '5076',
#   '(American, 1918–1997)',
#   '(American)',
#   '(1918)',
#   '(1997)',
#   '(Male)',
#   'c. 1960-62',
#   'Ink on board',
#   '33 x 30" (83.8 x 76.2 cm)',
#   'Gift of the architect',
#   '406.1985',
#   'Architecture',
#   'Architecture & Design',
#   '1985-11-18',
#   'Y',
#   '564',
#   'http://www.moma.org/collection/works/564',
#   'http://www.moma.org/media/W1siZiIsIjYzMDIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=925d893c2cbcb0f2',
#   '',
#   '',
#   '',
#   '83.8',
#   '',
#   '',
#   '76.2',
#   '',
#   ''],
#  ['First Unitarian Church and School, Rochester, New York, Final version: elevation',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1961',
#   'Graphite on tracing paper',
#   '16 1/8 x 27 1/2" (41 x 69.9 cm)',
#   'Gift of the architect',
#   '407.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '565',
#   'http://www.moma.org/collection/works/565',
#   'http://www.moma.org/media/W1siZiIsIjYzMTkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2aa410d551a2c3a8',
#   '',
#   '',
#   '',
#   '15.2',
#   '',
#   '',
#   '57.2',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketches',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '18 x 23 1/2" (45.7 x 59.7 cm)',
#   'Gift of the architect',
#   '407.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '566',
#   'http://www.moma.org/collection/works/566',
#   'http://www.moma.org/media/W1siZiIsIjYzMjAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=da9737b1e80bdb7d',
#   '',
#   '',
#   '',
#   '45.7',
#   '',
#   '',
#   '59.7',
#   '',
#   ''],
#  ['Graphic Arts Center Project, New York, New York, Elevation',
#   'Paul Rudolph',
#   '5076',
#   '(American, 1918–1997)',
#   '(American)',
#   '(1918)',
#   '(1997)',
#   '(Male)',
#   '1967',
#   'Ink on tracing paper',
#   '42 3/4 x 51 3/4" (108.6 x 131.4 cm)',
#   'Gift of the architect',
#   '407.1985',
#   'Architecture',
#   'Architecture & Design',
#   '1985-11-18',
#   'Y',
#   '567',
#   'http://www.moma.org/collection/works/567',
#   'http://www.moma.org/media/W1siZiIsIjYzMjciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=29223b31017699b0',
#   '',
#   '',
#   '',
#   '108.5852',
#   '',
#   '',
#   '131.4453',
#   '',
#   ''],
#  ['First Unitarian Church and School, Rochester, New York, Final version: elevation',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1961',
#   'Graphite on tracing paper',
#   '17 3/4 x 29 1/8" (45.1 x 74 cm)',
#   'Gift of the architect',
#   '408.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '568',
#   'http://www.moma.org/collection/works/568',
#   'http://www.moma.org/media/W1siZiIsIjYzMzUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=a32b96224b0958af',
#   '',
#   '',
#   '',
#   '45.1',
#   '',
#   '',
#   '74.0',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Graphite and charcoal on tracing paper',
#   '12 x 19 1/2" (30.5 x 49.5 cm)',
#   'Gift of the architect',
#   '408.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '569',
#   'http://www.moma.org/collection/works/569',
#   'http://www.moma.org/media/W1siZiIsIjYzMzYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=d9910bc918f3ec5c',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '49.5',
#   '',
#   ''],
#  ['First Unitarian Church and School, Rochester, New York, Final version: elevation',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1961',
#   'Graphite on tracing paper',
#   '17 3/4 x 29 1/8" (45.1x 74 cm)',
#   'Gift of the architect',
#   '409.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '571',
#   'http://www.moma.org/collection/works/571',
#   'http://www.moma.org/media/W1siZiIsIjYzNTEiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=2c0ddf128b45c500',
#   '',
#   '',
#   '',
#   '15.2',
#   '',
#   '',
#   '54.3',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '12 x 16" (30.5 x 40.6 cm)',
#   'Gift of the architect',
#   '409.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '572',
#   'http://www.moma.org/collection/works/572',
#   'http://www.moma.org/media/W1siZiIsIjYzNTIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=f936128698de46a5',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '40.6',
#   '',
#   ''],
#  ['First Unitarian Church and School, Rochester, New York, Final version: elevation',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1961',
#   'Graphite on tracing paper',
#   '17 3/4 x 29 1/8" (45.1 x 74 cm)',
#   'Gift of the architect',
#   '410.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '573',
#   'http://www.moma.org/collection/works/573',
#   'http://www.moma.org/media/W1siZiIsIjY0MjYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=9e6263de2e12b35e',
#   '',
#   '',
#   '',
#   '15.2',
#   '',
#   '',
#   '40.6',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '9 x 17 5/8" (22.9 x 44.8 cm)',
#   'Gift of the architect',
#   '410.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '574',
#   'http://www.moma.org/collection/works/574',
#   'http://www.moma.org/media/W1siZiIsIjY0MjciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=5cc7e12a8d8306ad',
#   '',
#   '',
#   '',
#   '22.9',
#   '',
#   '',
#   '44.8',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1964',
#   'Charcoal and graphite on tracing paper',
#   '12 x 22 3/4" (30.5 x 57.8 cm)',
#   'Gift of the architect',
#   '411.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '576',
#   'http://www.moma.org/collection/works/576',
#   'http://www.moma.org/media/W1siZiIsIjY0NDIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=314a88d2dd13c64f',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '57.8',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '12 x 17 1/4" (30.5 x 43.8 cm)',
#   'Gift of the architect',
#   '412.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '578',
#   'http://www.moma.org/collection/works/578',
#   'http://www.moma.org/media/W1siZiIsIjY0NjUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=fc8c70eed4bfeb01',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '43.8',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '12 1/8 x 22 5/8" (30.8 x 57.5 cm)',
#   'Gift of the architect',
#   '413.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '580',
#   'http://www.moma.org/collection/works/580',
#   'http://www.moma.org/media/W1siZiIsIjY0NzgiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=98ae1e0c42994258',
#   '',
#   '',
#   '',
#   '30.8',
#   '',
#   '',
#   '57.5',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Plan sketch of Prayer Hall',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '12 x 20" (30.5 x 50.8 cm)',
#   'Gift of the architect',
#   '414.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '582',
#   'http://www.moma.org/collection/works/582',
#   'http://www.moma.org/media/W1siZiIsIjY0OTMiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=dd4bf4fce1eafc24',
#   '',
#   '',
#   '',
#   '30.4801',
#   '',
#   '',
#   '50.8001',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '12 x 16" (30.5 x 40.6 cm)',
#   'Gift of the architect',
#   '415.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '584',
#   'http://www.moma.org/collection/works/584',
#   'http://www.moma.org/media/W1siZiIsIjY1MDkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=8213b2b22ca8feab',
#   '',
#   '',
#   '',
#   '30.5',
#   '',
#   '',
#   '40.6',
#   '',
#   ''],
#  ["General Motors Exhibit, 1964 World's Fair, project, New York (Queens), New York, Elevation and plans",
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1961',
#   'Ink on tracing paper',
#   '12 x 21 3/4" (30.5 x 55.2 cm)',
#   'Gift of the architect',
#   '416.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '585',
#   'http://www.moma.org/collection/works/585',
#   'http://www.moma.org/media/W1siZiIsIjY1MjQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=d97ce51d24ad9bbe',
#   '',
#   '',
#   '',
#   '19.1',
#   '',
#   '',
#   '41.9',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Prayer Hall: plan sketch',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1965',
#   'Charcoal on tracing paper',
#   '12 1/8 x 17 3/8" (30.8 x 44.1 cm)',
#   'Gift of the architect',
#   '416.1967',
#   'Architecture',
#   'Architecture & Design',
#   '1967-04-11',
#   'Y',
#   '586',
#   'http://www.moma.org/collection/works/586',
#   'http://www.moma.org/media/W1siZiIsIjY1MjUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=10fea7cd6d2f83b7',
#   '',
#   '',
#   '',
#   '30.8',
#   '',
#   '',
#   '44.1',
#   '',
#   ''],
#  ['Salk Institute for Biological Studies (laboratory, meeting house, and housing), La Jolla, California, Two elevations of meeting house',
#   'Louis I. Kahn',
#   '2964',
#   '(American, born Estonia. 1901–1974)',
#   '(American)',
#   '(1901)',
#   '(1974)',
#   '(Male)',
#   '1960',
#   'Ink and graphite on tracing paper',
#   '12 x 24 11/16" (30.5 x 62.7 cm)',
#   'Gift of the architect',
#   '417.1964',
#   'Architecture',
#   'Architecture & Design',
#   '1964-04-14',
#   'Y',
#   '587',
#   'http://www.moma.org/collection/works/587',
#   'http://www.moma.org/media/W1siZiIsIjY1MzgiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=c15338dc29452c3e',
#   '',
#   '',
#   '',
#   '17.7',
#   '',
#   '',
#   '46.3',
#   '',
#   ''],
#  ['Sher-e-Bangla Nagar, Capital of Bangladesh, Dhaka, Bangladesh, Perspective of hostels',
# ...
#   '24 x 36" (61 x 91.4 cm)',
#   'Gift of Push Pin Studios',
#   '1127.1969',
#   'Design',
#   'Architecture & Design',
#   '1969-12-01',
#   'Y',
#   '8602',
#   'http://www.moma.org/collection/works/8602',
#   'http://www.moma.org/media/W1siZiIsIjExNDE3Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=f2f96d7ed215ad11',
#   '',
#   '',
#   '',
#   '60.9601219202',
#   '',
#   '',
#   '91.4401828804',
#   '',
#   ''],
#  ['Visuele Communicatie Nederland, Stedelijk Museum Amsterdam',
#   'Wim Crouwel',
#   '1314',
#   '(Dutch, born 1928)',
#   '(Dutch)',
#   '(1928)',
#   '(0)',
#   '(Male)',
#   '1969',
#   'Offset lithograph',
#   '37 5/16 x 25 1/2" (94.8 x 64.8 cm)',
#   'Gift of the designer',
#   '1128.1969',
#   'Design',
#   'Architecture & Design',
#   '1969-12-01',
#   'Y',
#   '8604',
#   'http://www.moma.org/collection/works/8604',
#   'http://www.moma.org/media/W1siZiIsIjExNDE5Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=0d1866c192289f13',
#   '',
#   '',
#   '',
#   '94.8',
#   '',
#   '',
#   '64.8',
#   '',
#   ''],
#  ['Olivetti: Diseño y Productos',
#   'Juan Carlos Distéfano, Rubén Fontana, Carlos Soler',
#   '1556, 1931, 5515',
#   '(Argentine, born 1933) (Argentine, born 1942) (Argentine)',
#   '(Argentine) (Argentine) (Argentine)',
#   '(1933) (1942) (0)',
#   '(0) (0) (0)',
#   '(Male) (Male) (Male)',
#   '1967',
#   'Offset lithograph',
#   '28 1/2 x 42 1/2" (72 x 107 cm)',
#   'Gift of the designers',
#   '1129.1969',
#   'Design',
#   'Architecture & Design',
#   '1969-12-01',
#   'Y',
#   '8606',
#   'http://www.moma.org/collection/works/8606',
#   'http://www.moma.org/media/W1siZiIsIjIxMTk4MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=e3268ade81bcfb5a',
#   '',
#   '',
#   '',
#   '72.0',
#   '',
#   '',
#   '107.0',
#   '',
#   ''],
#  ['Le Park - Gran Premio de Pintura, XXXIII Bienal de Venecia 1966',
#   'Juan Carlos Distéfano, Rubén Fontana, Carlos Soler',
#   '1556, 1931, 5515',
#   '(Argentine, born 1933) (Argentine, born 1942) (Argentine)',
#   '(Argentine) (Argentine) (Argentine)',
#   '(1933) (1942) (0)',
#   '(0) (0) (0)',
#   '(Male) (Male) (Male)',
#   '1967',
#   'Offset lithograph',
#   '28 1/2 x 43" (72.4 x 109.2 cm)',
#   'Gift of the designers',
#   '1130.1969',
#   'Design',
#   'Architecture & Design',
#   '1969-12-01',
#   'Y',
#   '8608',
#   'http://www.moma.org/collection/works/8608',
#   '',
#   '',
#   '0.0',
#   '',
#   '72.3901447803',
#   '',
#   '',
#   '109.2202184404',
#   '',
#   ''],
#  ['Premio di Tella',
#   'Juan Carlos Distéfano, Rubén Fontana, Carlos Soler',
#   '1556, 1931, 5515',
#   '(Argentine, born 1933) (Argentine, born 1942) (Argentine)',
#   '(Argentine) (Argentine) (Argentine)',
#   '(1933) (1942) (0)',
#   '(0) (0) (0)',
#   '(Male) (Male) (Male)',
#   '1967',
#   'Offset lithograph',
#   '28 1/2 x 43 1/4" (72.4 x 109.9 cm)',
#   'Gift of the designers',
#   '1131.1969',
#   'Design',
#   'Architecture & Design',
#   '1969-12-01',
#   'Y',
#   '8610',
#   'http://www.moma.org/collection/works/8610',
#   'http://www.moma.org/media/W1siZiIsIjExNDI0Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=0fb41c3c5e2de51c',
#   '',
#   '',
#   '',
#   '72.4',
#   '',
#   '',
#   '109.9',
#   '',
#   ''],
#  ['Richard Bernstein, Galerie Kunsthandel Monet, Rokin 97, Amsterdam',
#   'Richard Bernstein',
#   '520',
#   '(American, 1939–2002)',
#   '(American)',
#   '(1939)',
#   '(2002)',
#   '(Male)',
#   '1967',
#   'Silkscreen',
#   '',
#   'Gift of the designer',
#   '1271.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'N',
#   '8721',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Visitez le Nouveau Quebec',
#   'Vittorio Fiorucci',
#   '1881',
#   '(Canadian, born Italy 1931)',
#   '(Canadian)',
#   '(1931)',
#   '(0)',
#   '(Male)',
#   '1967',
#   'Silkscreen',
#   '35 x 25" (88.9 x 63.5 cm)',
#   'Gift of the Triton Gallery',
#   '1272.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8722',
#   'http://www.moma.org/collection/works/8722',
#   'http://www.moma.org/media/W1siZiIsIjExNjk4Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=218a149eae8fd50b',
#   '',
#   '',
#   '',
#   '88.9002',
#   '',
#   '',
#   '63.5001',
#   '',
#   ''],
#  ["Exposition internationale d'art pornographique",
#   'Vittorio Fiorucci',
#   '1881',
#   '(Canadian, born Italy 1931)',
#   '(Canadian)',
#   '(1931)',
#   '(0)',
#   '(Male)',
#   '1967',
#   'Silkscreen',
#   '35 1/16 x 25" (89 x 63.5 cm)',
#   'Gift of the Triton Gallery',
#   '1273.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8723',
#   'http://www.moma.org/collection/works/8723',
#   '',
#   '',
#   '0.0',
#   '',
#   '89.0',
#   '',
#   '',
#   '63.5',
#   '',
#   ''],
#  ["Théâtre Alpha 347 - Il n'y aura plus d'arbres (There Won't Be Anymore Trees)",
#   'Jean-Michel Folon',
#   '1927',
#   '(Belgian, born 1934)',
#   '(Belgian)',
#   '(1934)',
#   '(0)',
#   '(Male)',
#   '1968',
#   'Poster',
#   '',
#   'Gift of the designer',
#   '1274.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'N',
#   '8724',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Punctum 7 Serigraphien - Mavignier - Galerie der Spiegel, 1966',
#   'Almir Mavignier',
#   '3858',
#   '(Brazilian, born 1925)',
#   '(Brazilian)',
#   '(1925)',
#   '(0)',
#   '(Male)',
#   '1966',
#   'Screenprint',
#   '',
#   'Gift of the designer',
#   '1277.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'N',
#   '8727',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Deutsches Museum',
#   'Almir Mavignier',
#   '3858',
#   '(Brazilian, born 1925)',
#   '(Brazilian)',
#   '(1925)',
#   '(0)',
#   '(Male)',
#   '1967',
#   'Offset lithograph',
#   '33 1/16 x 23 1/4" (84 x 59 cm)',
#   'Gift of the artist',
#   '1278.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8728',
#   'http://www.moma.org/collection/works/8728',
#   'http://www.moma.org/media/W1siZiIsIjExNzAxIl0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=5c1c6273180a6408',
#   '',
#   '0.0',
#   '',
#   '84.0',
#   '',
#   '',
#   '59.0',
#   '',
#   ''],
#  ['International Poetry Forum, Three Young Poets',
#   'Steve Poleskie',
#   '4668',
#   '(American, born 1938)',
#   '(American)',
#   '(1938)',
#   '(0)',
#   '(Male)',
#   '1968',
#   'Lithograph',
#   '',
#   'Gift of the designer',
#   '1279.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8729',
#   'http://www.moma.org/collection/works/8729',
#   'http://www.moma.org/media/W1siZiIsIjExNzAyIl0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=3116e340981893fb',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['4 Konzerte',
#   'Hans Jurgen Spohn',
#   '5570',
#   '(German, born 1934)',
#   '(German)',
#   '(1934)',
#   '(0)',
#   '(Male)',
#   '1967',
#   'Poster',
#   '',
#   'Gift of the designer',
#   '1280.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'N',
#   '8730',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Zwiedzajcie Zoo',
#   'Waldemar Swierzy',
#   '5753',
#   '(Polish, born 1931)',
#   '(Polish)',
#   '(1931)',
#   '(0)',
#   '(Male)',
#   '1967',
#   'Offset lithograph',
#   '26 3/8 x 38 3/16" (67 x 97 cm)',
#   'Gift of the Triton Gallery',
#   '1281.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8731',
#   'http://www.moma.org/collection/works/8731',
#   'http://www.moma.org/media/W1siZiIsIjIwOTU4NyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=567d8f5fcf067d53',
#   '',
#   '0.0',
#   '',
#   '67.0',
#   '',
#   '',
#   '97.0',
#   '',
#   ''],
#  ['Musica Viva',
#   'Walter Tafelmaier',
#   '5778',
#   '(German, born 1935)',
#   '(German)',
#   '(1935)',
#   '(0)',
#   '(Male)',
#   '1965',
#   'Offset lithograph',
#   '',
#   'Gift of the designer',
#   '1282.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8732',
#   'http://www.moma.org/collection/works/8732',
#   'http://www.moma.org/media/W1siZiIsIjExNzA1Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=28caeff65527ed74',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Musica Viva',
#   'Walter Tafelmaier',
#   '5778',
#   '(German, born 1935)',
#   '(German)',
#   '(1935)',
#   '(0)',
#   '(Male)',
#   '1966',
#   'Offset lithograph',
#   '',
#   'Gift of the designer',
#   '1283.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'N',
#   '8733',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Stedelijk Museum Amsterdam, 5 April t/m 23 Juni 1968, Vorm Gevers',
#   'Wim Crouwel',
#   '1314',
#   '(Dutch, born 1928)',
#   '(Dutch)',
#   '(1928)',
#   '(0)',
#   '(Male)',
#   '1968',
#   'Offset lithograph',
#   '37 3/16 x 24 15/16" (95.1 x 63.4 cm)',
#   'Gift of the designer',
#   '1285.1968',
#   'Design',
#   'Architecture & Design',
#   '1968-10-07',
#   'Y',
#   '8735',
#   'http://www.moma.org/collection/works/8735',
#   'http://www.moma.org/media/W1siZiIsIjIxMjAxMyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=d284786ab49aa136',
#   '',
#   '',
#   '',
#   '95.1',
#   '',
#   '',
#   '63.4',
#   '',
#   ''],
#  ['The Wildflower',
#   'Victor Moscoso',
#   '4117',
#   '(American, born Spain 1936)',
#   '(American)',
#   '(1936)',
#   '(0)',
#   '(Male)',
#   '1967',
#   'Lithographs',
#   'each: 20 1/16 x 14 1/8" (50.9 x 35.9 cm)',
#   'Gift of the designer',
#   '1439.2000.1-2',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8738',
#   'http://www.moma.org/collection/works/8738',
#   'http://www.moma.org/media/W1siZiIsIjMzOTQ0NCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=8966f4cb28538f3c',
#   '',
#   '',
#   '',
#   '50.9',
#   '',
#   '',
#   '35.9',
#   '',
#   ''],
#  ['Quick Silver Messenger Service, Big Brother & The Holding Co., Country Joe & The Fish',
#   'Victor Moscoso',
#   '4117',
#   '(American, born Spain 1936)',
#   '(American)',
#   '(1936)',
#   '(0)',
#   '(Male)',
#   '1966',
#   'Lithograph',
#   '20 1/8 x 14 1/4" (51.1 x 36.2 cm)',
#   'Gift of the designer',
#   '1440.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8739',
#   'http://www.moma.org/collection/works/8739',
#   'http://www.moma.org/media/W1siZiIsIjExNzgwIl0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=dcad0416524ccbec',
#   '',
#   '',
#   '',
#   '51.1',
#   '',
#   '',
#   '36.2',
#   '',
#   ''],
#  ['Ringo Starr',
#   'Richard Avedon',
#   '248',
#   '(American, 1923–2004)',
#   '(American)',
#   '(1923)',
#   '(2004)',
#   '(Male)',
#   '1967',
#   'Lithograph',
#   '31 1/8 x 22 1/2" (79.1 x 57.2 cm)',
#   'Gift of the designer',
#   '1441.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8740',
#   'http://www.moma.org/collection/works/8740',
#   'http://www.moma.org/media/W1siZiIsIjExNzgxIl0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=78495f9d985ff825',
#   '',
#   '',
#   '',
#   '79.1',
#   '',
#   '',
#   '57.2',
#   '',
#   ''],
#  ['Paul McCartney',
#   'Richard Avedon',
#   '248',
#   '(American, 1923–2004)',
#   '(American)',
#   '(1923)',
#   '(2004)',
#   '(Male)',
#   '1967',
#   'Lithograph',
#   '31 1/8 x 22 1/2" (79.1 x 57.2 cm)',
#   'Gift of the designer',
#   '1442.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8741',
#   'http://www.moma.org/collection/works/8741',
#   'http://www.moma.org/media/W1siZiIsIjExNzgzIl0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=cb7102a97faa13b5',
#   '',
#   '',
#   '',
#   '79.1',
#   '',
#   '',
#   '57.2',
#   '',
#   ''],
#  ['George Harrison',
#   'Richard Avedon',
#   '248',
#   '(American, 1923–2004)',
#   '(American)',
#   '(1923)',
#   '(2004)',
#   '(Male)',
#   '1967',
#   'Lithograph',
#   '31 1/8 x 22 1/2" (79.1 x 57.2 cm)',
#   'Gift of the designer',
#   '1443.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8742',
#   'http://www.moma.org/collection/works/8742',
#   'http://www.moma.org/media/W1siZiIsIjExNzg1Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=8d353b0fec495e81',
#   '',
#   '',
#   '',
#   '79.1',
#   '',
#   '',
#   '57.2',
#   '',
#   ''],
#  ['Objevy v tasili (Discoveries in Drawing) (Poster for exhibition of fresco copies in the Náprstkovo Muzeum, Prague)',
#   'Josef Flejšar',
#   '8273',
#   '(Czech, 1922–2010)',
#   '(Czech)',
#   '(1922)',
#   '(2010)',
#   '(Male)',
#   '1962',
#   'Lithograph',
#   '32 3/4 x 22 3/4" (83.2 x 57.8 cm)',
#   'Gift of the designer',
#   '1468.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8767',
#   'http://www.moma.org/collection/works/8767',
#   'http://www.moma.org/media/W1siZiIsIjExODE3Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=4e2c6c54a628126f',
#   '',
#   '',
#   '',
#   '83.1852',
#   '',
#   '',
#   '57.7851',
#   '',
#   ''],
#  ['Proces (The Trial) (Poster for the Czechoslovak release of the 1962 film directed by Orson Welles)',
#   'Zdenĕk Ziegler',
#   '8274',
#   '(Czech, born 1932)',
#   '(Czech)',
#   '(1932)',
#   '(0)',
#   '(Male)',
#   '1962',
#   'Lithograph',
#   '32 9/16 x 22 15/16" (82.7 x 58.3 cm)',
#   'Gift of the designer',
#   '1469.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8768',
#   'http://www.moma.org/collection/works/8768',
#   'http://www.moma.org/media/W1siZiIsIjExODE4Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=8d428ed9e6d82f93',
#   '',
#   '',
#   '',
#   '82.7',
#   '',
#   '',
#   '58.3',
#   '',
#   ''],
#  ['La Biennale di Venezia',
#   'A. G. Fronzoni',
#   '2017',
#   '(Italian, 1923–2002)',
#   '(Italian)',
#   '(1923)',
#   '(2002)',
#   '(Male)',
#   '1969',
#   'Lithograph',
#   '39 3/8 x 27 9/16" (100 x 70 cm)',
#   'Gift of the designer',
#   '1470.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8769',
#   'http://www.moma.org/collection/works/8769',
#   'http://www.moma.org/media/W1siZiIsIjExODE5Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=8d439514b02d8afc',
#   '',
#   '',
#   '',
#   '100.0',
#   '',
#   '',
#   '70.0',
#   '',
#   ''],
#  ['Silk-Screened Paintings',
#   'Peter Gee',
#   '2106',
#   '(British, born 1932)',
#   '(British)',
#   '(1932)',
#   '(0)',
#   '(Male)',
#   '1969',
#   'Silkscreen',
#   '34 7/8 x 25 3/8" (88.6 x 64.5 cm)',
#   'Gift of the designer',
#   '1471.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8770',
#   'http://www.moma.org/collection/works/8770',
#   '',
#   '',
#   '',
#   '',
#   '88.6',
#   '',
#   '',
#   '64.5',
#   '',
#   ''],
#  ['American Airlines 747 Astroliner',
#   'Peter Gee',
#   '2106',
#   '(British, born 1932)',
#   '(British)',
#   '(1932)',
#   '(0)',
#   '(Male)',
#   '1968',
#   'Lithograph',
#   '40 x 30" (101.6 x 76.2 cm)',
#   'Gift of the designer',
#   '1472.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8771',
#   'http://www.moma.org/collection/works/8771',
#   'http://www.moma.org/media/W1siZiIsIjYyMjE5Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=f3ce6b5711c48e65',
#   '',
#   '',
#   '',
#   '101.6',
#   '',
#   '',
#   '76.2',
#   '',
#   ''],
#  ['Das Kind und Seine Welt',
#   'Jörg Hamburger',
#   '2477',
#   '(Swiss, born 1935)',
#   '(Swiss)',
#   '(1935)',
#   '(0)',
#   '(Male)',
#   '1962',
#   'Lithograph',
#   '50 3/16 x 35 3/8" (127.5 x 89.9 cm)',
#   'Gift of the designer',
#   '1475.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8774',
#   'http://www.moma.org/collection/works/8774',
#   'http://www.moma.org/media/W1siZiIsIjExODIyIl0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=a533abe342996f68',
#   '',
#   '',
#   '',
#   '127.5',
#   '',
#   '',
#   '89.9',
#   '',
#   ''],
#  ['Einspuren - Spur Halten',
#   'Hans Hartmann',
#   '8393',
#   '(Swiss, born 1913)',
#   '(Swiss)',
#   '(1913)',
#   '(0)',
#   '(Male)',
#   '1963',
#   'Photolithograph',
#   '50 1/4 x 35 1/2" (127.6 x 90.2 cm)',
#   'Gift of the designer',
#   '1476.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8775',
#   'http://www.moma.org/collection/works/8775',
#   'http://www.moma.org/media/W1siZiIsIjExODI0Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=c074163c545a4ba6',
#   '',
#   '',
#   '',
#   '127.6',
#   '',
#   '',
#   '90.2',
#   '',
#   ''],
#  ['Aus den Sammlungen des Gewerbe-Museums Basel',
#   'Armin Hofmann',
#   '2697',
#   '(Swiss, born 1920)',
#   '(Swiss)',
#   '(1920)',
#   '(0)',
#   '(Male)',
#   '1964',
#   'Lithograph',
#   '50 1/4 x 35 5/8" (127.6 x 90.5 cm)',
#   'Gift of the designer',
#   '1479.2000',
#   'Design',
#   'Architecture & Design',
#   '2000-12-11',
#   'Y',
#   '8777',
#   'http://www.moma.org/collection/works/8777',
#   'http://www.moma.org/media/W1siZiIsIjExODI1Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=ea99eeace9a8a021',
#   '',
#   '',
#   '',
#   '127.6',
#   '',
#   '',
#   '90.5',
#   '',
#   ''],
#  ...]

# %% [markdown]
# #### Sorting a Table by Column
#
# We can sort a table based on the values in a given column with the `sorted` function and and the `itemgetter` tool, which we use to specify the column we’re sorting by. The following sorts the table `art_1960s` by artist name (i.e., index `1` in each row).

# %%
from operator import itemgetter
art_1960s_sorted = sorted(art_1960s, key = itemgetter(1))

# %% [markdown]
# Since each row is so long, let’s just look at our sorted set of authors. The following notation returns a list of  each row’s “Artist” cell, located at index `1`.

# %%
[row[1] for row in art_1960s_sorted]
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. G. Fronzoni',
#  'A. Gisiger',
#  'A. Michael Noll',
#  'A. Michael Noll',
#  'A. Michael Noll, R.C. Lummis, M. M. Sondhi',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'A.R. Penck (Ralf Winkler)',
#  'AA Bronson, Felix Partz, Jorge Zontal, General Idea',
#  'Aaron Kuriloff',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Aaron Siskind',
#  'Abraham Palatnik',
#  'Abraham Zapruder / Life Magazine, Time Inc.',
#  'Abram Games',
#  'Abram Krol',
#  'Achille Castiglioni, Pier Giacomo Castiglioni',
#  'Achille Castiglioni, Pier Giacomo Castiglioni',
#  'Achille Castiglioni, Pier Giacomo Castiglioni',
#  'Achille Castiglioni, Pier Giacomo Castiglioni, Livio Castiglioni',
#  'Achille Castiglioni, Pier Giacomo Castiglioni, Livio Castiglioni',
#  'Achille Perilli',
#  'Achille Perilli',
#  'Achille Perilli',
#  'Achilles Droungas',
#  'Ad Dekkers',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ad Reinhardt',
#  'Ademar Manarini',
#  'Ademar Manarini',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Adja Yunkers',
#  'Ado Sato',
#  'Adolph Gottlieb',
#  'Adolph Gottlieb',
#  'Adolph Gottlieb',
#  'Adolph Gottlieb',
#  'Adrian Piper',
#  'Adrian Piper',
#  'Adrian Piper',
#  'Adrian Piper',
#  'Adriana Maraz-Bernik',
#  'Afra Scarpa, Tobia Scarpa',
#  'Aftograf',
#  'Agam (Yaacov Agam)',
#  'Agam (Yaacov Agam)',
#  'Agatha Wojciechowsky',
#  'Agatha Wojciechowsky',
#  'Agnes Denes',
#  'Agnes Denes',
#  'Agnes Denes',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnes Martin',
#  'Agnès Varda',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Agustín Fernández',
#  'Ahmed Yacoubi',
#  'Aida Carballo',
#  'Airstream, Inc.',
#  'Akiko Shirai',
#  'Akiko Shirai',
#  'Akiko Shirai',
#  'Akira Matsumoto',
#  'Aktuální umĕni',
#  'Aktuální umĕni, Milan Knížák, Jan Mach, Vit Mach, Sonia Švecová, Jan Trtílek',
#  'Aktuální umĕni, Milan Knížák, Jan Mach, Vit Mach, Sonia Švecová, Jan Trtílek',
#  'Aktuální umĕni, Milan Knížák, Jan Mach, Vit Mach, Sonia Švecová, Jan Trtílek',
#  'Al Corchia',
#  'Al Hansen',
#  'Al Hansen',
#  'Al Heenan',
#  'Al Heenan',
#  'Al Held',
#  'Al Held',
#  'Al Held',
#  'Al Held',
#  'Al Held',
#  'Al Held',
#  'Al Held',
#  'Alain Jacquet',
#  'Alain Jacquet',
#  'Alain Jacquet',
#  'Alain Jacquet',
#  'Alain Resnais',
#  'Alain Resnais',
#  'Alain Resnais',
#  'Alain Resnais',
#  'Alain Tanner',
#  'Alan Cote',
#  'Alan Davie',
#  'Alan Davie',
#  'Alan Davie',
#  'Alan Fletcher',
#  'Alan Saret',
#  'Alan Saret',
#  'Alan Shields',
#  'Alan Shields',
#  'Alan Shields',
#  'Alan Sonfist',
#  'Alan Sonfist',
#  'Alberico Morena',
#  'Albert Lamorisse',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine',
#  'Albert M. Fine, George Maciunas',
#  'Albert Maysles, David Maysles',
#  'Albert Tucker',
#  'Albert York',
#  'Alberto Biasi',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Burri',
#  'Alberto Dutary',
#  'Alberto Dutary',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Giacometti',
#  'Alberto Gironella',
#  'Alberto Gironella',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Greco',
#  'Alberto Magnelli',
#  'Alberto Magnelli',
#  'Alda Maria Armagni',
#  'Aldemir Martins',
#  "Aldo Jacober, Pierangela d'Aniello",
#  'Alejandro Otero',
#  'Alejandro Puente',
#  'Alejandro Puente',
#  'Alejandro Puente',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Aleksandr Archipenko',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alen MacWeeney',
#  'Alena Kucerova',
#  'Alena Kucerova',
#  'Alessandro Blasetti',
#  'Alex Colville',
#  'Alex Colville',
#  'Alex Hay',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Katz',
#  'Alex Lovy',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Calder',
#  'Alexander Dobkin',
#  'Alexander Gonda',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Liberman',
#  'Alexander Semenovitch Shenderov',
#  'Alexander Semenovitch Vedernikov',
#  'Alexander Semenovitch Vedernikov',
#  'Alexander Slussarev',
#  'Alexandra Nikolaevna Jacobson',
#  'Alexei Alexandrovich Tyapushkin',
#  'Alfonso Ossorio',
#  'Alfred Eisenstaedt',
#  'Alfred Hrdlicka',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Jensen',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Leslie',
#  'Alfred Pohl',
#  'Alfred Pohl',
#  'Alfred Reth',
#  'Alfred Winter-Rust',
#  'Alfred Young',
#  'Alfredo Barbini',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Cortina',
#  'Alfredo Rostgaard',
#  'Alfredo Rostgaard',
#  'Alfredo Rostgaard',
#  'Alfredo Rostgaard',
#  'Alfredo Volpi',
#  'Alfredo Volpi',
#  'Alfredo Volpi',
#  'Alfredo Volpi',
#  'Alfredo da Silva',
#  'Alfredo da Silva',
#  'Alice Baber',
#  'Alice Baber',
#  'Alice Hutchins',
#  'Alice Hutchins',
#  'Alice Hutchins',
#  'Alicia Orlandi',
#  'Alicia Orlandi',
#  'Alicia Orlandi',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  'Alighiero Boetti',
#  ...]

# %% [markdown]
# Let's look at the most common nationalities in our table of 1960s artworks. Here we’re once again using the `Counter` constructor from the `collections` package.

# %%
c = Counter([row[4] for row in art_1960s_sorted])
c.most_common(20)
# Out:
# [('(American)', 10783),
#  ('(French)', 1414),
#  ('(German)', 964),
#  ('(British)', 816),
#  ('(Italian)', 767),
#  ('(Japanese)', 732),
#  ('', 418),
#  ('(Spanish)', 321),
#  ('()', 264),
#  ('(Argentine)', 258),
#  ('(Swiss)', 251),
#  ('(Belgian)', 218),
#  ('(Venezuelan)', 200),
#  ('(Chilean)', 195),
#  ('(American) (American)', 187),
#  ('(Brazilian)', 185),
#  ('(Dutch)', 181),
#  ('(Mexican)', 158),
#  ('(Russian)', 155),
#  ('(Czech)', 148)]

# %% [markdown]
# It’s impossible to memorize the details of every specialized tool available in Python, so you’ll probably end up repeatedly looking up processes like these.

# %% [markdown]
# #### Writing CSVs
# Now that we’ve filtered and sorted our metadata, let’s export it to a new CSV file called `art_1960s.csv`.

# %%
outpath = "/sharedfolder/art_1960s.csv"
with open(outpath, 'w') as fo:
    csv_writer = csv.writer(fo)
    csv_writer.writerow(artwork_header)
    csv_writer.writerows(art_1960s_sorted)

# %% [markdown]
# Note that we call use `writerow` function first to write the header row, then `writerows` to write the actual data.

# %% [markdown]
# Find the new file in `sharedfolder` and open it in Excel or LibreOffice. Take a few moments to explore the collection.

# %% [markdown]
# #### The Dictionary Data Type
#
# So far, when we want to access the “Artist” field in MoMA’s metadata, we’ve been referring to its position in a given row.

# %%
row = art_1960s_sorted[7700]
row[1]
# Out:
# 'Günter Brus'

# %% [markdown]
# This system is straightforward and well-suited for many jobs, but for large, complex projects it can be difficult to keep track of all those index numbers. Instead, we can use a dictionary to reference metadata fields by name rather than list index.
#
# Just like we can refer to a item in a list using brackets to enclose its position in the list, a dictionary, or dict, uses any chosen string or number to identify a value in a collection. This data structure is known as a key-value pair. Here’s the simplest way to create a new dictionary.

# %%
artist_meta = {}
artist_meta['ConstituentID'] = 248
artist_meta['DisplayName'] = 'Richard Avedon'
artist_meta['ArtistBio'] = 'American, 1923–2004'
artist_meta['Nationality'] = 'American'
artist_meta['Gender'] = 'Male'
artist_meta['BeginDate'] = 1923
artist_meta['EndDate'] = 2004
artist_meta['Wiki QID'] = 'Q305497'
artist_meta['ULAN'] = '500013773'

# %% [markdown]
# The following is a more compact format for the same key-value assignment.

# %%
artist_meta = {'ConstituentID': 248, 'DisplayName': 'Richard Avedon', 'Gender': 'Male', 'BeginDate': 1923, 'EndDate': 2004, 'ULAN': '500013773', 'Wiki QID': 'Q305497', 'ArtistBio': 'American, 1923–2004', 'Nationality': 'American'}

# %% [markdown]
# To access a value, enter its key between brackets like so.

# %%
artist_meta['DisplayName']
# Out:
# 'Richard Avedon'

# %% [markdown]
# And note that you can iterate over a dict to view and/or use its keys.

# %%
for key in artist_meta:
    print(key + " - " + str(artist_meta[key]))
# Out:
# ArtistBio - American, 1923–2004
# Nationality - American
# ULAN - 500013773
# BeginDate - 1923
# DisplayName - Richard Avedon
# Gender - Male
# EndDate - 2004
# ConstituentID - 248
# Wiki QID - Q305497

# %% [markdown]
# Next, let’s create a dict for each artist MoMA’s artist metadata. Here’s a snippet (repeated from above) that loads `Artists.csv` as a list of lists called `artist_table`.

# %%
import csv

artist_csv_path = "/sharedfolder/Artists.csv"
artist_table = []

with open(artist_csv_path) as fi:
    csv_input = csv.reader(fi)
    for row in csv_input:
        artist_table.append(row)

artist_header = artist_table[0]
artist_table.remove(artist_table[0])

artist_header
# Out:
# ['\ufeffConstituentID',
#  'DisplayName',
#  'ArtistBio',
#  'Nationality',
#  'Gender',
#  'BeginDate',
#  'EndDate',
#  'Wiki QID',
#  'ULAN']

# %% [markdown]
# Now we’ll use a for loop to iterate through `artist_table`, converting each list of cells to key-value format.

# %%
artist_dicts = []

for row in artist_table:
    artist_meta = {}
    artist_meta['ConstituentID'] = row[0]
    artist_meta['DisplayName'] = row[1]
    artist_meta['ArtistBio'] = row[2]
    artist_meta['Nationality'] = row[3]
    artist_meta['Gender'] = row[4]
    artist_meta['BeginDate'] = int(row[5])
    artist_meta['EndDate'] = int(row[6])
    artist_meta['Wiki QID'] = row[7]
    artist_meta['ULAN'] = row[8]
    artist_dicts.append(artist_meta)

# %% [markdown]
# The list `artist_dicts` should now contain records for about 15,000 artists.

# %%
len(artist_dicts)
# Out:
# 15228

# %% [markdown]
# Specifying an index in brackets will return a dict object.

# %%
artist_dicts[12007]
# Out:
# {'ArtistBio': 'Swedish, born 1979',
#  'BeginDate': 1979,
#  'ConstituentID': '35986',
#  'DisplayName': 'Klara Liden',
#  'EndDate': 0,
#  'Gender': 'Female',
#  'Nationality': 'Swedish',
#  'ULAN': '',
#  'Wiki QID': 'Q513343'}

# %% [markdown]
# And we can use one of our standard key names to get a particular value.

# %%
artist_dicts[12007]['DisplayName']
# Out:
# 'Klara Liden'

# %% [markdown]
# If we want to create a list of artist names, birth years, etc., we can thus iterate through the `artists_dicts` list and specify the field we want by name.

# %% [markdown]
# #### Working with JSON
# JSON data is a representation of key-value pairs, very much like a dictionary in Python. For the following example we’ll download a JSON version of the artwork metadata we’ve been working with.

# %%
import json
from urllib.request import urlopen

url = "https://media.githubusercontent.com/media/MuseumofModernArt/collection/master/Artworks.json?raw=true"
json_string = urlopen(url).read().decode('utf8')
json_data = json.loads(json_string)

# %% [markdown]
# To view JSON data (as well as dictionaries and just about any other data format), Python offers a “pretty printer” module. Here we are viewing the first 200 artworks in the metadata set.
#
# There are also numerous online tools for prettifying JSON data, such as [these](http://jsonviewer.stack.hu/) [two](http://json.parser.online.fr/beta/).

# %%
from pprint import pprint

pprint(json_data[:200])
# Out:
# [{'AccessionNumber': '885.1996',
#   'Artist': ['Otto Wagner'],
#   'ArtistBio': ['Austrian, 1841–1918'],
#   'BeginDate': [1841],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6210],
#   'CreditLine': 'Fractional and promised gift of Jo Carole and Ronald S. '
#                 'Lauder',
#   'Date': '1896',
#   'DateAcquired': '1996-04-09',
#   'Department': 'Architecture & Design',
#   'Dimensions': '19 1/8 x 66 1/2" (48.6 x 168.9 cm)',
#   'EndDate': [1918],
#   'Gender': ['Male'],
#   'Height (cm)': 48.6,
#   'Medium': 'Ink and cut-and-pasted painted pages on paper',
#   'Nationality': ['Austrian'],
#   'ObjectID': 2,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjU5NDA1Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=137b8455b1ec6167',
#   'Title': 'Ferdinandsbrücke Project, Vienna, Austria, Elevation, preliminary '
#            'version',
#   'URL': 'http://www.moma.org/collection/works/2',
#   'Width (cm)': 168.9},
#  {'AccessionNumber': '1.1995',
#   'Artist': ['Christian de Portzamparc'],
#   'ArtistBio': ['French, born 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7470],
#   'CreditLine': 'Gift of the architect in honor of Lily Auchincloss',
#   'Date': '1987',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '16 x 11 3/4" (40.6 x 29.8 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 40.6401,
#   'Medium': 'Paint and colored pencil on print',
#   'Nationality': ['French'],
#   'ObjectID': 3,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjk3Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=55b65fa4368fe00a',
#   'Title': 'City of Music, National Superior Conservatory of Music and Dance, '
#            'Paris, France, View from interior courtyard',
#   'URL': 'http://www.moma.org/collection/works/3',
#   'Width (cm)': 29.8451},
#  {'AccessionNumber': '1.1997',
#   'Artist': ['Emil Hoppe'],
#   'ArtistBio': ['Austrian, 1876–1957'],
#   'BeginDate': [1876],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7605],
#   'CreditLine': 'Gift of Jo Carole and Ronald S. Lauder',
#   'Date': '1903',
#   'DateAcquired': '1997-01-15',
#   'Department': 'Architecture & Design',
#   'Dimensions': '13 1/2 x 12 1/2" (34.3 x 31.8 cm)',
#   'EndDate': [1957],
#   'Gender': ['Male'],
#   'Height (cm)': 34.3,
#   'Medium': 'Graphite, pen, color pencil, ink, and gouache on tracing paper',
#   'Nationality': ['Austrian'],
#   'ObjectID': 4,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjk4Il0sWyJwIiwiY29udmVydCIsIi1yZXNpemUgMzAweDMwMFx1MDAzZSJdXQ.jpg?sha=fdcfca4db3acac1f',
#   'Title': 'Villa near Vienna Project, Outside Vienna, Austria, Elevation',
#   'URL': 'http://www.moma.org/collection/works/4',
#   'Width (cm)': 31.8},
#  {'AccessionNumber': '2.1995',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '20 x 20" (50.8 x 50.8 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 50.8,
#   'Medium': 'Photographic reproduction with colored synthetic laminate',
#   'Nationality': [],
#   'ObjectID': 5,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjEyNCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=c89b9071486760a5',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, '
#            'Introductory panel to Episode 1: The Park',
#   'URL': 'http://www.moma.org/collection/works/5',
#   'Width (cm)': 50.8},
#  {'AccessionNumber': '2.1997',
#   'Artist': ['Emil Hoppe'],
#   'ArtistBio': ['Austrian, 1876–1957'],
#   'BeginDate': [1876],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7605],
#   'CreditLine': 'Gift of Jo Carole and Ronald S. Lauder',
#   'Date': '1903',
#   'DateAcquired': '1997-01-15',
#   'Department': 'Architecture & Design',
#   'Dimensions': '15 1/8 x 7 1/2" (38.4 x 19.1 cm)',
#   'EndDate': [1957],
#   'Gender': ['Male'],
#   'Height (cm)': 38.4,
#   'Medium': 'Graphite, color pencil, ink, and gouache on tracing paper',
#   'Nationality': ['Austrian'],
#   'ObjectID': 6,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjEyNiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=b21f3d10def77da9',
#   'Title': 'Villa, project, outside Vienna, Austria, Exterior perspective',
#   'URL': 'http://www.moma.org/collection/works/6',
#   'Width (cm)': 19.1},
#  {'AccessionNumber': '3.1995.1',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 7,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE0OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=66fd4135e60693d0',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/7',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.1-24',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': 'Each: 14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photographs',
#   'Nationality': [],
#   'ObjectID': 8,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE0OSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=e57fc281da1e6a83',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/8',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.10',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 9,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE0OSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=e57fc281da1e6a83',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/9',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.11',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 10,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1MCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=c63ba008a6d5b139',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/10',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.12',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 11,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1MSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=13e9436b6bfdcb6e',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/11',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.13',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 12,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=6e1527eb9b09450e',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/12',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.14',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 13,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1NCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=9a7e91e26cc070d3',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/13',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.15',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 14,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1NSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=928404313b6e327a',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/14',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.16',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 15,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1NiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=92e86c4dda40db51',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/15',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.17',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 16,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1NyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=10298a6fdd0a3f8b',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/16',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.18',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 17,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=6298badad2083963',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/17',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.19',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 18,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE1OSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=812f8374417397f7',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/18',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.2',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 19,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2MCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=853a4c12a1f866b3',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/19',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.20',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 20,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2MSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=7d969f2f0f338021',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/20',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.21',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 21,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=71cc02520546adeb',
#   'Title': 'The Manhattan Transcripts Project, New York, New York , Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/21',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.22',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 22,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=d139e20bbc4aa0bb',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/22',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.23',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 23,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2NCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=16ccf1f79cb2603a',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/23',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.24',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 24,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2NSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=5d556407eb094641',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/24',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.3',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 25,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2NiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=18a8385ca7cdd4e7',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/25',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.4',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 26,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2NyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=449672fc7f320c11',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/26',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.5',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 27,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=12696ff274c2d075',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/27',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.6',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 28,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE2OSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=b03e29eaf9015560',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/28',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.7',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 29,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE3MCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=c79937bf4be17dd4',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/29',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.8',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 30,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE3MSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=983ec471f7b9bf38',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/30',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1995.9',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1976-77',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '14 x 18" (35.6 x 45.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 35.6,
#   'Medium': 'Gelatin silver photograph',
#   'Nationality': [],
#   'ObjectID': 31,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE3MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=8dc2b1702f1cc928',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 1: '
#            'The Park',
#   'URL': 'http://www.moma.org/collection/works/31',
#   'Width (cm)': 45.7},
#  {'AccessionNumber': '3.1997',
#   'Artist': ['Louis I. Kahn'],
#   'ArtistBio': ['American, born Estonia. 1901–1974'],
#   'BeginDate': [1901],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [2964],
#   'CreditLine': 'Purchase',
#   'Date': '1968',
#   'DateAcquired': '1997-01-15',
#   'Department': 'Architecture & Design',
#   'Dimensions': '44 1/2 x 66" (113 x 167.6 cm)',
#   'EndDate': [1974],
#   'Gender': ['Male'],
#   'Height (cm)': 113.0,
#   'Medium': 'Charcoal and graphite on tracing paper',
#   'Nationality': ['American'],
#   'ObjectID': 32,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjE3MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=84cc6597561b2de4',
#   'Title': 'Memorial to the Six Million Jewish Martyrs, project, New York '
#            'City, New York, Perspective of central pier',
#   'URL': 'http://www.moma.org/collection/works/32',
#   'Width (cm)': 167.6},
#  {'AccessionNumber': '4.1995',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '20 x 20" (50.8 X 50.8 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 50.8,
#   'Medium': 'Photographic reproduction with colored synthetic laminate',
#   'Nationality': [],
#   'ObjectID': 33,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjIwMCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=6eac24bddfbd6e80',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, '
#            'Introductory panel to Episode 2: The Street (Border Crossing)',
#   'URL': 'http://www.moma.org/collection/works/33',
#   'Width (cm)': 50.8},
#  {'AccessionNumber': '4.1997',
#   'Artist': ['Marcel Kammerer'],
#   'ArtistBio': ['Austrian, 1878–1969'],
#   'BeginDate': [1878],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7607],
#   'CreditLine': 'Gift of Jo Carole and Ronald S. Lauder',
#   'Date': '1900',
#   'DateAcquired': '1997-01-15',
#   'Department': 'Architecture & Design',
#   'Dimensions': '18 7/8 x 12 3/8" (47.9 x 31.4 cm)',
#   'EndDate': [1969],
#   'Gender': ['Male'],
#   'Height (cm)': 47.9,
#   'Medium': 'Ink, graphite, watercolor, gouache, and airbrush on paper',
#   'Nationality': ['Austrian'],
#   'ObjectID': 34,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjIwMiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=0cfad4657585b97a',
#   'Title': 'Royal Hunting Tent, project, Exterior perspective',
#   'URL': 'http://www.moma.org/collection/works/34',
#   'Width (cm)': 31.4},
#  {'AccessionNumber': '5.1995',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1978',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '24 x 322" (61 x 817.9 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 60.9601,
#   'Medium': 'Ink, charcoal, graphite, cut-and-pasted photographic '
#             'reproductions, Letraset type, and color pencil on tracing paper',
#   'Nationality': [],
#   'ObjectID': 35,
#   'ThumbnailURL': None,
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 2: '
#            'The Street (Border Crossing)',
#   'URL': 'http://www.moma.org/collection/works/35',
#   'Width (cm)': 817.8816},
#  {'AccessionNumber': '5.1997',
#   'Artist': ['Otto Schönthal'],
#   'ArtistBio': ['Austrian, 1878–1961'],
#   'BeginDate': [1878],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7608],
#   'CreditLine': 'Gift of Jo Carole and Ronald S. Lauder',
#   'Date': '1905',
#   'DateAcquired': '1997-01-15',
#   'Department': 'Architecture & Design',
#   'Dimensions': '12 x 8 1/2" (30.5 x 21.6 cm)',
#   'EndDate': [1961],
#   'Gender': ['Male'],
#   'Height (cm)': 30.5,
#   'Medium': 'Graphite, ink, watercolor, and metallic paint on paper',
#   'Nationality': ['Austrian'],
#   'ObjectID': 36,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjIzMyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=ef193035b3a3aafd',
#   'Title': 'House in Krems, project, Krems, Austria, Elevation',
#   'URL': 'http://www.moma.org/collection/works/36',
#   'Width (cm)': 21.6},
#  {'AccessionNumber': '6.1995',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '20 x 20"(50.8 x 50.8 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 50.8,
#   'Medium': 'Photographic reproduction with colored synthetic laminate',
#   'Nationality': [],
#   'ObjectID': 38,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=31484971971b7d89',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, '
#            'Introductory panel to Episode 3: The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/38',
#   'Width (cm)': 50.8},
#  {'AccessionNumber': '6.1997',
#   'Artist': ['Otto Schönthal'],
#   'ArtistBio': ['Austrian, 1878–1961'],
#   'BeginDate': [1878],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7608],
#   'CreditLine': 'Gift of Jo Carole and Ronald S. Lauder',
#   'Date': '1906',
#   'DateAcquired': '1997-01-15',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 5/8 x 14 1/8" (29.6 x 35.8 cm)',
#   'EndDate': [1961],
#   'Gender': ['Male'],
#   'Height (cm)': 29.6,
#   'Medium': 'Pencil, ink, colored pencil, and gouache on paper',
#   'Nationality': ['Austrian'],
#   'ObjectID': 39,
#   'ThumbnailURL': None,
#   'Title': 'Imperial Post Office, Teschen, Austria (Elevation)',
#   'URL': 'http://www.moma.org/collection/works/39',
#   'Width (cm)': 35.8},
#  {'AccessionNumber': '7.1995.1',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 41,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI5MyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=10dec16cba1a425d',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/41',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.1-9',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': 'Each: 48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9202,
#   'Medium': 'Ink and transfer on tracing paper',
#   'Nationality': [],
#   'ObjectID': 42,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI4OTExNCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=9bdec4b6fe84ea57',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/42',
#   'Width (cm)': 60.9601},
#  {'AccessionNumber': '7.1995.2',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 43,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI5NSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=fe1b299b2811e1f2',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/43',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.3',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 44,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI5NiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=1d4d25ae7bcd3c35',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/44',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.4',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 45,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI5NyJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=9ea63502ed5fc43b',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/45',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.5',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 46,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI5OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=1bd4abfd31196d89',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/46',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.6',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 47,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI5OSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=0c0575c28d6851d8',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/47',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.7',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 48,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjMwMCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=1bc4e79e5aea997e',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/48',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.8',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': [],
#   'ObjectID': 49,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjMwMSJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=6bbd8aacda8af72a',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall),',
#   'URL': 'http://www.moma.org/collection/works/49',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '7.1995.9',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1979',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '48 x 24" (121.9 x 61 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 121.9,
#   'Medium': 'Ink and photographic reproductions on tracing paper',
#   'Nationality': [],
#   'ObjectID': 50,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI4OTExNCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=9bdec4b6fe84ea57',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 3: '
#            'The Tower (The Fall)',
#   'URL': 'http://www.moma.org/collection/works/50',
#   'Width (cm)': 61.0},
#  {'AccessionNumber': '8.1995',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': 'Each: 20 x 20" (50.8 x 50.8 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 50.8,
#   'Medium': 'Photographic reproduction with colored synthetic laminate',
#   'Nationality': [],
#   'ObjectID': 52,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjMyMiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=069dcd60f6b2ba6a',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, '
#            'Introductory panel to Episode 4: The Block',
#   'URL': 'http://www.moma.org/collection/works/52',
#   'Width (cm)': 50.8},
#  {'AccessionNumber': '9.1995.1',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980-81',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '19 x 31" (48.3 x 78.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 48.3,
#   'Medium': 'Ink and cut-and-pasted gelatin silver photographs on tracing '
#             'paper',
#   'Nationality': [],
#   'ObjectID': 54,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjM0OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=4a7ba2ec36104db6',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 4: '
#            'The Block',
#   'URL': 'http://www.moma.org/collection/works/54',
#   'Width (cm)': 78.7},
#  {'AccessionNumber': '9.1995.1-14',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980-81',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': 'Each: 19 x 31" (48.2 x 78.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 48.2,
#   'Medium': 'Ink and photographs on tracing paper',
#   'Nationality': [],
#   'ObjectID': 55,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjM0OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=4a7ba2ec36104db6',
#   'Title': 'The Manhattan Transcripts Project, New York, New York, Episode 4: '
#            'The Block',
#   'URL': 'http://www.moma.org/collection/works/55',
#   'Width (cm)': 78.7},
#  {'AccessionNumber': '9.1995.10',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Purchase and partial gift of the architect in honor of Lily '
#                 'Auchincloss',
#   'Date': '1980-81',
#   'DateAcquired': '1995-01-17',
#   'Department': 'Architecture & Design',
#   'Dimensions': '19 x 31" (48.3 x 78.7 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 48.3,
#   'Medium': 'Ink and cut-and-pasted gelatin silver photographs on tracing '
#             'paper',
#   'Nationality': [],
#   'ObjectID': 56,
# ...
#   'Department': 'Architecture & Design',
#   'Dimensions': '12 x 33 1/2" (30.5 x 85.1 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 30.5,
#   'Medium': 'Ink on tracing paper',
#   'Nationality': ['Japanese'],
#   'ObjectID': 239,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2MDQiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=c87d42a587f3195c',
#   'Title': 'Nara Convention Hall, Nara, Japan, Preliminary sketches',
#   'URL': 'http://www.moma.org/collection/works/239',
#   'Width (cm)': 85.1},
#  {'AccessionNumber': '154.1993',
#   'Artist': ['Bernard Tschumi'],
#   'ArtistBio': ['French and Swiss, born Switzerland 1944'],
#   'BeginDate': [1944],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7056],
#   'CreditLine': 'Gift of Barbara Pine',
#   'Date': '1983',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 5/8 x 16 1/2" (29.5 x 41.9 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 29.5276,
#   'Medium': 'Ink on paper',
#   'Nationality': [],
#   'ObjectID': 240,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2MjEiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=dda73f5dc4ce17d1',
#   'Title': 'Parc de la Villette, Paris, France, Exterior perspectives, sketch',
#   'URL': 'http://www.moma.org/collection/works/240',
#   'Width (cm)': 41.9101},
#  {'AccessionNumber': '155.1993.1-36',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'N',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': '1915-17',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': None,
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 241,
#   'ThumbnailURL': None,
#   'Title': 'American System-Built Houses for The Richards Company, project, '
#            'Milwaukee, Wisconsin, Perspectives, plans, and elevations',
#   'URL': None},
#  {'AccessionNumber': '155.1993.13',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': '1915–1917',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 x 8 1/2" (27.9 x 21.6 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 27.9,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 242,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NDUiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=9c818166b4aae25c',
#   'Title': 'American System-Built Houses for The Richards Company project '
#            '(Exterior perspective of model D101)',
#   'URL': 'http://www.moma.org/collection/works/242',
#   'Width (cm)': 21.6},
#  {'AccessionNumber': '155.1993.14',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': '1915–1917',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 x 8 5/8" (27.9 x 21.9 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 27.9,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 243,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NDYiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=876fcf75567b5b5d',
#   'Title': 'American System-Built Houses for The Richards Company project '
#            '(Exterior perspective of model E3)',
#   'URL': 'http://www.moma.org/collection/works/243',
#   'Width (cm)': 21.9},
#  {'AccessionNumber': '155.1993.15',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': 'c. 1915-17',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '8 1/2 x 11 1/8" (21.6 x 28.3 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 21.6,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 244,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NDciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=205bd99f51782e7d',
#   'Title': 'American System-Built Houses for The Richards Company, project, '
#            'Milwaukee, Wisconsin, Isometric plan of model J400',
#   'URL': 'http://www.moma.org/collection/works/244',
#   'Width (cm)': 28.3},
#  {'AccessionNumber': '155.1993.16',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': 'c. 1915-17',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '8 5/8 x 11" (21.9 x 27.9 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 21.9,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 245,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NDgiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=3a867440a4b08c52',
#   'Title': 'American System-Built Houses for The Richards Company, project, '
#            'Milwaukee, Wisconsin, Isometric plan of model J900',
#   'URL': 'http://www.moma.org/collection/works/245',
#   'Width (cm)': 27.9},
#  {'AccessionNumber': '155.1993.17',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': 'c. 1915-17',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 x 8 1/2" (27.9 x 21.6 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 27.9,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 246,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NDkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=cd80e7b950c2be3f',
#   'Title': 'American System-Built Houses for The Richards Company, project, '
#            'Milwaukee, Wisconsin, Perpsective of model J902',
#   'URL': 'http://www.moma.org/collection/works/246',
#   'Width (cm)': 21.6},
#  {'AccessionNumber': '155.1993.18',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': '1915–1917',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 x 8 1/2" (27.9 x 21.6 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 27.9,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 247,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NTAiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=f10223e7c92596fe',
#   'Title': 'American System-Built Houses for The Richards Company project, '
#            '(Plan oblique of unspecified model)',
#   'URL': 'http://www.moma.org/collection/works/247',
#   'Width (cm)': 21.6},
#  {'AccessionNumber': '155.1993.2',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': '1915–1917',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 1/8 x 8 5/8" (28.3 x 21.9 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 28.3,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 248,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NTEiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=c609c987ff950e20',
#   'Title': 'American System-Built Houses for The Richards Company project '
#            '(Perspective of model A221)',
#   'URL': 'http://www.moma.org/collection/works/248',
#   'Width (cm)': 21.9},
#  {'AccessionNumber': '155.1993.4',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': 'c. 1915-17',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 x 8 1/2" (27.9 x 21.6 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 27.9,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 249,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NTIiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=64eaca004e2402ef',
#   'Title': 'American System-Built Houses for The Richards Company, project, '
#            'Milwaukee, Wisconsin, Perspective of model A243',
#   'URL': 'http://www.moma.org/collection/works/249',
#   'Width (cm)': 21.6},
#  {'AccessionNumber': '155.1993.6',
#   'Artist': ['Frank Lloyd Wright'],
#   'ArtistBio': ['American, 1867–1959'],
#   'BeginDate': [1867],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6459],
#   'CreditLine': 'Gift of David Rockefeller, Jr. Fund, Ira Howard Levy Fund, '
#                 'and Jeffrey P. Klein Purchase Fund',
#   'Date': '1915–1917',
#   'DateAcquired': '1993-05-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '11 x 8 1/2" (27.9 x 21.6 cm)',
#   'EndDate': [1959],
#   'Gender': ['Male'],
#   'Height (cm)': 61.5951231902,
#   'Medium': 'Lithograph',
#   'Nationality': ['American'],
#   'ObjectID': 250,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI2NTMiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=4d2ecbddcce1eb58',
#   'Title': 'American System-Built Houses for The Richards Company project '
#            '(Exterior perspective of model B23)',
#   'URL': 'http://www.moma.org/collection/works/250',
#   'Width (cm)': 21.6},
#  {'AccessionNumber': '157.1991',
#   'Artist': ['Roberto Burle Marx', 'Oscar Niemeyer'],
#   'ArtistBio': ['Brazilian, 1909–1994', 'Brazilian, 1907–2012'],
#   'BeginDate': [1909, 1907],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6934, 8103],
#   'CreditLine': 'Gift of Roblee McCarthy, Jr. Fund and Lily Auchincloss Fund',
#   'Date': '1953',
#   'DateAcquired': '1991-06-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '39 1/2  x  59 1/2" (100.3 x 151.1 cm)',
#   'EndDate': [1994, 2012],
#   'Gender': ['Male', 'Male'],
#   'Height (cm)': 100.3,
#   'Medium': 'Gouache and graphite on board',
#   'Nationality': ['Brazilian', 'Brazilian'],
#   'ObjectID': 252,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI4NDc1MiJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=d00103acc404dd06',
#   'Title': 'Ibirapuera Park project, São Paulo, Brazil (Site plan)',
#   'URL': 'http://www.moma.org/collection/works/252',
#   'Width (cm)': 151.1},
#  {'AccessionNumber': '158.1991',
#   'Artist': ['Roberto Burle Marx', 'Oscar Niemeyer'],
#   'ArtistBio': ['Brazilian, 1909–1994', 'Brazilian, 1907–2012'],
#   'BeginDate': [1909, 1907],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [6934, 8103],
#   'CreditLine': 'Gift of Roblee McCarthy, Jr. Fund and Lily Auchincloss Fund',
#   'Date': '1953',
#   'DateAcquired': '1991-06-04',
#   'Department': 'Architecture & Design',
#   'Dimensions': '39 x 59 1/2" (99.1 x 151.1 cm)',
#   'EndDate': [1994, 2012],
#   'Gender': ['Male', 'Male'],
#   'Height (cm)': 99.1,
#   'Medium': 'Gouache on board',
#   'Nationality': ['Brazilian', 'Brazilian'],
#   'ObjectID': 253,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjI4NDc1NCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=73c8b1297478de0b',
#   'Title': 'Ibirapuera Park Project, São Paulo, Brazil (Perspective)',
#   'URL': 'http://www.moma.org/collection/works/253',
#   'Width (cm)': 151.1},
#  {'AccessionNumber': '191.1998',
#   'Artist': ['Neil M. Denari'],
#   'ArtistBio': ['American, born 1957'],
#   'BeginDate': [1957],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7933],
#   'CreditLine': 'Ralph Fehlbaum Purchase Fund',
#   'Date': '1992',
#   'DateAcquired': '1998-04-22',
#   'Department': 'Architecture & Design',
#   'Dimensions': '24 1/2 x 33 1/16" (62.2 x 84 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 62.2,
#   'Medium': 'Ink, airbrush, and cut-and-pasted printed self-adhesive polymer '
#             'sheet on frosted polymer sheet',
#   'Nationality': ['American'],
#   'ObjectID': 255,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjMxNTciXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=0ce2bf49d3f5f3c7',
#   'Title': 'Prototype Architecture School No. 5, project, Los Angeles, '
#            'California, Elevations',
#   'URL': 'http://www.moma.org/collection/works/255',
#   'Width (cm)': 84.0},
#  {'AccessionNumber': '192.1998',
#   'Artist': ['Ludwig Mies van der Rohe'],
#   'ArtistBio': ['American, born Germany. 1886–1969'],
#   'BeginDate': [1886],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [7166],
#   'CreditLine': 'Rob Beyer Purchase Fund, Edward Larrabee Barnes Purchase '
#                 'Fund, Marcel Breuer Purchase Fund, and Philip Johnson '
#                 'Purchase Fund',
#   'Date': '1910',
#   'DateAcquired': '1998-04-22',
#   'Department': 'Architecture & Design',
#   'Dimensions': '55 1/2 x 94 1/2" (141 x 240 cm)',
#   'EndDate': [1969],
#   'Gender': ['Male'],
#   'Height (cm)': 141.0,
#   'Medium': 'Gouache on linen',
#   'Nationality': ['American'],
#   'ObjectID': 256,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjMxNjkiXSxbInAiLCJjb252ZXJ0IiwiLXJlc2l6ZSAzMDB4MzAwXHUwMDNlIl1d.jpg?sha=3c9df97b4be13aa4',
#   'Title': 'Bismarck Monument, project, Bingen, Germany, Perspective view of '
#            'courtyard',
#   'URL': 'http://www.moma.org/collection/works/256',
#   'Width (cm)': 240.0},
#  {'AccessionNumber': '194.1973',
#   'Artist': ['David Jacob'],
#   'ArtistBio': ['American, born 1928'],
#   'BeginDate': [1928],
#   'Cataloged': 'Y',
#   'Classification': 'Architecture',
#   'ConstituentID': [2864],
#   'CreditLine': 'Estée and Joseph Lauder Design Fund',
#   'Date': '1970',
#   'DateAcquired': '1973-05-08',
#   'Department': 'Architecture & Design',
#   'Depth (cm)': 87.3127,
#   'Dimensions': '28 x 34 3/8 x 34 3/8" (71.1 x 87.3 x 87.3 cm)',
#   'EndDate': [0],
#   'Gender': ['Male'],
#   'Height (cm)': 71.1201,
#   'Medium': 'Fiberglass, polyester resin, metal, paper, plastic and synthetic '
#             'polymer paint',
#   'Nationality': ['American'],
#   'ObjectID': 257,
#   'ThumbnailURL': 'http://www.moma.org/media/W1siZiIsIjIyODY1OCJdLFsicCIsImNvbnZlcnQiLCItcmVzaXplIDMwMHgzMDBcdTAwM2UiXV0.jpg?sha=ff682356d0f9e950',
#   'Title': 'Simulated Dwelling for a Family of Five Project',
#   'URL': 'http://www.moma.org/collection/works/257',
#   'Width (cm)': 87.3127}]

# %% [markdown]
# Much like a dictionary object in Python, a JSON object is made up of key-value pairs that can contain (and be contained in) lists. In this case, MoMA has presented metadata for its artworks as a list of key-value pairs.
#
# To see the number of artworks included in the JSON object, use the `len()` function.

# %%
len(json_data)
# Out:
# 133331

# %% [markdown]
# To view the key-value metadata for a random artwork, use `random.choice()`.

# %%
import random

random.choice(json_data)
# Out:
# {'AccessionNumber': '48.1991.x1-x2',
#  'Artist': ['Karen Klugman'],
#  'ArtistBio': ['American, born 1946'],
#  'BeginDate': [1946],
#  'Cataloged': 'N',
#  'Classification': 'Photograph',
#  'ConstituentID': [7030],
#  'CreditLine': 'The Family of Man Fund',
#  'Date': '1989',
#  'DateAcquired': '1991-03-14',
#  'Department': 'Photography',
#  'Dimensions': '28 1/8 x 38 5/16" (71.4 x 97.3 cm)',
#  'EndDate': [0],
#  'Gender': ['Female'],
#  'Height (cm)': 71.4,
#  'Medium': 'Chromogenic color print',
#  'Nationality': ['American'],
#  'ObjectID': 44797,
#  'ThumbnailURL': None,
#  'Title': 'Headsets',
#  'URL': None,
#  'Width (cm)': 97.3}

# %% [markdown]
# Using bracket notation, we can access individual metadata fields by their keys. Here we display several metadata fields for a randomly chosen artwork.

# %%
artwork = random.choice(json_data)

print(artwork['Artist'])
print(artwork['Title'])
print(artwork['Date'])
print(artwork['ObjectID'])
print(artwork['URL'])
# Out:
# ['Lee Friedlander']
# Santa Fe
# 1995
# 87025
# None

# %% [markdown]
# The following loop will print the `Artist` field for the first 100 artworks in the list.

# %%
for item in json_data[:100]:
    pprint(item['Artist'])
# Out:
# ['Otto Wagner']
# ['Christian de Portzamparc']
# ['Emil Hoppe']
# ['Bernard Tschumi']
# ['Emil Hoppe']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Louis I. Kahn']
# ['Bernard Tschumi']
# ['Marcel Kammerer']
# ['Bernard Tschumi']
# ['Otto Schönthal']
# ['Bernard Tschumi']
# ['Otto Schönthal']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Bernard Tschumi']
# ['Hans Poelzig']
# ['Raimund Abraham']
# ['Peter Eisenman', 'Robert Cole']
# ['Rem Koolhaas', 'Madelon Vriesendorp']
# ['Roger C. Ferri']
# ['Bernard Tschumi']
# ['Roger C. Ferri']
# ['Bernard Tschumi']
# ['Roger C. Ferri']
# ['Michael Graves']
# ['Michael Graves']
# ['Michael Graves']
# ['Michael Graves']
# ['Aldo Rossi', 'Gianni Braghieri', 'M. Bosshard']
# ['Ludwig Mies van der Rohe']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']
# ['Erik Gunnar Asplund']

# %% [markdown]
# You can also use `random.sample()` to view artist names for 100 artworks chosen at random.

# %%
for item in random.sample(json_data, 100):
    pprint(item['Artist'])
# Out:
# ['Henri Michaux']
# ['Franz Erhard Walther']
# ['Georges Braque']
# ['Barney Ingoglia/The New York Times']
# ['Rufino Tamayo']
# ['Felice Beato']
# ['William Wegman']
# ['Natalia Goncharova']
# ['Wols (A. O. Wolfgang Schulze)']
# ['Tony Bevan']
# ['Eugène Atget']
# ['Aftograf']
# ['Dóra Maurer']
# ['Adolf Fassbender']
# ['Glenn O. Coleman']
# ['Various Artists']
# ['Nicholas Krushenick']
# ['Kaj Franck']
# ['Kazimir Malevich']
# ['Louise Bourgeois']
# ['Lee Friedlander']
# ['Garo Antreasian']
# ['Clinton Adams']
# ['Ivan Kudriashov']
# ['Raoul Dufy']
# ['K.R.H. Sonderborg']
# ['André Dunoyer de Segonzac']
# ['Louise Bourgeois']
# ['George Maciunas']
# ['Louise Bourgeois']
# ['Gerald Jackson']
# ['Palle Nielson']
# ['Joel Meyerowitz']
# ['Vanessa Beecroft']
# ['caraballo-farman']
# ['Maurice de Vlaminck']
# ['Georg Baselitz']
# ['James McGarrell']
# ['Various Artists']
# ['Unknown photographer']
# ['Peter Doig']
# ['Charles J. Brabin']
# ['Eduardo Paolozzi']
# ['Seymour Chwast', 'Richard Mantel', 'Milton Glaser']
# ['Safi Faye']
# ['Chris Ofili']
# ['Oskar Schlemmer']
# ['Vincent Borrelli']
# ['Ansel Adams']
# ['Dorothea Lange']
# ['Masuo Ikeda']
# ['Bruce Horowitz']
# ['Maurice Denis']
# ['Eugène Atget']
# ['Jacob August Riis']
# ['La Monte Young']
# ['Bill Jensen']
# ['Kirill Rozhdestvenskii']
# ['George Maciunas']
# ['Pablo Picasso']
# ['Martin Kersels']
# ['Krzysztof Wodiczko']
# ['Robert Wilson']
# ['Unknown Artist']
# ['Elizabeth Murray']
# ['Gego (Gertrud Goldschmidt)']
# ['George Maciunas',
#  'Greg Sharits',
#  'Paul Sharits',
#  'Bob Grimes',
#  'Dave Thompson']
# ['Fiona Banner']
# ['Mario Bellini']
# ['Ian (Hugh Guiler) Hugo']
# ['The Beatles']
# ['Frank Lloyd Wright']
# ['John Hoyland']
# ['Georges Braque']
# ['Christian Marclay']
# ['Unknown Artist']
# ['Ragnar Kjartansson']
# ['Marie Laurencin']
# ['Senzeni Marasela']
# ['Unknown photographer']
# ['Peter Doig']
# ['Lewis W. Hine']
# ['William Vandivert']
# ['Isidoro Ocampo']
# ['Geta Brătescu']
# ['Louise Bourgeois']
# ['Dorothea Lange']
# ['David Octavius Hill']
# ['Lucien Clergue']
# ['Jules Pascin']
# ['Helmut Kandl']
# ['Émile Bernard']
# ['Unknown photographer']
# ['Eduardo Paolozzi']
# ['Garry Winogrand']
# ['Alexander Roitburd']
# ['Bruce Nauman']
# ['Mario Prassinos']
# ['William Hanna', 'Joseph Barbera']
# ['John Baldessari', 'Harry Shunk', 'János Kender']

# %% [markdown]
# #### JSON Data to CSV
# Next we’ll transfer these metadata fields to CSV format. First, let’s print a list of metadata fields for reference:

# %%
header = []

for key in json_data[0]:
    header.append(key)

# %% [markdown]
# Next we'll create a list of metadata fields to include in our CSV. These keys will appear at the top of the file as column headers.

# %%
column_headers = ['Date', 'Artist', 'Title', 'Medium', 'Nationality', 'ObjectID', 'URL', 'Department']

pprint(column_headers)
# Out:
# ['Date',
#  'Artist',
#  'Title',
#  'Medium',
#  'Nationality',
#  'ObjectID',
#  'URL',
#  'Department']

# %% [markdown]
# Then we’ll use these keys to create a list of rows for our CSV. Since some metadata entries in the JSON object appear as lists rather than strings, we’ll use the `str()` function to reformat each metadata item as we add it to the table.
#
# To avoid slowing things down, we will work with metadata for 20,000 randomly chosen artworks.

# %%
meta_table = []

for record in random.sample(json_data, 20000):
    row = []
    for key in column_headers:
        row.append(str(record[key]))
    meta_table.append(row)

pprint(meta_table[0])
# Out:
# ['c. 1965',
#  "['Alison Knowles']",
#  'by Alison Knowles',
#  'Series of ten sheets of paper with carbon copy, typewriter, ink, blue '
#  'pencil, and graphite, with additions by Dick Higgins and unknown hands',
#  "['American']",
#  '127405',
#  'http://www.moma.org/collection/works/127405',
#  'Prints & Illustrated Books']

# %% [markdown]
# Finally, we will write our metadata list of lists as a CSV.

# %%
import csv

out_path = "/sharedfolder/MoMA_20K.csv"

with open(out_path, 'w') as fo:
    csv_out = csv.writer(fo)
    csv_out.writerow(column_headers)
    csv_out.writerows(meta_table)

# %% [markdown]
# Open your CSV in LibreOffice or Excel.
